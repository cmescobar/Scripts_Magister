# %%
# Imports
import os, warnings
import librosa
import numpy as np
import tensorflow as tf
import soundfile as sf
import matplotlib.pyplot as plt
from ast import literal_eval
from scipy.io import wavfile
from scipy import signal, fftpack
from collections import defaultdict
from testing_functions import test_hss
from process_functions import preprocessing_audio
from utils import find_and_open_audio, signal_segmentation, get_resp_segments
from heart_sound_segmentation.filter_and_sampling import downsampling_signal, \
    upsampling_signal
from respiratory_sound_classification.respiratory_sound_management import \
    get_label_filename
from source_separation.descriptor_functions import get_spectrogram
from IPython.display import Audio
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn import preprocessing, linear_model, svm
from sklearn.metrics import confusion_matrix, accuracy_score
from pybalu.feature_selection import sfs
from pybalu.feature_transformation import normalize

# %% [markdown]
# # Funciones previas

# %%
# Funciones de características
def get_filterbanks(N, samplerate, freq_lim, n_filters, norm_exp=1,
                    scale_type='mel', filter_type='triangular',
                    norm_filters=True, plot_filterbank=False):
    '''Función que permite obtener un banco de filtros linealmente
    espaciados o espaciados en frecuencia de mel para calcular
    coeficientes cepstrales.
    
    Parameters
    ----------
    N : ndarray
        Largo de la señal.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_filters : int
        Cantidad de filtros a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''
    def _freq_to_bin(f):
        # Definición del bin correspondiente en la definición
        # del intervalo de cálculo. Se usa (N - 1) ya que los bins
        # se definen entre 0 y (N - 1) (largo N)
        return np.rint(f / samplerate * (N - 1)).astype(int)
    
    
    def _triangular_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i] + 1] = \
                np.linspace(0, 1, abs(bins_points[i] - bins_points[i - 1] + 1))
            
            # Tramo descendente del filtro triangular
            filter_bank[i - 1][bins_points[i]:bins_points[i + 1] + 1] = \
                np.linspace(1, 0, abs(bins_points[i + 1] - bins_points[i] + 1))
            
        return filter_bank
    
    
    def _hanning_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i + 1] + 1] = \
                np.hanning(abs(bins_points[i + 1] - bins_points[i - 1] + 1))
        
        return filter_bank
    
    
    def _squared_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i + 1] + 1] = 1
        
        return filter_bank
    
    
    def _norm_filterbank(filter_bank):
        # Definición del banco de filtros de salida
        filter_bank_out = np.zeros((n_filters, N))
        
        # Normalizar los filtros a energía 1
        for i in range(n_filters):
            filter_bank_out[i] = filter_bank[i] / \
                                 sum(filter_bank[i] ** norm_exp)
            
        return filter_bank_out
    
    
    # Definición de los bines en base a las frecuencias de cada filtro
    if scale_type == 'linear':
        # Definición de las "n_filters" frecuencias equiespaciadas entre
        # 0 y freq_lim. Se le agregan 2 puntos (0 y el freq_lim) ya que se 
        # necesitan para definir los límites de los filtros.
        freqs = np.arange(0, (n_filters + 1) + 1) * freq_lim / (n_filters + 1)
    
    
    elif scale_type == 'mel':
        # Definición del límite en frecuencias de mel (para no pasarse del
        # freq_lim al devolverse)
        mel_freq_lim = 2595 * np.log10(1 + freq_lim / 700)
        
        # Definición de las "n_filters" frecuencias espaciadas en escala mel 
        # entre 0 y freq_lim. Se le agregan 2 puntos (0 y el freq_lim) ya 
        # que se necesitan para definir los límites de los filtros.
        mel_freqs = np.arange(0, (n_filters + 1) + 1) * mel_freq_lim / (n_filters + 1)
        
        # Transformando de intervalos equi espaciados usando la escala
        # de mel. Es necesario hacer la transformación inversa ya que
        # en este caso se dice que lo equi espaciado viene de mel
        freqs = 700 * (10 ** (mel_freqs / 2595) - 1)
    
    else:
        raise Exception('Opción de tipo de coeficiente cepstral no válido.')
    
    
    # Transformando a bins
    bins_to = _freq_to_bin(freqs)
    
    
    # Obtención del banco de filtros
    if filter_type == 'triangular':
        filter_bank = _triangular_filter(bins_to)
        
    if filter_type == 'hanning':
        filter_bank = _hanning_filter(bins_to)
    
    elif filter_type == 'squared':
        filter_bank = _squared_filter(bins_to)
    
    # Normalizar por la energía de la señal
    if norm_filters:
        filter_bank = _norm_filterbank(filter_bank)
    
    
    # Gráfico del banco de filtros
    if plot_filterbank:
        plt.figure()
        
        # Definición del vector de frecuencias
        f_plot = np.arange(N) * samplerate / N
        
        for i in range(n_filters):
            plt.plot(filter_bank[i])
            # plt.plot(f_plot, filter_bank[i])

        for i in bins_to:
            # plt.axvline(i * samplerate / N, c='silver', linestyle=':')
            plt.axvline(i, c='silver', linestyle=':')
            
        # plt.xlim([0, freq_lim])
        plt.xlim([0, bins_to[-1]])
        plt.show()
    
    
    return filter_bank


def get_cepstral_coefficients(signal_in, samplerate, spectrogram_params,
                              freq_lim, n_filters, n_coefs, scale_type='mel', 
                              filter_type='triangular', inverse_func='dct', 
                              norm_filters=True, plot_filterbank=False, 
                              power=2):
    '''Función que permite obtener los coeficientes cepstrales a partir de 
    un banco de filtros.
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_coefs : int
        Cantidad de coeficientes a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''    
    # Definición de la cantidad de puntos a considerar
    filter_bank = get_filterbanks(spectrogram_params['N'], samplerate, 
                                  freq_lim=freq_lim, n_filters=n_filters, 
                                  scale_type=scale_type, 
                                  filter_type=filter_type,
                                  norm_filters=norm_filters, 
                                  plot_filterbank=plot_filterbank)
    
    # Obtener el espectrograma de la señal
    t, f, S = get_spectrogram(signal_in, samplerate, N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=True)
    
    # Definición del espectro de la señal
    energy_spectrum = np.abs(S) ** power
    
    # Se aplica el banco de filtros sobre el espectro de la señal
    energy_coefs = np.dot(filter_bank, energy_spectrum)
    
    # Aplicando el logaritmo
    energy_coefs = np.log(energy_coefs + 1e-10)
    
    # Calculando los coeficientes cepstrales
    if inverse_func == 'dct':
        cepstral_coefs = fftpack.dct(energy_coefs, norm='ortho', axis=0)
    elif inverse_func == 'idft':
        cepstral_coefs = np.fft.ifft(energy_coefs, axis=-1).real
    else:
        raise Exception('Opción de tipo de función inversa no válida.')
    
    
    return cepstral_coefs[:n_coefs]


def get_bands_coefficients(signal_in, samplerate, spectrogram_params,
                           freq_lim, n_coefs, scale_type='mel', 
                           filter_type='triangular', norm_filters=True, 
                           plot_filterbank=False, 
                           power=2):
    '''Función que permite obtener la energía por bandas de frecuencia
    a partir de un banco de filtros.
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_coefs : int
        Cantidad de coeficientes a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''    
    # Definición de la cantidad de puntos a considerar
    filter_bank = get_filterbanks(spectrogram_params['N'], samplerate, 
                                  freq_lim=freq_lim, 
                                  n_coefs=n_coefs, scale_type=scale_type, 
                                  filter_type=filter_type,
                                  norm_filters=norm_filters, 
                                  plot_filterbank=plot_filterbank)
    
    # Obtener el espectrograma de la señal
    t, f, S = get_spectrogram(signal_in, samplerate, N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=True)
    
    # Definición del espectro de la señal
    energy_spectrum = np.abs(S) ** power
    
    # Se aplica el banco de filtros sobre el espectro de la señal
    energy_coefs = np.dot(filter_bank, energy_spectrum)
    
    return energy_coefs


def get_energy_bands(signal_in, samplerate, spectrogram_params, 
                     fmin=0, fmax=1000, fband=20, power=2):
    '''Función que permite definir un espectrograma en bandas de 
    energía.
    
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    spectrogram_params : dict
        Parámetros del espectrograma.
    fmin : float, optional
        Frecuencia mínima a considerar en el intervalo de interés.
        Por defecto es 0.
    fmax : float, optional
        Frecuencia máxima a considerar en el intervalo de interés.
        Este valor no puede mayor a samplerate / 2. Por defecto 
        es 1000.
    fband : float, optional
        Ancho de cada banda de frecuencia entre fmin y fmax. Por 
        defecto es 20.
    power : float, optional
        Exponente con el que se calcula la energía.
    
    Returns
    -------
    energy_S : ndarray
        Bandas de energía a través del tiempo (formato 
        espectrograma) con dimensión (#bandas x #bins de tiempo 
        del espectrograma).     
    '''
    # Obtener el espectrograma
    t, f, S = get_spectrogram(signal_in, samplerate, 
                              N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=False)
    
    # Definición de los intervalos
    f_intervals = np.arange(fmin, fmax, fband)

    # Definición de la lista que almacenará los datos
    energy_band = np.zeros(len(f_intervals) - 1)
    energy_S = np.zeros((len(energy_band), len(t)))

    for i in range(len(f_intervals) - 1):
        lower_lim = f_intervals[i]
        upper_lim = f_intervals[i + 1]

        # Definición de los índices de interés
        indexes = np.where((lower_lim <= f) & (f <= upper_lim))[0]

        # Definiendo el valor
        energy_S[i] = np.sum(abs(S[indexes,:]) ** power, axis=0)
    
    return energy_S

# %%
def _conditioning_signal(signal_in, samplerate, samplerate_to):
    # Acondicionando en caso de que no tenga samplerate de 1000 Hz.
    if samplerate < samplerate_to:
        print(f'Upsampling de la señal de fs = {samplerate} Hz '
              f'a fs = {samplerate_to} Hz.') 
        new_rate = samplerate_to           
        audio_to = upsampling_signal(signal_in, samplerate, new_samplerate=new_rate)

    elif samplerate > samplerate_to:
        print(f'Downsampling de la señal de fs = {samplerate} Hz '
              f'a fs = {samplerate_to} Hz.')
        new_rate, audio_to = downsampling_signal(signal_in, samplerate, 
                                                 freq_pass=samplerate_to//2-100, 
                                                 freq_stop=samplerate_to//2)

    else:
        print(f'Samplerate adecuado a fs = {samplerate} Hz.')
        audio_to = signal_in
        new_rate = samplerate_to

    # Mensaje para asegurar
    print(f'Señal acondicionada a {new_rate} Hz para la separación de fuentes.')

    # Asegurándose de que el largo de la señal sea par
    if len(audio_to) % 2 != 0:
        audio_to = np.concatenate((audio_to, [0]))

    return audio_to, new_rate

# %%
def pybalu_clean(features, tol=1e-8, show=False):
    n_features = features.shape[1]
    ip = np.ones(n_features, dtype=int)

    # cleaning correlated features
    warnings.filterwarnings('ignore')
    C = np.abs(np.corrcoef(features, rowvar=False))
    idxs = np.vstack(np.where(C > .99))
    
    # remove pairs of same feature ( feature i will have a correlation of 1 whit itself )
    idxs = idxs[:, idxs[0,:] != idxs[1,:]]
    
    # remove correlated features
    if idxs.size > 0:
        ip[np.max(idxs, 0)] = 0
    
    # remove constant features
    s = features.std(axis=0, ddof=1)
    ip[s < tol] = 0
    p = np.where(ip.astype(bool))[0]

    if show:
        print(f'Clean: number of features reduced from {n_features} to {p.size}.')

    return p

# %% [markdown]
# # Parámetros de los descriptores

# %%
# Parámetro base de datos
preprocess = True

# Parámetros de los espectrogramas generales
N = 1024
noverlap = int(0.9 * N)
spec_params = {'N': N, 'noverlap': noverlap, 'window': 'hann', 
               'padding': 0, 'repeat': 0}

# Parámetros MFCC
mfcc_params = {'n_mfcc': 50, 'n_filters': 50, 'spec_params': spec_params,
               'freq_lim': 2000, 'norm_filters': True, 'power': 2}
lfcc_params = {'n_mfcc': 50, 'n_filters': 50, 'spec_params': spec_params,
               'freq_lim': 2000, 'norm_filters': True, 'power': 2}
energy_params = {'spec_params': spec_params, 'fmin': 0, 'fmax': 1000, 
                 'fband': 20}

# Parámetros de extracción de características
collapse_mfcc = 'mean'
func_type = 'cepstral_coefficients'

# %%
# Dirección de la base de datos
db_original = 'C:/Users/Chris/Desktop/Scripts_Magister/Respiratory_Sound_Database/audio_and_txt_files'
db_folder = 'preprocessed_signals'

# Nombres de los archivos
filenames = [i[:-4] for i in os.listdir(db_folder) if i.endswith('.wav') and not 'Tc' in i]

# %% [markdown]
# # Stratify

# %%
# Definición de la carpeta a buscar los archivos
train_test_folder = '/'.join(db_original.split('/')[:-1])
file_traintest = f'{train_test_folder}/ICBHI_challenge_train_test.txt'

def train_test_filebased(filename, db_root, db_folder):
    # Definición de las listas de entrenamiento y testeo
    train_list = list()
    test_list = list()

    # Definición de la lista de nombres de entrenamiento y testeo
    with open(filename, 'r', encoding='utf8') as file:
        for line in file:
            # Obteniendo los datos de cada línea
            data = line.strip().split('\t')

            # Controlar que no se utilicen sonidos traqueales
            if 'Tc' in data[0]:
                continue

            # Definición del nombre del archivo de audio
            filename_audio = f'{db_root}/{data[0]}.wav'

            # Obteniendo el samplerate del archivo original
            try:
                sr, _ = wavfile.read(f'{filename_audio}')
            except:
                _, sr = sf.read(f'{filename_audio}')

            if data[1] == 'train':
                train_list.append((f'{db_folder}/{data[0]}_{sr}'))
            elif data[1] == 'test':
                test_list.append((f'{db_folder}/{data[0]}_{sr}'))
                
    return train_list, test_list


train_list, test_list = \
        train_test_filebased(file_traintest, db_original, db_folder)

# %%
# Checkeo de sanidad
patients_train = set()
patients_test = set()

for filename in train_list:
    patient_i = filename.split('/')[-1].split('_')[0]
    patients_train.add(patient_i)

for filename in test_list:
    patient_i = filename.split('/')[-1].split('_')[0]
    patients_test.add(patient_i)

print(patients_train)
print(patients_test)
print(patients_train & patients_test)
print(len(train_list))
print(len(test_list))

# %% [markdown]
# # Creación de etiquetas por eventos

# %%
# Dirección de los eventos
db_events = 'C:/Users/Chris/Desktop/Scripts_Magister/Respiratory_Sound_Database/events'
db_folder = 'preprocessed_signals'

for filename in sound_files:
    # Definición del nombre correspondiente
    signal_name = '_'.join(filename.split('_')[:-1])
    
    with open(f'{db_events}/{signal_name}_events.txt', 'r', encoding='utf8') as file:
        # Obteniendo el largo de cada señal
        filename_audio = f'{db_folder}/{filename}'
        
        # Cargando el archivo
        try:
            samplerate, audio = wavfile.read(f'{filename_audio}')
        except:
            audio, samplerate = sf.read(f'{filename_audio}')
        
        # Definición de las etiquetas para cada caso
        Y_wheeze = np.zeros(len(audio))
        Y_crackl = np.zeros(len(audio))
        
        # Obteniendo la información de cada segmento
        for line in file:
            # Obteniendo la información de la línea
            data = line.strip().split('\t')
            
            if data == ['']:
                continue
            
            # Definición de los límites inferior y superior
            lower = int(float(data[0]) * samplerate)
            upper = int(float(data[1]) * samplerate)
            
            # Revisando etiquetas
            if data[-1] == 'crackle':
                Y_crackl[lower:upper] = 1
            
            if data[-1] == 'wheeze':
                Y_wheeze[lower:upper] = 1
            
        # Una vez definido, se agrega al diccionario
        Y_wheeze_dict[signal_name] = Y_wheeze.astype(int)
        Y_crackl_dict[signal_name] = Y_crackl.astype(int)

# %% [markdown]
# # Extracción de características

# %%
# %matplotlib notebook

# Definición de los arrays donde se acumulará las características
X_data_mean = list()
X_data_max = list()
X_segments = list()

# Definición de los arrays donde se acumularán las etiquetas
Y_wheeze = list()
Y_crackl = list()

# Diccionario que indica los segmentos que corresponden a cada paciente
patient_register = defaultdict(list)

# Contador de los segmentos
seg_i = 0

# Definición de una lista auxiliar de sanidad
segments_register = list()


# Nombre del archivo .wav a utilizar
for num, name in enumerate(filenames):
    print(f'Iteración {num + 1}: {name}')
    print(f'--------------------------')
    
    # Definición del paciente de interés
    patient = name.split('_')[0]
    
    if preprocess:
        filename = f'{db_folder}/{name}'
    else:
        filename = f'{db_original}/{name}'
    
    
    # Cargando el archivo
    try:
        samplerate, resp_signal = wavfile.read(f'{filename}.wav')
    except:
        resp_signal, samplerate = sf.read(f'{filename}.wav')
    
    print(f'Samplerate = {samplerate}, largo = {resp_signal.shape}')
    
    # Normalizando
    resp_signal = resp_signal / max(abs(resp_signal))
    
    
    # Obteniendo la información de los segmentos de este archivo de 
    # audio
    sr = filename.split('_')[-1]
    name_lab = '_'.join(filename.split('/')[-1].split('_')[:-1])
    Y_wheeze, Y_crackl = \
            get_label_filename(filename=name_lab, samplerate=float(sr), 
                               length_desired=len(resp_signal))
    
    continue
    
    # Para cada segmento, se obtiene la información de interés
    for resp_info in resp_list_info:
        # Registrando
        patient_register[patient].append(seg_i)
        seg_i += 1
        
        # Agregando a la lista el segmento
        X_segments.append(resp_info[0])
        
        ### Calculando las características a partir del segmento ###
        
        # Cálculo del MFCC
        mfcc_features = \
            get_cepstral_coefficients(resp_info[0], samplerate, 
                                      spectrogram_params=mfcc_params['spec_params'],
                                      freq_lim=mfcc_params['freq_lim'], 
                                      n_filters=mfcc_params['n_filters'], 
                                      n_coefs=mfcc_params['n_mfcc'], 
                                      scale_type='mel', 
                                      filter_type='triangular', inverse_func='dct', 
                                      norm_filters=mfcc_params['norm_filters'], 
                                      plot_filterbank=False, 
                                      power=mfcc_params['power'])
                
        # Cálculo del LFCC
        lfcc_features = \
            get_cepstral_coefficients(resp_info[0], samplerate, 
                                      spectrogram_params=lfcc_params['spec_params'],
                                      freq_lim=lfcc_params['freq_lim'], 
                                      n_filters=lfcc_params['n_filters'], 
                                      n_coefs=lfcc_params['n_mfcc'], 
                                      scale_type='linear', 
                                      filter_type='triangular', inverse_func='dct', 
                                      norm_filters=lfcc_params['norm_filters'], 
                                      plot_filterbank=False, 
                                      power=lfcc_params['power'])
        
        # Cálculo de la energía por bandas
        energy_S = \
            get_energy_bands(resp_info[0], samplerate,
                             spectrogram_params=energy_params['spec_params'],
                             fmin=energy_params['fmin'], 
                             fmax=energy_params['fmax'], 
                             fband=energy_params['fband'])
        
        # Colapsando la información
        to_append_mean = np.concatenate((mfcc_features.mean(axis=1),
                                         lfcc_features.mean(axis=1),
                                         20 * np.log10(energy_S.mean(axis=1))), axis=0)
        to_append_max = np.concatenate((mfcc_features.max(axis=1),
                                        lfcc_features.max(axis=1),
                                        20 * np.log10(energy_S.max(axis=1))), axis=0)
        
        # Agregando la información a cada arreglo
        X_data_mean.append(to_append_mean)
        X_data_max.append(to_append_max)
        
        Y_crackl.append(resp_info[1])
        Y_wheeze.append(resp_info[2])


# Transformando listas a arrays
X_data_mean = np.array(X_data_mean)
X_data_max = np.array(X_data_max)

Y_wheeze = np.array(Y_wheeze)
Y_crackl = np.array(Y_crackl)
# Out:
# Iteración 1: 101_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 2: 101_1b1_Pr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 3: 102_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 4: 103_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 5: 104_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (63424,)
# Iteración 6: 104_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (102336,)
# Iteración 7: 104_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (73920,)
# Iteración 8: 104_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (60096,)
# Iteración 9: 104_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (91840,)
# Iteración 10: 104_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (94912,)
# Iteración 11: 106_2b1_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 12: 106_2b1_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 13: 107_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 14: 107_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 15: 107_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 16: 107_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 17: 107_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 18: 107_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 19: 107_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 20: 107_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 21: 107_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 22: 107_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 23: 107_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 24: 107_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 25: 107_2b5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 26: 107_2b5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 27: 107_2b5_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 28: 107_2b5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 29: 107_2b5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 30: 107_2b5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 31: 107_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 32: 107_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 33: 107_3p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 34: 107_3p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 35: 107_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 36: 107_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 37: 108_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 38: 109_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (81344,)
# Iteración 39: 109_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (79808,)
# Iteración 40: 109_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (67776,)
# Iteración 41: 109_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (69824,)
# Iteración 42: 109_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (70592,)
# Iteración 43: 109_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# Iteración 44: 110_1b1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (285800,)
# Iteración 45: 110_1p1_Al_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (129200,)
# Iteración 46: 110_1p1_Ll_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (129600,)
# Iteración 47: 110_1p1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (129600,)
# Iteración 48: 110_1p1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (301000,)
# Iteración 49: 112_1b1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (271400,)
# Iteración 50: 112_1b1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (134400,)
# Iteración 51: 112_1p1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (117440,)
# Iteración 52: 112_1p1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# Iteración 53: 112_1p1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# Iteración 54: 113_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# Iteración 55: 113_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (62912,)
# Iteración 56: 113_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (83392,)
# Iteración 57: 113_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# Iteración 58: 113_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (78528,)
# Iteración 59: 113_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (87744,)
# Iteración 60: 114_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 61: 114_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 62: 114_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 63: 114_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 64: 114_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 65: 115_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 66: 116_1b2_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 67: 118_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (61888,)
# Iteración 68: 118_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (73408,)
# Iteración 69: 118_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (50112,)
# Iteración 70: 118_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (80320,)
# Iteración 71: 118_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (49856,)
# Iteración 72: 118_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (49856,)
# Iteración 73: 119_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 74: 120_1b1_Al_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (267000,)
# Iteración 75: 120_1b1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (267000,)
# Iteración 76: 120_1b1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (344800,)
# Iteración 77: 120_1b1_Pl_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (269600,)
# Iteración 78: 120_1b1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (269600,)
# Iteración 79: 122_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 80: 122_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 81: 122_2b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 82: 122_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 83: 122_2b3_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 84: 122_2b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 85: 123_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 86: 124_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (50112,)
# Iteración 87: 124_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (44992,)
# Iteración 88: 124_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (72896,)
# Iteración 89: 124_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (69056,)
# Iteración 90: 124_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (38336,)
# Iteración 91: 124_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (31424,)
# Iteración 92: 126_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 93: 127_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88068,)
# Iteración 94: 129_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 95: 130_1p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 96: 130_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 97: 130_1p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 98: 130_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 99: 130_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 100: 130_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 101: 130_1p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 102: 130_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 103: 130_1p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 104: 130_1p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 105: 130_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 106: 130_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 107: 130_1p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 108: 130_1p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 109: 130_1p4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 110: 130_1p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 111: 130_1p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 112: 130_1p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 113: 130_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 114: 130_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 115: 130_2b2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 116: 130_2b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 117: 130_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 118: 130_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 119: 130_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 120: 130_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 121: 130_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 122: 130_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 123: 130_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 124: 130_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 125: 130_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 126: 130_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 127: 130_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 128: 130_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 129: 130_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 130: 130_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 131: 130_2p5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 132: 130_2p5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 133: 130_2p5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 134: 130_2p5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 135: 130_2p5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 136: 130_3b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 137: 130_3b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 138: 130_3b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 139: 130_3b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 140: 130_3b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 141: 130_3b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 142: 130_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 143: 130_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 144: 130_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 145: 130_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 146: 130_3p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 147: 130_3p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 148: 130_3p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 149: 130_3p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 150: 130_3p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 151: 130_3p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 152: 131_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 153: 132_2b1_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 154: 132_2b2_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 155: 133_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 156: 133_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 157: 133_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 158: 133_2p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 159: 133_2p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 160: 133_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 161: 133_2p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 162: 133_2p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 163: 133_2p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 164: 133_2p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 165: 133_2p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 166: 133_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 167: 133_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 168: 133_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 169: 133_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 170: 134_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 171: 134_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 172: 134_2b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 173: 134_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 174: 134_2b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 175: 135_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 176: 135_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 177: 135_2b1_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 178: 135_2b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 179: 135_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 180: 135_2b2_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 181: 135_2b3_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 182: 135_2b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 183: 135_2b3_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 184: 135_2b3_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 185: 136_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 186: 137_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 187: 137_1b1_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 188: 138_1p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 189: 138_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 190: 138_1p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 191: 138_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 192: 138_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 193: 138_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 194: 138_1p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 195: 138_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 196: 138_1p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 197: 138_1p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 198: 138_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 199: 138_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 200: 138_1p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 201: 138_1p4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 202: 138_1p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 203: 138_1p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 204: 138_1p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 205: 138_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 206: 138_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 207: 138_2p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 208: 138_2p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 209: 138_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 210: 138_2p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 211: 139_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (78528,)
# Iteración 212: 139_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (67776,)
# Iteración 213: 139_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (83392,)
# Iteración 214: 139_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# Iteración 215: 139_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# Iteración 216: 139_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (64960,)
# Iteración 217: 140_2b2_Ll_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 218: 140_2b3_Ll_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 219: 141_1b1_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 220: 141_1b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 221: 141_1b2_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 222: 141_1b2_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 223: 141_1b3_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 224: 141_1b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 225: 141_1b3_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 226: 142_1b1_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 227: 143_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 228: 144_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88112,)
# Iteración 229: 145_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 230: 145_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 231: 145_2b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 232: 145_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 233: 145_3b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 234: 145_3b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 235: 145_3b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 236: 146_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 237: 146_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 238: 146_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 239: 146_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 240: 146_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 241: 146_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 242: 146_8p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 243: 146_8p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 244: 146_8p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 245: 146_8p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 246: 146_8p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 247: 147_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 248: 147_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 249: 147_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 250: 147_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 251: 147_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 252: 147_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 253: 147_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 254: 147_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 255: 147_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 256: 147_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 257: 147_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 258: 147_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 259: 147_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 260: 148_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 261: 149_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 262: 149_1b1_Lr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 263: 149_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 264: 150_1b2_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 265: 151_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 266: 151_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 267: 151_2p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 268: 151_2p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 269: 151_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 270: 151_2p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 271: 151_2p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 272: 151_2p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 273: 151_2p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 274: 151_2p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 275: 151_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 276: 151_2p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 277: 151_2p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 278: 151_2p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 279: 151_2p4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 280: 151_2p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 281: 151_2p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 282: 151_2p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 283: 151_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 284: 151_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 285: 151_3p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 286: 151_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 287: 151_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 288: 151_3p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 289: 152_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 290: 153_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 291: 154_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 292: 154_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 293: 154_1b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 294: 154_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 295: 154_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 296: 154_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 297: 154_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 298: 154_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 299: 154_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 300: 154_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 301: 154_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 302: 154_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 303: 154_3b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 304: 154_3b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 305: 154_3b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 306: 154_4b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 307: 154_4b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 308: 154_4b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 309: 154_4b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 310: 154_4b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 311: 154_4b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 312: 155_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 313: 156_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 314: 156_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 315: 156_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 316: 156_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 317: 156_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 318: 156_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 319: 156_5b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 320: 156_5b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 321: 156_5b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 322: 156_5b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 323: 156_5b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 324: 156_5b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 325: 156_8b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 326: 156_8b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 327: 156_8b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 328: 156_8b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# Iteración 329: 156_8b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-ba8d6cf00bef> in <module>
#      43
#      44     # Normalizando
# ---> 45     resp_signal = resp_signal / max(abs(resp_signal))
#      46
#      47
#
# KeyboardInterrupt:

# %% [markdown]
# # Stratify

# %%
# Definición de los grupos de pacientes
patient_groups = {1: ['101', '102', '103', '104', '106', '107', '108', '112', '114', 
                      '120', '123', '134', '165'],
                  2: ['109', '119', '126', '129', '130', '131', '132', '137', '144', 
                      '148','197'],
                  3: ['110', '115', '133', '135', '140', '141', '167', '181', '207', 
                      '226', '162'],
                  4: ['143', '145', '146', '147', '149', '150', '151', '152', '153', 
                      '159', '166', '179', '214'],
                  5: ['113', '136', '142', '154', '156', '160', '161', '175', '185', 
                      '225', '169'],
                  6: ['155', '158', '163', '164', '168', '170', '171', '183', '216', 
                      '221', '218'],
                  7: ['122', '172', '173', '174', '176', '177', '180', '189', '191', 
                      '195', '196'],
                  8: ['178', '184', '186', '187', '188', '192', '194', '202', '208', 
                      '204', '222', '223'],
                  9: ['116', '124', '139', '193', '198', '199', '200', '201', '203', 
                      '224'],
                  10: ['118', '127', '138', '157', '205', '206', '210', '211', '213', 
                       '215', '219', '220']}

# Definición de variables de control
segment_count = 0
patients_reviewed = list()

for i in patient_groups.keys():
    segments_by_group = 0
    
    for j in patient_groups[i]:
        # Sumando al contador de grupo
        segments_by_group += len(patient_register[j])
        
    # Agregando a la lista de pacientes totales
    patients_reviewed.extend(patient_groups[i])
    
    # Sumando al contador total 
    segment_count += segments_by_group
    
    # Print de sanidad
    print(f'Grupo {i}: {segments_by_group}')

print(f'Definidos {segment_count} de {Y_wheeze.shape[0]}')
# Out:
# Grupo 1: 597
# Grupo 2: 597
# Grupo 3: 597
# Grupo 4: 600
# Grupo 5: 595
# Grupo 6: 599
# Grupo 7: 600
# Grupo 8: 598
# Grupo 9: 596
# Grupo 10: 600
# Definidos 5979 de 5979

# %%
Y_complete = np.zeros(len(Y_wheeze))

for i in range(len(Y_wheeze)):
    if Y_crackl[i] == 0 and Y_wheeze[i] == 0:
        Y_complete[i] = 0
    elif Y_crackl[i] == 0 and Y_wheeze[i] == 1:
        Y_complete[i] = 1
    elif Y_crackl[i] == 1 and Y_wheeze[i] == 0:
        Y_complete[i] = 2
    elif Y_crackl[i] == 1 and Y_wheeze[i] == 1:
        Y_complete[i] = 3

# %%
Y_complete = Y_complete.astype(int)
print(Y_complete.dtype)
# Out:
# int32

# %% [markdown]
# # Diseño del sistema de clasificación

# %%
def ML_classification_system(X_train, Y_train, X_test, Y_test, 
                             clean_params=None, sel_params=None, 
                             class_params=None):
    '''Diseño del sistema de clasificación basado en Machine 
    Learning.
    
    Parameters
    ----------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        'tol': 13-5, 'show': True. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        'n_features': 10, 'show': True. Por defecto es None.
    class_params: dict or None, optional
        Parámetros del proceso de clasificación. Si es None se 
        utilizan características por defecto: 
        'classifier': 'knn', 'k_neigh': 10. Por defecto es None. 
        En caso de usar 'svm', es posible modificar el 'kernel'.
        
    Returns
    -------
    classifier : class
        Clasificador entrenado.
    X_test : ndarray
        Matriz de testeo modificada (en caso de que X_test no 
        sea None).
    params_out : dict
        Parámetros obtenidos a partir del entrenamiento del
        sistema sobre los datos. Se entrega información de las
        características del clean ('s_clean'), normalización
        ('a_norm' y 'b_norm'), y de la selección de 
        características ('s_sfs').
    Y_pred : ndarray or None
        Predicción realizada por el sistema (en caso de que
        Y_test no sea None). Si no se entrega Y_test, la salida
        será None.
    '''
    # Parámetros por defecto
    if clean_params is None:
        clean_params = {'tol': 1e-5, 'show': True}
    
    if sel_params is None:
        sel_params = {'n_features': 10, 'show': True}
    
    if class_params is None:
        class_params = {'classifier': 'knn', 'k_neigh': 10}
        
    Y_pred = None
    
    
    #### Pipeline de la etapa de clasificación ####
    
    ## 1) Limpieza de las características
    s_clean = pybalu_clean(X_train, tol=clean_params['tol'], 
                           show=clean_params['show'])
    
    # Aplicando la limpieza
    X_train = X_train[:, s_clean]
    
    
    ## 2) Normalización de los datos
    X_train, a_norm, b_norm = normalize(X_train)
    
    
    ## 3) Selección de características
    s_sfs = sfs(X_train, Y_train, show=sel_params['show'],
                n_features=sel_params['n_features'])
    
    # Aplicando la selección
    X_train = X_train[:, s_sfs]
    
    
    ## 4) Proceso de clasificación   
    if class_params['classifier'] == 'knn':
        classifier = KNeighborsClassifier(n_neighbors=\
                                          class_params['k_neigh'])
        
    elif class_params['classifier'] == 'svm':
        classifier = svm.SVC(kernel=class_params['kernel'])
    
    else:
        raise Exception('Opción de clasificador no definida '
                        'correctamente.')
    
    # Ajustando el clasificador
    classifier.fit(X_train, Y_train)
    
    
    # Aplicando todo el proceso a los datos de testeo
    if X_test is not None:
        X_test = X_test[:, s_clean]         # 1) Clean
        X_test = a_norm * X_test + b_norm   # 2) Normalización
        X_test = X_test[:, s_sfs]           # 3) Selección
        
        # Aplicando el clasificador
        if Y_test is not None:
            Y_pred = classifier.predict(X_test)

    
    # Definición del diccionario de parámetros
    params_out = {'a_norm': a_norm, 'b_norm': b_norm, 's_clean': s_clean,
                  's_sfs': s_sfs}
        
    return classifier, X_test, params_out, Y_pred


def NN_MLP_classification_system(X_train, Y_train, X_test, Y_test, 
                                 clean_params=None, sel_params=None, 
                                 mlp_params=None):
    '''Diseño del sistema de clasificación basado en Redes Neuronales
    Multicapas.
    
    Parameters
    ----------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        {'tol': 13-5, 'show': True}. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        {'n_features': 10, 'show': True}. Por defecto es None.
    mlp_params : dict or None, optional
        Parámetros del preoceso de clasificación con MLP. Si es
        None se utilizan las características por defecto:
        {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
         'batch_size': None, 'epochs': 100, 'verbose': 1, 
         'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                      tf.keras.metrics.Precision()],
         'out_layer': 'sigmoid', 'preprocessing': True}
        
    Returns
    -------
    classifier : class
        Clasificador entrenado.
    X_test : ndarray
        Matriz de testeo modificada (en caso de que X_test no 
        sea None).
    params_out : dict
        Parámetros obtenidos a partir del entrenamiento del
        sistema sobre los datos. Se entrega información de las
        características del clean ('s_clean'), normalización
        ('a_norm' y 'b_norm'), y de la selección de 
        características ('s_sfs').
    Y_pred : ndarray or None
        Predicción realizada por el sistema (en caso de que
        Y_test no sea None). Si no se entrega Y_test, la salida
        será None.
    '''
    # Parámetros por defecto
    if clean_params is None:
        clean_params = {'tol': 1e-5, 'show': True}
    
    if sel_params is None:
        sel_params = {'n_features': 10, 'show': True}
        
    if mlp_params is None:
        mlp_params = {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
                      'batch_size': None, 'epochs': 100, 'verbose': 1, 
                      'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                                  tf.keras.metrics.Precision()],
                      'out_layer': 'sigmoid', 'preprocessing': True}
    
    Y_pred = None
    
    
    #### Pipeline de la etapa de clasificación ####
    
    # Rutina de preprocesamiento
    if mlp_params['preprocessing']:
        ## 1) Limpieza de las características
        s_clean = pybalu_clean(X_train, tol=clean_params['tol'], 
                               show=clean_params['show'])

        # Aplicando la limpieza
        X_train = X_train[:, s_clean]


        ## 2) Normalización de los datos
        X_train, a_norm, b_norm = normalize(X_train)


        ## 3) Selección de características
        s_sfs = sfs(X_train, Y_train, show=sel_params['show'],
                    n_features=sel_params['n_features'])

        # Aplicando la selección
        X_train = X_train[:, s_sfs]

    
    
    ## 4) Proceso de clasificación
    
    # Definición del modelo
    model = MLP_network(input_shape=(X_train.shape[1],),
                        out_layer=mlp_params['out_layer'])
    
    # Compilando modelos
    model.compile(optimizer=mlp_params['optimizer'], 
                  loss=mlp_params['loss'],
                  metrics=mlp_params['metrics'])
    
    
    # Definición de los vectores
    if mlp_params['out_layer'] == 'softmax':
        # One-Hot
        Y_train_to = \
            np.array([Y_train, np.ones(len(Y_train)) - Y_train]).T
    
    elif mlp_params['out_layer'] == 'sigmoid':
        # Normal
        Y_train_to = Y_train
    
    
    # Ajustando el Modelo
    history = model.fit(x=X_train, y=Y_train_to, 
                        batch_size=mlp_params['batch_size'],
                        epochs=mlp_params['epochs'],
                        verbose=mlp_params['verbose'])
    
    
    # Aplicando todo el proceso a los datos de testeo
    if X_test is not None:
        # Si se realizó el preprocesamiento, se actualiza
        if preprocessing:
            X_test = X_test[:, s_clean]         # 1) Clean
            X_test = X_test * a_norm + b_norm   # 2) Normalización
            X_test = X_test[:, s_sfs]           # 3) Selección
        
        # Aplicando el clasificador
        if Y_test is not None:
            Y_pred = model.predict(X_test)

    
    # Definición del diccionario de parámetros
    params_out = {'a_norm': a_norm, 'b_norm': b_norm, 's_clean': s_clean,
                  's_sfs': s_sfs, 'history': history}
        
    return model, X_test, params_out, Y_pred


def MLP_network_OLD(input_shape, out_layer='sigmoid'):
    '''Función que define una red de perceptrones multicapas para 
    clasificar.
    
    Parameters
    ----------
    input_shape : list or ndarray
        Dimensión de la información de entrada.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    
    def _layer(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    
    # Definición de la red misma
    x_layer = _layer(x_in, units=500, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_1')
    x_layer = _layer(x_layer, units=200, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_2')
    x_layer = _layer(x_layer, units=100, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_3')
    x_layer = _layer(x_layer, units=80, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_4')
    x_layer = _layer(x_layer, units=30, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_5')
    x_layer = _layer(x_layer, units=10, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_6')
    x_layer = _layer(x_layer, units=5, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_7')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_MLP')
    
    return model


def MLP_network(input_shape, out_layer='sigmoid'):
    '''Función que define una red de perceptrones multicapas para 
    clasificar.
    
    Parameters
    ----------
    input_shape : list or ndarray
        Dimensión de la información de entrada.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    
    def _layer(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    
    # Definición de la red misma
    x_layer = _layer(x_in, units=40, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_1')
    x_layer = _layer(x_layer, units=30, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_2')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_MLP')
    
    return model


def CNN_network_OLD(input_shape, padding_value, out_layer='sigmoid'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling1D(pool_size=2, strides=2, 
                                             padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    # Definición de la capa de máscara
    x_masked = tf.keras.layers.Masking(mask_value=padding_value)(x_in)
                                             
    # Definición de la CNN
    layer_params_1 = {'filters': 50, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_masked, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 30, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 10, 'kernel_size': 25, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=3, layer_params=layer_params_3)
                                             
    layer_params_4 = {'filters': 7, 'kernel_size': 13, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_4'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=3, layer_params=layer_params_4)
                      
    
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.Flatten()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=500, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    x_layer = _mlp_layers(x_layer, units=200, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_2')
    x_layer = _mlp_layers(x_layer, units=100, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_3')
    x_layer = _mlp_layers(x_layer, units=80, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_4')
    x_layer = _mlp_layers(x_layer, units=30, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_5')
    x_layer = _mlp_layers(x_layer, units=10, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_6')
    x_layer = _mlp_layers(x_layer, units=5, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_7')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def CNN_network(input_shape, padding_value, out_layer='sigmoid'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling1D(pool_size=2, strides=2, 
                                             padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
                                             
    # Definición de la CNN
    layer_params_1 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_in, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_3)
                                             
    layer_params_4 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_4'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_4)
                      
    layer_params_5 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_5'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_5)
                                             
    layer_params_6 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_6'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_6)
    
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.Flatten()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=40, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def CNN_network_2(input_shape, padding_value, out_layer='sigmoid'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling1D(pool_size=2, strides=2, 
                                             padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    # Definición de la CNN
    layer_params_1 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_in, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_3)
                                             
    layer_params_4 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_4'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_4)
                      
    layer_params_5 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_5'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_5)
                                             
    layer_params_6 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_6'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_6)
    
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.GlobalMaxPool1D()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=40, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def CNN_network_2D(input_shape, padding_value, out_layer='softmax'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'softmax'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    # Definición de la capa de máscara
    x_masked = tf.keras.layers.Masking(mask_value=padding_value)(x_in)
                                             
    # Definición de la CNN
    layer_params_1 = {'filters': 15, 'kernel_size': (5,5), 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_masked, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 15, 'kernel_size': (4,4), 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 15, 'kernel_size': (3,3), 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_3)
    
                                             
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.Flatten()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=40, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def train_test_definition(X_data, Y_data, index_test, patient_groups,
                          patient_register, kfold=10):
    '''Función que permite retornar los conjuntos de entrenamiento
    y testeo en base a la división de la base de datos realizada 
    previamente para hacer una validación cruzada.
    
    Parameters
    ----------
    X_data : ndarray
        Matriz de características.
    Y_data : ndarray
        Etiquetas de la matriz de características.
    index_test : int
        Índice del grupo de testeo en la validación cruzada.
    patient_gropus : dict
        Diccionario que contiene los pacientes que corresponden
        a cada grupo de la validación cruzada.
    patient_register : dict
        Diccionario que contiene las entradas de cada paciente
        en la matriz de características.
    kfold : int, optional
        k de la validación cruzada que se realiza. Por defecto 
        es 10.
    
    Returns
    -------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    '''
    # Definición de los pacientes de testeo 
    test_patients = patient_groups[index_test]
    
    # Y entrenamiento
    train_patients = list()
    for i in range(1, kfold + 1):
        if i != index_test:
            train_patients.extend(patient_groups[i])
            
    # Definición de las entradas de entrenamiento y testeo
    train_indexes = list()
    test_indexes = list()
    
    for i in train_patients:
        train_indexes.extend(patient_register[str(i)])
    
    for i in test_patients:
        test_indexes.extend(patient_register[str(i)])

    # Aplicando los indices sobre los datos
    X_train = X_data[train_indexes]
    Y_train = Y_data[train_indexes]
    X_test  = X_data[test_indexes]
    Y_test  = Y_data[test_indexes]
    
    return X_train, Y_train, X_test, Y_test
    
    
def crossval_results(X_data, Y_data, experiment_type='ML', clean_params=None, 
                     sel_params=None, class_params=None, mlp_params=None,
                     kfold=10):
    '''Función que permite calcular el desempeño del clasificador
    mediante una validación cruzada de los datos.
    
    Parameters
    ----------
    X_data : ndarray
        Matriz de características.
    Y_data : ndarray
        Etiquetas de la matriz de características.
    experiment_type : {'ML', 'NN-MLP' 'CNN'}, optional
        Tipo de sistema a estudiar. 'ML' corresponde a un diseño
        estilo Machine-Learning (Rec. de Patrones). 'NN-MLP'
        corresponde a un diseño que utiliza como salida un 
        clasificador de perceptrones multicapas. 'CNN' es un
        diseño que utiliza una CNN con arquitectura clásica
        (AlexNet o VGG-16) para clasificar cada segmento.
        Por defecto es 'ML'.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        'tol': 13-5, 'show': True. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        'n_features': 10, 'show': True. Por defecto es None.
    class_params: dict or None, optional
        Parámetros del proceso de clasificación. Si es None se 
        utilizan características por defecto: 
        'classifier': 'knn', 'k_neigh': 10. Por defecto es None. 
        En caso de usar 'svm', es posible modificar el 'kernel'.
    mlp_params : dict or None, optional
        Parámetros del preoceso de clasificación con MLP. Si es
        None se utilizan las características por defecto:
        {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
         'batch_size': None, 'epochs': 100, 'verbose': 1, 
         'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                      tf.keras.metrics.Precision()],
         'out_layer': 'sigmoid', 'preprocessing': True}
    kfold : int, optional
        k de las repeticiones de la validación cruzada k-fold.
        Por defecto es 10.
    
    Returns
    -------
    confmat_list: list
        Lista de las matrices de confusión para cada iteración.
    accuracy_list : list
        Lista de las accuracys para cada iteración.
    '''
    # Definición de la lista de matrices de confusión
    confmat_list = list()
    
    # Iteraciónes del k-fold cross validation
    for index in range(1, kfold + 1):
        # Definición de la base de datos
        X_train, Y_train, X_test, Y_test = \
            train_test_definition(X_data, Y_data, index_test=index, 
                                  patient_groups=patient_groups,
                                  patient_register=patient_register)

        # Aplicando el clasificador
        if experiment_type == 'ML':
            classifier, X_test, params_out, Y_pred = \
                    ML_classification_system(X_train, Y_train, X_test, Y_test, 
                                             clean_params=clean_params, 
                                             sel_params=sel_params, 
                                             class_params=class_params)
            
        elif experiment_type == 'NN-MLP':
            model, X_test, params_out, Y_pred = \
                NN_MLP_classification_system(X_train, Y_train, X_test, Y_test, 
                                             clean_params=clean_params, 
                                             sel_params=sel_params, 
                                             mlp_params=mlp_params)
            
            # Modificar el Y_pred
            Y_pred = np.where(Y_pred < 0.5, 0, 1)[:, 0]

        elif experiment_type == 'CNN':
            pass
    
        else:
            raise Exception('Opción no válida para "experiment_type".')
    
        # Obteniendo la matriz de confusión
        conf_mat = confusion_matrix(Y_pred, Y_test)
        
        # Agregando a la lista
        confmat_list.append(conf_mat)
    
    # Cálculo de los resultados finales
    accuracy_list = list()
    
    for cmat in confmat_list:
        accuracy_i = np.sum(np.diag(cmat)) / np.sum(cmat)
        accuracy_list.append(accuracy_i)
        
    print(f'Accuracy {kfold}-fold CV: {np.mean(accuracy_list)} +- '
          f'{np.std(accuracy_list)}')
    
    return confmat_list, accuracy_list

# %%
# Parámetros generales
clean_params = {'tol': 1e-5, 'show': True}
sel_params = {'n_features': 60, 'show': True}

# %% [markdown]
# # kNN

# %%
class_params = {'classifier': 'knn', 'k_neigh': 3}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.28 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.29 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.26 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.38 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.38 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.26 features/s]
# Accuracy 10-fold CV: 0.7387033842769613 +- 0.06189357848326816
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.41 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.47 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.40 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.46 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.52 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.46 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.51 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.53 features/s]
# Accuracy 10-fold CV: 0.572222518197343 +- 0.054716716032860026
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.34 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.25 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:29<00:00, 2.06 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.22 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:28<00:00, 2.08 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.27 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.34 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.27 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Accuracy 10-fold CV: 0.7830178803175932 +- 0.06632339713684625
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.35 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.43 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.43 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.45 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.44 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.42 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.35 features/s]
# Accuracy 10-fold CV: 0.5805272107422775 +- 0.050036441302683574

# %%
class_params = {'classifier': 'knn', 'k_neigh': 3}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_complete, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_complete, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 122.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 11.6 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 9.79 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:07, 7.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:07, 7.11 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:08, 6.61 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 6.67 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.52 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.33 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:08, 6.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.13 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 5.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 5.81 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:08, 5.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:08, 5.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:08, 5.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:08, 5.16 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 4.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:08, 4.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.29 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:08, 3.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:05<00:09, 3.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:09, 3.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:09, 3.33 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:06<00:11, 2.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:11, 2.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:07<00:11, 2.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:11, 2.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:10, 2.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:08<00:10, 2.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:10, 2.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:09<00:09, 2.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:09, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:11<00:07, 2.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:12<00:07, 2.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:13<00:06, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:05, 2.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.16 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:04, 2.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 2.03 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:03, 2.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 2.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:20<00:00, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.90 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:04, 11.6 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 10.0 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.25 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.81 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 6.16 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 6.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:07, 5.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:07, 5.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:07, 5.54 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:08, 5.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 4.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:08, 4.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:09, 3.84 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:09, 3.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:05<00:10, 2.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:09, 2.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:07<00:10, 2.57 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:10, 2.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:08, 2.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.38 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.38 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:10<00:08, 2.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:08, 2.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.16 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:06, 2.09 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:05, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 1.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 1.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:18<00:02, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:19<00:01, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:20<00:00, 1.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.89 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:04, 11.8 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 10.1 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.58 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 6.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:01<00:07, 6.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:07, 6.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:07, 6.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:07, 5.79 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:07, 5.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:02<00:08, 5.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.69 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.56 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:03<00:08, 4.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:08, 3.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:09, 3.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.18 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:05<00:10, 3.09 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:06<00:09, 2.84 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.75 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:07<00:09, 2.60 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:09, 2.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:09, 2.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:09<00:08, 2.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:10<00:08, 2.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:05, 2.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:13<00:05, 2.16 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:14<00:04, 2.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 2.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:15<00:04, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 1.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 1.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:19<00:00, 1.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.96 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 11.4 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 9.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 8.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.79 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.81 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 6.12 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 6.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:07, 5.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:07, 5.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:07, 5.67 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:07, 5.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 4.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.76 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:03<00:08, 4.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:09, 3.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:09, 3.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:05<00:10, 2.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:09, 2.81 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:07<00:09, 2.61 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:09, 2.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:09, 2.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:10<00:08, 2.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:05, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:04, 2.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 2.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 1.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 1.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.84 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:19<00:00, 1.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.93 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:04, 12.2 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 10.3 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:05, 9.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.18 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.03 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.81 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 6.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 6.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:07, 6.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:07, 5.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:07, 5.74 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:07, 5.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 4.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.79 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:08, 4.12 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:09, 3.80 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:10, 3.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.18 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:05<00:10, 2.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:09, 2.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.74 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:07<00:09, 2.62 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:09, 2.54 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.52 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:09, 2.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:09<00:08, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:10<00:07, 2.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.29 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.25 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:05, 2.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.12 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:04, 2.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 2.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 1.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 1.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 1.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:19<00:00, 1.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.93 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 11.6 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 9.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.76 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 6.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:01<00:07, 6.25 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:07, 6.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:07, 6.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:07, 5.80 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:07, 5.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:02<00:08, 5.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.57 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:03<00:08, 4.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.31 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:08, 3.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:09, 3.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.16 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:05<00:10, 3.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 3.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:06<00:09, 2.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:10, 2.69 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:07<00:10, 2.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:10, 2.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:09, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:09<00:08, 2.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:10<00:08, 2.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:05, 2.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.13 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:05, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 1.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 1.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 1.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:19<00:00, 1.84 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.93 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 11.3 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 9.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.14 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.54 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 7.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.39 features/s]
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:24<00:01, 1.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:25<00:00, 1.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.28 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:06, 9.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:06, 8.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:07, 7.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:07, 6.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:08, 6.57 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:01<00:08, 6.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:08, 5.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:09, 5.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:09, 5.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:09, 5.18 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:02<00:09, 4.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:02<00:09, 4.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:09, 4.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:09, 4.76 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:09, 4.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:03<00:09, 4.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:03<00:10, 4.18 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:10, 3.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:04<00:10, 3.84 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:04<00:10, 3.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:04<00:10, 3.62 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:10, 3.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:05<00:10, 3.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:05<00:10, 3.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:06<00:11, 2.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:06<00:12, 2.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:06<00:12, 2.54 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:07<00:12, 2.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:07<00:12, 2.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:08<00:12, 2.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:08<00:12, 2.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:09<00:12, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:09<00:12, 2.03 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:10<00:12, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:10<00:12, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:11<00:12, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:11<00:11, 1.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:12<00:11, 1.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:13<00:10, 1.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:13<00:10, 1.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:14<00:10, 1.76 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:14<00:09, 1.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:15<00:09, 1.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:16<00:08, 1.69 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:16<00:08, 1.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:17<00:07, 1.68 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:17<00:07, 1.67 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:18<00:06, 1.61 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:19<00:06, 1.52 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:19<00:06, 1.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:20<00:05, 1.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:21<00:04, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:22<00:04, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:22<00:03, 1.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:23<00:02, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:24<00:02, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:25<00:01, 1.38 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:25<00:00, 1.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.26 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:06, 9.66 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:06, 8.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:07, 7.61 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:07, 6.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:08, 6.60 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:01<00:08, 6.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:08, 6.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:09, 5.62 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:09, 5.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:09, 5.09 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:02<00:09, 5.03 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:02<00:09, 4.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:09, 4.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:09, 4.75 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:09, 4.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:03<00:09, 4.58 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:03<00:09, 4.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:10, 3.79 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:04<00:10, 3.72 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:04<00:10, 3.61 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:04<00:10, 3.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:11, 3.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:05<00:11, 3.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:05<00:11, 2.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:06<00:12, 2.76 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:06<00:12, 2.60 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:07<00:12, 2.52 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:07<00:12, 2.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:07<00:12, 2.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:08<00:12, 2.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:08<00:12, 2.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:09<00:12, 2.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:09<00:12, 2.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:10<00:12, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:10<00:12, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:11<00:11, 1.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:11<00:11, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:12<00:11, 1.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:13<00:10, 1.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:13<00:10, 1.78 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:14<00:10, 1.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:14<00:10, 1.69 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:15<00:09, 1.66 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:16<00:09, 1.66 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:16<00:08, 1.66 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:17<00:07, 1.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:18<00:07, 1.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:18<00:06, 1.58 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:19<00:06, 1.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:20<00:06, 1.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:20<00:05, 1.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:21<00:04, 1.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:22<00:04, 1.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:22<00:03, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:23<00:02, 1.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:24<00:02, 1.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:25<00:01, 1.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:26<00:00, 1.33 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.24 features/s]
# Accuracy 10-fold CV: 0.45221528710973324 +- 0.06520120754441792

# %% [markdown]
# # SVM

# %%
class_params = {'classifier': 'svm', 'kernel': 'poly'}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.41 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.39 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.31 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.40 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.43 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.27 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.30 features/s]
# Accuracy 10-fold CV: 0.7977224996719388 +- 0.07023547049904728
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.40 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.47 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.50 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.47 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.45 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.50 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Accuracy 10-fold CV: 0.6014071003621553 +- 0.09932738706666563
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.38 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:11<00:10, 1.83 features/s]

# %%
class_params = {'classifier': 'svm', 'kernel': 'poly'}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_complete, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_complete, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 122.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 11.3 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 9.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:07, 7.68 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.74 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.56 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.14 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 5.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 5.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:07, 5.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:07, 5.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:07, 5.74 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:07, 5.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 5.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.76 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.66 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:03<00:08, 4.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:09, 3.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:09, 3.75 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:09, 3.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:09, 3.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:09, 3.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:05<00:09, 3.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:09, 3.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:10, 2.66 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:11, 2.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:08<00:11, 2.31 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:10, 2.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:08, 2.52 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:11<00:08, 2.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:08, 2.09 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:12<00:08, 2.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:13<00:07, 2.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:06, 2.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:05, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:16<00:04, 1.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:17<00:03, 1.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:18<00:02, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:19<00:01, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:20<00:00, 1.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.88 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 11.5 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 9.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.11 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:07, 7.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:08, 6.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:08, 6.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:08, 5.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 5.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 5.77 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:08, 5.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:08, 5.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:08, 5.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:08, 4.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 4.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:09, 4.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.25 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:09, 4.09 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:09, 3.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:09, 3.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:05<00:10, 3.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:06<00:10, 2.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:09, 2.80 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:08<00:10, 2.54 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:10, 2.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:09, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.38 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:11<00:08, 2.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:08, 2.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:12<00:07, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:13<00:06, 2.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.13 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:14<00:06, 2.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:15<00:05, 2.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:05, 1.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:16<00:04, 1.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:17<00:03, 1.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:03, 1.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:18<00:02, 1.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:02, 1.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:19<00:01, 1.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:20<00:00, 1.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.85 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 11.5 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 10.0 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.78 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.18 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.68 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 6.11 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 6.12 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:07, 5.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:07, 6.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:07, 5.75 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:07, 5.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:02<00:08, 5.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.91 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.57 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:03<00:08, 4.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.38 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:08, 4.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:09, 3.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:09, 3.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:09, 3.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:05<00:10, 3.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:10, 2.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:06<00:09, 2.84 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.80 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:07<00:09, 2.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:09, 2.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:08, 2.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:09<00:08, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:10<00:08, 2.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.22 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:05, 2.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:13<00:05, 2.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:14<00:04, 2.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 2.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:15<00:03, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 2.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:16<00:03, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:17<00:02, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 1.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:19<00:00, 1.66 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.93 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:04, 11.7 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 10.0 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.25 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 7.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:07, 7.56 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 6.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:08, 6.13 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:08, 6.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.13 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:07, 6.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 5.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:08, 5.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:08, 5.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:08, 5.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:02<00:08, 5.10 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 4.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:03<00:08, 4.43 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:08, 4.29 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:08, 4.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:04<00:09, 3.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:09, 3.31 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:06<00:10, 2.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.77 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:06<00:11, 2.62 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:10, 2.67 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:10, 2.62 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:08<00:10, 2.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:10, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:09, 2.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.38 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:11<00:07, 2.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.31 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:12<00:07, 2.13 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:07, 2.18 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:13<00:07, 2.13 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.03 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:14<00:06, 1.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:06, 1.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:15<00:05, 2.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:04, 2.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:16<00:04, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:17<00:03, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:02, 2.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:18<00:02, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:01, 2.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:19<00:01, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:00, 2.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:20<00:00, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.92 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:04, 11.7 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 10.0 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.33 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.36 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 7.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:08, 5.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:08, 5.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:01<00:08, 5.74 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:07, 5.80 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:08, 5.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:08, 4.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:08, 4.94 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:03<00:09, 4.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:09, 4.31 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:09, 4.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:09, 3.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:04<00:09, 3.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:10, 3.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:09, 3.72 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:09, 3.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:05<00:10, 3.27 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.11 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:06<00:10, 3.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:06<00:10, 3.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.85 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:07<00:10, 2.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:09, 2.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:08<00:09, 2.71 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:09, 2.67 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:09<00:09, 2.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.52 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:08, 2.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:11<00:07, 2.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:06, 2.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.33 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:06, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:06, 1.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:04, 2.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 2.01 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:04, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:02, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:01, 2.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 2.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.99 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:19<00:00, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.94 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:04, 11.6 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 9.78 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:07, 7.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:07, 6.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:08, 6.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:08, 5.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:08, 5.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:08, 5.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:09, 5.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:08, 5.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:02<00:08, 5.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:08, 5.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:08, 5.26 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:08, 5.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:02<00:08, 5.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:03<00:08, 5.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:08, 4.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:08, 4.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:03<00:08, 4.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:04<00:08, 4.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:09, 4.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:04<00:08, 4.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:04<00:09, 3.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:05<00:09, 3.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:05<00:10, 3.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:05<00:10, 3.11 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:06<00:10, 2.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:06<00:10, 2.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:07<00:10, 2.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:07<00:09, 2.86 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:07<00:09, 2.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:08<00:09, 2.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:08<00:09, 2.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:08<00:09, 2.63 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:09<00:09, 2.54 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:09<00:08, 2.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:10<00:08, 2.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:10<00:08, 2.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:11<00:07, 2.48 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:11<00:07, 2.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:11<00:07, 2.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:12<00:06, 2.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:12<00:06, 2.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:13<00:06, 2.31 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:13<00:05, 2.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:14<00:05, 2.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:14<00:05, 2.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:15<00:04, 2.08 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:15<00:04, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:16<00:03, 2.06 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:16<00:03, 2.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:17<00:02, 2.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:17<00:02, 2.03 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:18<00:01, 2.04 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:18<00:01, 2.03 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:19<00:01, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:19<00:00, 1.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.97 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:04, 11.8 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:05, 10.1 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:06, 9.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:06, 8.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:06, 7.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:00<00:07, 7.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:07, 7.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:07, 7.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:07, 6.89 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:07, 6.63 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:01<00:07, 6.50 features/s]
#
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:24<00:01, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:24<00:00, 1.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.34 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:08, 7.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:09, 5.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:10, 5.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:11, 4.93 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:01<00:11, 4.51 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:01<00:12, 4.17 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:12, 4.05 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:02<00:12, 3.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:02<00:12, 3.90 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:02<00:12, 3.78 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:02<00:12, 3.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:03<00:13, 3.61 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:03<00:12, 3.58 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:03<00:13, 3.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:04<00:13, 3.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:04<00:13, 3.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:04<00:13, 3.02 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:05<00:14, 2.79 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:05<00:15, 2.67 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:06<00:15, 2.52 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:06<00:15, 2.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:07<00:16, 2.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:07<00:16, 2.24 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:08<00:16, 2.07 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:08<00:18, 1.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:09<00:18, 1.77 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:10<00:18, 1.72 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:10<00:18, 1.69 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:11<00:18, 1.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:11<00:18, 1.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:12<00:17, 1.56 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:13<00:18, 1.50 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:14<00:18, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:14<00:17, 1.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:15<00:15, 1.56 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:16<00:15, 1.49 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:16<00:15, 1.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:17<00:15, 1.37 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:18<00:14, 1.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:19<00:14, 1.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:20<00:14, 1.25 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:20<00:14, 1.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:21<00:13, 1.20 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:22<00:12, 1.19 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:23<00:11, 1.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:24<00:09, 1.31 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:24<00:08, 1.35 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:25<00:08, 1.33 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:26<00:07, 1.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:27<00:07, 1.28 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:27<00:06, 1.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:28<00:05, 1.30 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:29<00:04, 1.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:30<00:03, 1.34 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:30<00:02, 1.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:31<00:02, 1.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:32<00:01, 1.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:33<00:00, 1.32 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:33<00:00, 1.77 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features:   0%|                                                           | 0.00/60.0 [00:00<?, ? features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   3%|█▋                                                  | 2.00/60.0 [00:00<00:05, 9.87 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   5%|██▌                                                 | 3.00/60.0 [00:00<00:06, 8.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   7%|███▍                                                | 4.00/60.0 [00:00<00:07, 7.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:   8%|████▎                                               | 5.00/60.0 [00:00<00:07, 6.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  10%|█████▏                                              | 6.00/60.0 [00:00<00:08, 6.53 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  12%|██████                                              | 7.00/60.0 [00:01<00:08, 6.12 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  13%|██████▉                                             | 8.00/60.0 [00:01<00:08, 5.95 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  15%|███████▊                                            | 9.00/60.0 [00:01<00:09, 5.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  17%|████████▋                                           | 10.0/60.0 [00:01<00:09, 5.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  18%|█████████▌                                          | 11.0/60.0 [00:01<00:09, 5.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  20%|██████████▍                                         | 12.0/60.0 [00:02<00:09, 5.15 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  22%|███████████▎                                        | 13.0/60.0 [00:02<00:09, 4.97 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  23%|████████████▏                                       | 14.0/60.0 [00:02<00:09, 5.00 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  25%|█████████████                                       | 15.0/60.0 [00:02<00:09, 4.88 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  27%|█████████████▊                                      | 16.0/60.0 [00:02<00:08, 4.92 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  28%|██████████████▋                                     | 17.0/60.0 [00:03<00:09, 4.77 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  30%|███████████████▌                                    | 18.0/60.0 [00:03<00:09, 4.44 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  32%|████████████████▍                                   | 19.0/60.0 [00:03<00:10, 3.96 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  33%|█████████████████▎                                  | 20.0/60.0 [00:03<00:10, 3.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  35%|██████████████████▏                                 | 21.0/60.0 [00:04<00:10, 3.67 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  37%|███████████████████                                 | 22.0/60.0 [00:04<00:10, 3.60 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  38%|███████████████████▉                                | 23.0/60.0 [00:04<00:10, 3.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  40%|████████████████████▊                               | 24.0/60.0 [00:05<00:10, 3.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  42%|█████████████████████▋                              | 25.0/60.0 [00:05<00:10, 3.23 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  43%|██████████████████████▌                             | 26.0/60.0 [00:06<00:12, 2.63 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  45%|███████████████████████▍                            | 27.0/60.0 [00:06<00:14, 2.21 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  47%|████████████████████████▎                           | 28.0/60.0 [00:07<00:16, 1.98 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  48%|█████████████████████████▏                          | 29.0/60.0 [00:07<00:16, 1.83 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  50%|██████████████████████████                          | 30.0/60.0 [00:08<00:16, 1.82 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  52%|██████████████████████████▊                         | 31.0/60.0 [00:09<00:17, 1.63 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  53%|███████████████████████████▋                        | 32.0/60.0 [00:09<00:16, 1.69 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  55%|████████████████████████████▌                       | 33.0/60.0 [00:10<00:15, 1.69 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  57%|█████████████████████████████▍                      | 34.0/60.0 [00:11<00:16, 1.58 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  58%|██████████████████████████████▎                     | 35.0/60.0 [00:11<00:15, 1.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  60%|███████████████████████████████▏                    | 36.0/60.0 [00:12<00:14, 1.61 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  62%|████████████████████████████████                    | 37.0/60.0 [00:12<00:13, 1.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  63%|████████████████████████████████▉                   | 38.0/60.0 [00:13<00:12, 1.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  65%|█████████████████████████████████▊                  | 39.0/60.0 [00:14<00:12, 1.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:14<00:11, 1.73 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  68%|███████████████████████████████████▌                | 41.0/60.0 [00:15<00:10, 1.76 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  70%|████████████████████████████████████▍               | 42.0/60.0 [00:15<00:10, 1.70 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  72%|█████████████████████████████████████▎              | 43.0/60.0 [00:16<00:10, 1.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  73%|██████████████████████████████████████▏             | 44.0/60.0 [00:17<00:09, 1.65 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  75%|███████████████████████████████████████             | 45.0/60.0 [00:17<00:09, 1.62 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  77%|███████████████████████████████████████▊            | 46.0/60.0 [00:18<00:08, 1.64 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  78%|████████████████████████████████████████▋           | 47.0/60.0 [00:18<00:08, 1.59 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  80%|█████████████████████████████████████████▌          | 48.0/60.0 [00:19<00:07, 1.60 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  82%|██████████████████████████████████████████▍         | 49.0/60.0 [00:20<00:06, 1.58 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  83%|███████████████████████████████████████████▎        | 50.0/60.0 [00:20<00:06, 1.55 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  85%|████████████████████████████████████████████▏       | 51.0/60.0 [00:21<00:06, 1.46 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  87%|█████████████████████████████████████████████       | 52.0/60.0 [00:22<00:05, 1.41 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  88%|█████████████████████████████████████████████▉      | 53.0/60.0 [00:23<00:04, 1.40 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  90%|██████████████████████████████████████████████▊     | 54.0/60.0 [00:23<00:04, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  92%|███████████████████████████████████████████████▋    | 55.0/60.0 [00:24<00:03, 1.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  93%|████████████████████████████████████████████████▌   | 56.0/60.0 [00:25<00:02, 1.45 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  95%|█████████████████████████████████████████████████▍  | 57.0/60.0 [00:25<00:02, 1.47 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  97%|██████████████████████████████████████████████████▎ | 58.0/60.0 [00:26<00:01, 1.42 features/s]
#
#
#
#
#
#
#
#
# Selecting Features:  98%|███████████████████████████████████████████████████▏| 59.0/60.0 [00:27<00:00, 1.39 features/s]
#
#
#
#
#
#
#
#
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:28<00:00, 2.14 features/s]
# Accuracy 10-fold CV: 0.47906065756004274 +- 0.13159659440963523

# %% [markdown]
# # Redes Neuronales MLP

# %%
preprocessing = True
mlp_params = {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
              'batch_size': None, 'epochs': 30, 'verbose': 0, 
              'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                          tf.keras.metrics.Precision()],
              'out_layer': 'sigmoid', 'preprocessing': True}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)
# Out:
# Clean: number of features reduced from 149 to 122.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.05 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.05 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.14 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.78 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.09 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.01 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:28<00:00, 2.09 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.62 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.69 features/s]
# Accuracy 10-fold CV: 0.7614519708020536 +- 0.05586195315613456
# Clean: number of features reduced from 149 to 122.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.26 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.95 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.15 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.07 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.17 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.10 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.12 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.23 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.99 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.18 features/s]
# Accuracy 10-fold CV: 0.5878765666011667 +- 0.060046022376537465
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.29 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.22 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.24 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.25 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.21 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:28<00:00, 2.12 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.20 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:29<00:00, 2.06 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.21 features/s]
# Accuracy 10-fold CV: 0.7791725087409809 +- 0.054885882735558486
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.30 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.23 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.44 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.42 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.30 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.31 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.31 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.42 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Accuracy 10-fold CV: 0.5803796909170138 +- 0.061762798859557225
