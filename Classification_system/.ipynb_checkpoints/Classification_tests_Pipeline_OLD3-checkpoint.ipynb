# %%
# Imports
import os, warnings
import librosa
import numpy as np
import tensorflow as tf
import soundfile as sf
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy import signal, fftpack
from collections import defaultdict
from testing_functions import test_hss
from process_functions import preprocessing_audio
from utils import find_and_open_audio, signal_segmentation, get_resp_segments
from heart_sound_segmentation.filter_and_sampling import downsampling_signal, \
    upsampling_signal
from source_separation.descriptor_functions import get_spectrogram
from IPython.display import Audio
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn import preprocessing, linear_model, svm
from sklearn.metrics import confusion_matrix, accuracy_score
from pybalu.feature_selection import sfs
from pybalu.feature_transformation import normalize

# %% [markdown]
# # Funciones previas

# %%
# Funciones de características
def get_filterbanks(N, samplerate, freq_lim, n_filters, norm_exp=1,
                    scale_type='mel', filter_type='triangular',
                    norm_filters=True, plot_filterbank=False):
    '''Función que permite obtener un banco de filtros linealmente
    espaciados o espaciados en frecuencia de mel para calcular
    coeficientes cepstrales.
    
    Parameters
    ----------
    N : ndarray
        Largo de la señal.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_filters : int
        Cantidad de filtros a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''
    def _freq_to_bin(f):
        # Definición del bin correspondiente en la definición
        # del intervalo de cálculo. Se usa (N - 1) ya que los bins
        # se definen entre 0 y (N - 1) (largo N)
        return np.rint(f / samplerate * (N - 1)).astype(int)
    
    
    def _triangular_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i] + 1] = \
                np.linspace(0, 1, abs(bins_points[i] - bins_points[i - 1] + 1))
            
            # Tramo descendente del filtro triangular
            filter_bank[i - 1][bins_points[i]:bins_points[i + 1] + 1] = \
                np.linspace(1, 0, abs(bins_points[i + 1] - bins_points[i] + 1))
            
        return filter_bank
    
    
    def _hanning_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i + 1] + 1] = \
                np.hanning(abs(bins_points[i + 1] - bins_points[i - 1] + 1))
        
        return filter_bank
    
    
    def _squared_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i + 1] + 1] = 1
        
        return filter_bank
    
    
    def _norm_filterbank(filter_bank):
        # Definición del banco de filtros de salida
        filter_bank_out = np.zeros((n_filters, N))
        
        # Normalizar los filtros a energía 1
        for i in range(n_filters):
            filter_bank_out[i] = filter_bank[i] / \
                                 sum(filter_bank[i] ** norm_exp)
            
        return filter_bank_out
    
    
    # Definición de los bines en base a las frecuencias de cada filtro
    if scale_type == 'linear':
        # Definición de las "n_filters" frecuencias equiespaciadas entre
        # 0 y freq_lim. Se le agregan 2 puntos (0 y el freq_lim) ya que se 
        # necesitan para definir los límites de los filtros.
        freqs = np.arange(0, (n_filters + 1) + 1) * freq_lim / (n_filters + 1)
    
    
    elif scale_type == 'mel':
        # Definición del límite en frecuencias de mel (para no pasarse del
        # freq_lim al devolverse)
        mel_freq_lim = 2595 * np.log10(1 + freq_lim / 700)
        
        # Definición de las "n_filters" frecuencias espaciadas en escala mel 
        # entre 0 y freq_lim. Se le agregan 2 puntos (0 y el freq_lim) ya 
        # que se necesitan para definir los límites de los filtros.
        mel_freqs = np.arange(0, (n_filters + 1) + 1) * mel_freq_lim / (n_filters + 1)
        
        # Transformando de intervalos equi espaciados usando la escala
        # de mel. Es necesario hacer la transformación inversa ya que
        # en este caso se dice que lo equi espaciado viene de mel
        freqs = 700 * (10 ** (mel_freqs / 2595) - 1)
    
    else:
        raise Exception('Opción de tipo de coeficiente cepstral no válido.')
    
    
    # Transformando a bins
    bins_to = _freq_to_bin(freqs)
    
    
    # Obtención del banco de filtros
    if filter_type == 'triangular':
        filter_bank = _triangular_filter(bins_to)
        
    if filter_type == 'hanning':
        filter_bank = _hanning_filter(bins_to)
    
    elif filter_type == 'squared':
        filter_bank = _squared_filter(bins_to)
    
    # Normalizar por la energía de la señal
    if norm_filters:
        filter_bank = _norm_filterbank(filter_bank)
    
    
    # Gráfico del banco de filtros
    if plot_filterbank:
        plt.figure()
        
        # Definición del vector de frecuencias
        f_plot = np.arange(N) * samplerate / N
        
        for i in range(n_filters):
            plt.plot(filter_bank[i])
            # plt.plot(f_plot, filter_bank[i])

        for i in bins_to:
            # plt.axvline(i * samplerate / N, c='silver', linestyle=':')
            plt.axvline(i, c='silver', linestyle=':')
            
        # plt.xlim([0, freq_lim])
        plt.xlim([0, bins_to[-1]])
        plt.show()
    
    
    return filter_bank


def get_cepstral_coefficients(signal_in, samplerate, spectrogram_params,
                              freq_lim, n_filters, n_coefs, scale_type='mel', 
                              filter_type='triangular', inverse_func='dct', 
                              norm_filters=True, plot_filterbank=False, 
                              power=2):
    '''Función que permite obtener los coeficientes cepstrales a partir de 
    un banco de filtros.
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_coefs : int
        Cantidad de coeficientes a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''    
    # Definición de la cantidad de puntos a considerar
    filter_bank = get_filterbanks(spectrogram_params['N'], samplerate, 
                                  freq_lim=freq_lim, n_filters=n_filters, 
                                  scale_type=scale_type, 
                                  filter_type=filter_type,
                                  norm_filters=norm_filters, 
                                  plot_filterbank=plot_filterbank)
    
    # Obtener el espectrograma de la señal
    t, f, S = get_spectrogram(signal_in, samplerate, N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=True)
    
    # Definición del espectro de la señal
    energy_spectrum = np.abs(S) ** power
    
    # Se aplica el banco de filtros sobre el espectro de la señal
    energy_coefs = np.dot(filter_bank, energy_spectrum)
    
    # Aplicando el logaritmo
    energy_coefs = np.log(energy_coefs + 1e-10)
    
    # Calculando los coeficientes cepstrales
    if inverse_func == 'dct':
        cepstral_coefs = fftpack.dct(energy_coefs, norm='ortho', axis=0)
    elif inverse_func == 'idft':
        cepstral_coefs = np.fft.ifft(energy_coefs, axis=-1).real
    else:
        raise Exception('Opción de tipo de función inversa no válida.')
    
    
    return cepstral_coefs[:n_coefs]


def get_bands_coefficients(signal_in, samplerate, spectrogram_params,
                           freq_lim, n_coefs, scale_type='mel', 
                           filter_type='triangular', norm_filters=True, 
                           plot_filterbank=False, 
                           power=2):
    '''Función que permite obtener la energía por bandas de frecuencia
    a partir de un banco de filtros.
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_coefs : int
        Cantidad de coeficientes a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''    
    # Definición de la cantidad de puntos a considerar
    filter_bank = get_filterbanks(spectrogram_params['N'], samplerate, 
                                  freq_lim=freq_lim, 
                                  n_coefs=n_coefs, scale_type=scale_type, 
                                  filter_type=filter_type,
                                  norm_filters=norm_filters, 
                                  plot_filterbank=plot_filterbank)
    
    # Obtener el espectrograma de la señal
    t, f, S = get_spectrogram(signal_in, samplerate, N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=True)
    
    # Definición del espectro de la señal
    energy_spectrum = np.abs(S) ** power
    
    # Se aplica el banco de filtros sobre el espectro de la señal
    energy_coefs = np.dot(filter_bank, energy_spectrum)
    
    return energy_coefs


def get_energy_bands(signal_in, samplerate, spectrogram_params, 
                     fmin=0, fmax=1000, fband=20, power=2):
    '''Función que permite definir un espectrograma en bandas de 
    energía.
    
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    spectrogram_params : dict
        Parámetros del espectrograma.
    fmin : float, optional
        Frecuencia mínima a considerar en el intervalo de interés.
        Por defecto es 0.
    fmax : float, optional
        Frecuencia máxima a considerar en el intervalo de interés.
        Este valor no puede mayor a samplerate / 2. Por defecto 
        es 1000.
    fband : float, optional
        Ancho de cada banda de frecuencia entre fmin y fmax. Por 
        defecto es 20.
    power : float, optional
        Exponente con el que se calcula la energía.
    
    Returns
    -------
    energy_S : ndarray
        Bandas de energía a través del tiempo (formato 
        espectrograma) con dimensión (#bandas x #bins de tiempo 
        del espectrograma).     
    '''
    # Obtener el espectrograma
    t, f, S = get_spectrogram(signal_in, samplerate, 
                              N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=False)
    
    # Definición de los intervalos
    f_intervals = np.arange(fmin, fmax, fband)

    # Definición de la lista que almacenará los datos
    energy_band = np.zeros(len(f_intervals) - 1)
    energy_S = np.zeros((len(energy_band), len(t)))

    for i in range(len(f_intervals) - 1):
        lower_lim = f_intervals[i]
        upper_lim = f_intervals[i + 1]

        # Definición de los índices de interés
        indexes = np.where((lower_lim <= f) & (f <= upper_lim))[0]

        # Definiendo el valor
        energy_S[i] = np.sum(abs(S[indexes,:]) ** power, axis=0)
    
    return energy_S

# %%
def _conditioning_signal(signal_in, samplerate, samplerate_to):
    # Acondicionando en caso de que no tenga samplerate de 1000 Hz.
    if samplerate < samplerate_to:
        print(f'Upsampling de la señal de fs = {samplerate} Hz '
              f'a fs = {samplerate_to} Hz.') 
        new_rate = samplerate_to           
        audio_to = upsampling_signal(signal_in, samplerate, new_samplerate=new_rate)

    elif samplerate > samplerate_to:
        print(f'Downsampling de la señal de fs = {samplerate} Hz '
              f'a fs = {samplerate_to} Hz.')
        new_rate, audio_to = downsampling_signal(signal_in, samplerate, 
                                                 freq_pass=samplerate_to//2-100, 
                                                 freq_stop=samplerate_to//2)

    else:
        print(f'Samplerate adecuado a fs = {samplerate} Hz.')
        audio_to = signal_in
        new_rate = samplerate_to

    # Mensaje para asegurar
    print(f'Señal acondicionada a {new_rate} Hz para la separación de fuentes.')

    # Asegurándose de que el largo de la señal sea par
    if len(audio_to) % 2 != 0:
        audio_to = np.concatenate((audio_to, [0]))

    return audio_to, new_rate

# %%
def pybalu_clean(features, tol=1e-8, show=False):
    n_features = features.shape[1]
    ip = np.ones(n_features, dtype=int)

    # cleaning correlated features
    warnings.filterwarnings('ignore')
    C = np.abs(np.corrcoef(features, rowvar=False))
    idxs = np.vstack(np.where(C > .99))
    
    # remove pairs of same feature ( feature i will have a correlation of 1 whit itself )
    idxs = idxs[:, idxs[0,:] != idxs[1,:]]
    
    # remove correlated features
    if idxs.size > 0:
        ip[np.max(idxs, 0)] = 0
    
    # remove constant features
    s = features.std(axis=0, ddof=1)
    ip[s < tol] = 0
    p = np.where(ip.astype(bool))[0]

    if show:
        print(f'Clean: number of features reduced from {n_features} to {p.size}.')

    return p

# %% [markdown]
# # Parámetros de los descriptores

# %%
# Parámetro base de datos
preprocess = True

# Parámetros de los espectrogramas generales
N = 1024
noverlap = int(0.9 * N)
spec_params = {'N': N, 'noverlap': noverlap, 'window': 'hann', 
               'padding': 0, 'repeat': 0}

# Parámetros MFCC
mfcc_params = {'n_mfcc': 50, 'n_filters': 50, 'spec_params': spec_params,
               'freq_lim': 2000, 'norm_filters': True, 'power': 2}
lfcc_params = {'n_mfcc': 50, 'n_filters': 50, 'spec_params': spec_params,
               'freq_lim': 2000, 'norm_filters': True, 'power': 2}
energy_params = {'spec_params': spec_params, 'fmin': 0, 'fmax': 1000, 
                 'fband': 20}

# Parámetros de extracción de características
collapse_mfcc = 'mean'
func_type = 'cepstral_coefficients'

# %%
# Dirección de la base de datos
db_original = 'C:/Users/Chris/Desktop/Scripts_Magister/Respiratory_Sound_Database/audio_and_txt_files'
db_folder = 'preprocessed_signals_OLD'

# Nombres de los archivos
filenames = [i[:-4] for i in os.listdir(db_folder) if i.endswith('.wav') and not 'Tc' in i]

# %% [markdown]
# # Extracción de características

# %%
# %matplotlib notebook

# Definición de los arrays donde se acumulará las características
X_data_mean = list()
X_data_max = list()
X_segments = list()

# Definición de los arrays donde se acumularán las etiquetas
Y_wheeze = list()
Y_crackl = list()

# Diccionario que indica los segmentos que corresponden a cada paciente
patient_register = defaultdict(list)

# Contador de los segmentos
seg_i = 0

# Nombre del archivo .wav a utilizar
for num, name in enumerate(filenames):
    print(f'Iteración {num + 1}: {name}')
    print(f'--------------------------')
    
    # Definición del paciente de interés
    patient = name.split('_')[0]
    
    if preprocess:
        filename = f'{db_folder}/{name}'
    else:
        filename = f'{db_original}/{name}'

    # Cargando el archivo
    try:
        samplerate, resp_signal = wavfile.read(f'{filename}.wav')
    except:
        resp_signal, samplerate = sf.read(f'{filename}.wav')
    
    print(f'Samplerate = {samplerate}, largo = {resp_signal.shape}')
    
    # Normalizando
    resp_signal = resp_signal / max(abs(resp_signal))
    
    
    # Obteniendo la información de los segmentos de este archivo de audio
    resp_list_info = get_resp_segments(resp_signal, samplerate, 
                                       filepath=f'{db_original}/{name}.txt')
    
    
    # Para cada segmento, se obtiene la información de interés
    for resp_info in resp_list_info:
        # Registrando
        patient_register[patient].append(seg_i)
        seg_i += 1
        
        # Agregando a la lista el segmento
        X_segments.append(resp_info[0])
        
        ### Calculando las características a partir del segmento ###
        
        # Cálculo del MFCC
        mfcc_features = \
            get_cepstral_coefficients(resp_info[0], samplerate, 
                                      spectrogram_params=mfcc_params['spec_params'],
                                      freq_lim=mfcc_params['freq_lim'], 
                                      n_filters=mfcc_params['n_filters'], 
                                      n_coefs=mfcc_params['n_mfcc'], 
                                      scale_type='mel', 
                                      filter_type='triangular', inverse_func='dct', 
                                      norm_filters=mfcc_params['norm_filters'], 
                                      plot_filterbank=False, 
                                      power=mfcc_params['power'])
                
        # Cálculo del LFCC
        lfcc_features = \
            get_cepstral_coefficients(resp_info[0], samplerate, 
                                      spectrogram_params=lfcc_params['spec_params'],
                                      freq_lim=lfcc_params['freq_lim'], 
                                      n_filters=lfcc_params['n_filters'], 
                                      n_coefs=lfcc_params['n_mfcc'], 
                                      scale_type='linear', 
                                      filter_type='triangular', inverse_func='dct', 
                                      norm_filters=lfcc_params['norm_filters'], 
                                      plot_filterbank=False, 
                                      power=lfcc_params['power'])
        
        # Cálculo de la energía por bandas
        energy_S = \
            get_energy_bands(resp_info[0], samplerate,
                             spectrogram_params=energy_params['spec_params'],
                             fmin=energy_params['fmin'], 
                             fmax=energy_params['fmax'], 
                             fband=energy_params['fband'])
        
        # Colapsando la información
        to_append_mean = np.concatenate((mfcc_features.mean(axis=1),
                                         lfcc_features.mean(axis=1),
                                         energy_S.mean(axis=1)), axis=0)
        to_append_max = np.concatenate((mfcc_features.max(axis=1),
                                        lfcc_features.max(axis=1),
                                        energy_S.max(axis=1)), axis=0)
        
        # Agregando la información a cada arreglo
        X_data_mean.append(to_append_mean)
        X_data_max.append(to_append_max)
        
        Y_wheeze.append(resp_info[1])
        Y_crackl.append(resp_info[2])


# Transformando listas a arrays
X_data_mean = np.array(X_data_mean)
X_data_max = np.array(X_data_max)

Y_wheeze = np.array(Y_wheeze)
Y_crackl = np.array(Y_crackl)
# Out:
# Iteración 1: 101_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 2: 101_1b1_Pr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 3: 102_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 4: 103_2b2_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 5: 106_2b1_Pl_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 6: 106_2b1_Pr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 7: 107_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 8: 107_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 9: 107_2b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 10: 107_2b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 11: 107_2b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 12: 107_2b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 13: 107_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 14: 107_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 15: 107_2b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 16: 107_2b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 17: 107_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 18: 107_2b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 19: 107_2b5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 20: 107_2b5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 21: 107_2b5_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 22: 107_2b5_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 23: 107_2b5_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 24: 107_2b5_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 25: 107_3p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 26: 107_3p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 27: 107_3p2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 28: 107_3p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 29: 107_3p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 30: 107_3p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 31: 108_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 32: 114_1b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 33: 114_1b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 34: 114_1b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 35: 114_1b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 36: 114_1b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 37: 115_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 38: 116_1b2_Pl_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 39: 119_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 40: 122_2b1_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 41: 122_2b1_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 42: 122_2b2_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 43: 122_2b2_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 44: 122_2b3_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 45: 122_2b3_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 46: 123_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 47: 126_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 48: 127_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80062,)
# Iteración 49: 129_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 50: 130_1p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 51: 130_1p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 52: 130_1p2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 53: 130_1p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 54: 130_1p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 55: 130_1p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 56: 130_1p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 57: 130_1p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 58: 130_1p3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 59: 130_1p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 60: 130_1p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 61: 130_1p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 62: 130_1p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 63: 130_1p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 64: 130_1p4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 65: 130_1p4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 66: 130_1p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 67: 130_1p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 68: 130_2b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 69: 130_2b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 70: 130_2b2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 71: 130_2b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 72: 130_2b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 73: 130_2b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 74: 130_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 75: 130_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 76: 130_2b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 77: 130_2b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 78: 130_2b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 79: 130_2b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 80: 130_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 81: 130_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 82: 130_2b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 83: 130_2b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 84: 130_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 85: 130_2p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 86: 130_2p5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 87: 130_2p5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 88: 130_2p5_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 89: 130_2p5_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 90: 130_2p5_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 91: 130_3b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 92: 130_3b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 93: 130_3b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 94: 130_3b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 95: 130_3b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 96: 130_3b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 97: 130_3p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 98: 130_3p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 99: 130_3p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 100: 130_3p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 101: 130_3p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 102: 130_3p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 103: 130_3p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 104: 130_3p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 105: 130_3p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 106: 130_3p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 107: 131_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 108: 132_2b1_Lr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 109: 132_2b2_Lr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 110: 133_2p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 111: 133_2p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 112: 133_2p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 113: 133_2p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 114: 133_2p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 115: 133_2p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 116: 133_2p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 117: 133_2p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 118: 133_2p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 119: 133_2p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 120: 133_2p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 121: 133_3p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 122: 133_3p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 123: 133_3p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 124: 133_3p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 125: 134_2b1_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 126: 134_2b1_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 127: 134_2b2_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 128: 134_2b2_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 129: 134_2b3_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 130: 135_2b1_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 131: 135_2b1_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 132: 135_2b1_Pl_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 133: 135_2b2_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 134: 135_2b2_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 135: 135_2b2_Pl_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 136: 135_2b3_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 137: 135_2b3_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 138: 135_2b3_Pl_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 139: 135_2b3_Pr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 140: 136_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 141: 137_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 142: 137_1b1_Ll_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 143: 138_1p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 144: 138_1p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 145: 138_1p2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 146: 138_1p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 147: 138_1p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 148: 138_1p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 149: 138_1p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 150: 138_1p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 151: 138_1p3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 152: 138_1p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 153: 138_1p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 154: 138_1p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 155: 138_1p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 156: 138_1p4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 157: 138_1p4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 158: 138_1p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 159: 138_1p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 160: 138_2p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 161: 138_2p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 162: 138_2p2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 163: 138_2p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 164: 138_2p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 165: 138_2p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 166: 140_2b2_Ll_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 167: 140_2b3_Ll_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 168: 141_1b1_Pr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 169: 141_1b2_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 170: 141_1b2_Lr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 171: 141_1b2_Pr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 172: 141_1b3_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 173: 141_1b3_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 174: 141_1b3_Pr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 175: 142_1b1_Pl_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 176: 143_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 177: 144_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80102,)
# Iteración 178: 145_2b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 179: 145_2b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 180: 145_2b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 181: 145_2b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 182: 145_3b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 183: 145_3b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 184: 145_3b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 185: 146_2b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 186: 146_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 187: 146_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 188: 146_2b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 189: 146_2b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 190: 146_2b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 191: 146_8p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 192: 146_8p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 193: 146_8p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 194: 146_8p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 195: 146_8p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 196: 147_2b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 197: 147_2b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 198: 147_2b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 199: 147_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 200: 147_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 201: 147_2b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 202: 147_2b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 203: 147_2b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 204: 147_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 205: 147_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 206: 147_2b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 207: 147_2b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 208: 147_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 209: 148_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 210: 149_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 211: 149_1b1_Lr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 212: 149_1b1_Pl_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 213: 150_1b2_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 214: 151_2p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 215: 151_2p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 216: 151_2p2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 217: 151_2p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 218: 151_2p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 219: 151_2p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 220: 151_2p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 221: 151_2p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 222: 151_2p3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 223: 151_2p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 224: 151_2p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 225: 151_2p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 226: 151_2p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 227: 151_2p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 228: 151_2p4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 229: 151_2p4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 230: 151_2p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 231: 151_2p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 232: 151_3p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 233: 151_3p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 234: 151_3p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 235: 151_3p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 236: 151_3p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 237: 151_3p3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 238: 152_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 239: 153_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 240: 154_1b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 241: 154_1b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 242: 154_1b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 243: 154_1b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 244: 154_1b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 245: 154_1b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 246: 154_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 247: 154_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 248: 154_2b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 249: 154_2b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 250: 154_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 251: 154_2b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 252: 154_3b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 253: 154_3b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 254: 154_3b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 255: 154_4b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 256: 154_4b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 257: 154_4b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 258: 154_4b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 259: 154_4b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 260: 154_4b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 261: 155_2b1_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 262: 156_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 263: 156_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 264: 156_2b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 265: 156_2b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 266: 156_2b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 267: 156_2b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 268: 156_5b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 269: 156_5b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 270: 156_5b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 271: 156_5b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 272: 156_5b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 273: 156_5b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 274: 156_8b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 275: 156_8b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 276: 156_8b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 277: 156_8b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 278: 156_8b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 279: 158_1b3_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 280: 158_1p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 281: 158_1p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 282: 158_1p2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 283: 158_1p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 284: 158_1p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 285: 158_1p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 286: 158_1p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 287: 158_1p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 288: 158_1p3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 289: 158_1p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 290: 158_1p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 291: 158_1p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 292: 158_1p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 293: 158_1p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 294: 158_1p4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 295: 158_1p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 296: 158_1p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 297: 158_2p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 298: 158_2p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 299: 159_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 300: 159_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 301: 159_1b1_Ll_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 302: 159_1b1_Pr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 303: 160_1b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 304: 160_1b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 305: 160_1b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 306: 160_1b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 307: 160_1b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 308: 160_1b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 309: 160_1b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 310: 160_1b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 311: 160_1b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 312: 160_1b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 313: 160_1b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 314: 160_1b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 315: 160_1b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 316: 160_1b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 317: 160_1b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 318: 160_2b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 319: 160_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 320: 160_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 321: 160_2b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 322: 161_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 323: 161_1b1_Pl_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 324: 162_1b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 325: 162_1b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 326: 162_1b2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 327: 162_1b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 328: 162_1b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 329: 162_1b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 330: 162_2b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 331: 162_2b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 332: 162_2b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 333: 162_2b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 334: 162_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 335: 162_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 336: 162_2b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 337: 162_2b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 338: 162_2b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 339: 162_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 340: 162_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 341: 162_2b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 342: 162_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 343: 162_2b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 344: 163_2b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 345: 163_2b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 346: 163_2b2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 347: 163_2b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 348: 163_2b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 349: 163_2b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 350: 163_8b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 351: 163_8b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 352: 163_8b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 353: 163_8b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 354: 163_8b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 355: 163_8b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 356: 164_1b1_Ll_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 357: 165_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (79500,)
# Iteración 358: 165_1b1_Pl_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 359: 165_1b1_Pr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 360: 167_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 361: 167_1b1_Pr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 362: 168_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 363: 169_1b1_Lr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 364: 169_1b2_Ll_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 365: 170_1b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 366: 170_1b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 367: 170_1b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 368: 170_1b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 369: 170_1b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 370: 170_1b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 371: 170_1b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 372: 170_1b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 373: 170_1b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 374: 170_1b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 375: 170_1b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 376: 170_1b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 377: 170_1b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 378: 170_1b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 379: 170_1b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 380: 170_1b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 381: 170_2b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 382: 170_2b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 383: 170_2b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 384: 170_2b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 385: 170_2b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 386: 171_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 387: 172_1b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 388: 172_1b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 389: 172_1b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 390: 172_1b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 391: 172_1b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 392: 172_1b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 393: 172_1b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 394: 172_1b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 395: 172_1b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 396: 172_1b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 397: 172_1b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 398: 172_1b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 399: 172_1b5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 400: 172_1b5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 401: 172_1b5_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 402: 172_1b5_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 403: 172_1b5_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 404: 172_1b5_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 405: 172_2b5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 406: 172_2b5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 407: 172_2b5_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 408: 172_2b5_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 409: 172_2b5_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 410: 173_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 411: 174_1p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 412: 174_1p2_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 413: 174_1p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 414: 174_1p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 415: 174_1p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 416: 174_1p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 417: 174_1p3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 418: 174_1p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 419: 174_1p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 420: 174_1p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 421: 174_1p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 422: 174_1p4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 423: 174_1p4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 424: 174_1p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 425: 174_1p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 426: 174_2p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 427: 174_2p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 428: 174_2p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 429: 174_2p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 430: 176_1b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 431: 176_1b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 432: 176_1b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 433: 176_1b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 434: 176_1b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 435: 176_1b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 436: 176_1b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 437: 176_1b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 438: 176_1b4_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 439: 176_1b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 440: 176_1b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 441: 176_1b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 442: 176_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 443: 176_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 444: 176_2b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 445: 176_2b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 446: 176_2b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 447: 176_2b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 448: 177_1b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 449: 177_1b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 450: 177_1b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 451: 177_1b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 452: 177_1b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 453: 177_1b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 454: 177_1b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 455: 177_1b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 456: 177_1b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 457: 177_1b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 458: 177_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 459: 177_2b4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 460: 177_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 461: 177_2b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 462: 178_1b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 463: 178_1b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 464: 178_1b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 465: 178_1b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 466: 178_1b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 467: 178_1b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 468: 178_1b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 469: 178_1b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 470: 178_1b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 471: 178_1b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 472: 178_1b6_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 473: 178_1b6_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 474: 178_1b6_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 475: 178_1b6_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 476: 178_1b6_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# ...
# Samplerate = 4000, largo = (80182,)
# Iteración 537: 194_1b1_Lr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 538: 194_1b1_Pr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 539: 196_1b1_Pr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 540: 197_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 541: 198_1b5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 542: 198_1b5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 543: 198_1b5_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 544: 198_1b5_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 545: 198_1b5_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 546: 198_1b5_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 547: 198_6p1_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 548: 198_6p1_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 549: 198_6p1_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 550: 198_6p1_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 551: 198_6p1_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 552: 198_6p1_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 553: 199_2b1_Ll_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 554: 199_2b3_Ll_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 555: 200_2p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 556: 200_2p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 557: 200_2p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 558: 200_2p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 559: 200_2p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 560: 200_2p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 561: 200_2p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 562: 200_2p3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 563: 200_2p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 564: 200_2p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 565: 200_2p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 566: 200_2p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 567: 200_2p4_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 568: 200_2p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 569: 200_2p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 570: 200_3p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 571: 200_3p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 572: 200_3p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 573: 200_3p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 574: 201_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 575: 201_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 576: 201_1b2_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 577: 201_1b2_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 578: 201_1b3_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 579: 201_1b3_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 580: 202_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (79380,)
# Iteración 581: 203_1p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 582: 203_1p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 583: 203_1p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 584: 203_1p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 585: 203_1p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 586: 203_1p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 587: 203_1p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 588: 203_1p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 589: 203_1p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 590: 203_1p4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 591: 203_1p4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 592: 203_1p4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 593: 203_1p4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 594: 203_2p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 595: 203_2p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 596: 203_2p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 597: 203_2p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 598: 204_2b5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 599: 204_2b5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 600: 204_2b5_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 601: 204_7p5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 602: 204_7p5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 603: 204_7p5_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 604: 204_7p5_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 605: 204_7p5_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 606: 205_1b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 607: 205_1b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 608: 205_1b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 609: 205_1b3_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 610: 205_1b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 611: 205_1b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 612: 205_2b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 613: 205_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 614: 205_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 615: 205_2b3_Ll_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 616: 205_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 617: 205_3b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 618: 205_3b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 619: 205_3b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 620: 205_3b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 621: 205_4b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 622: 205_4b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 623: 205_4b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 624: 205_4b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 625: 205_4b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 626: 206_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 627: 206_1b1_Lr_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 628: 206_1b1_Pl_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 629: 207_2b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 630: 207_2b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 631: 207_2b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 632: 207_2b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 633: 207_2b3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 634: 207_2b3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 635: 207_2b3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 636: 207_2b3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 637: 207_2b4_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 638: 207_2b4_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 639: 207_2b4_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 640: 207_2b4_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 641: 207_3b2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 642: 207_3b2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 643: 207_3b2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 644: 207_3b2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 645: 207_3b2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 646: 208_1b1_Ll_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (79982,)
# Iteración 647: 210_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 648: 210_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (79460,)
# Iteración 649: 211_1p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 650: 211_1p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 651: 211_1p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 652: 211_1p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 653: 211_1p5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 654: 213_1p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 655: 213_1p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 656: 213_1p2_Lr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 657: 213_1p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 658: 213_1p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 659: 213_1p3_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 660: 213_1p3_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 661: 213_1p3_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 662: 213_1p3_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 663: 213_1p5_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 664: 213_1p5_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 665: 213_1p5_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 666: 213_1p5_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 667: 213_2p2_Al_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 668: 213_2p2_Ar_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 669: 213_2p2_Pl_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 670: 213_2p2_Pr_mc_AKGC417L
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 671: 214_1b1_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (79540,)
# Iteración 672: 215_1b2_Ar_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 673: 216_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 674: 216_1b1_Pl_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 675: 219_2b1_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 676: 219_2b2_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 677: 220_1b2_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 678: 221_2b1_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 679: 221_2b1_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 680: 221_2b1_Lr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 681: 221_2b1_Pl_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 682: 221_2b2_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 683: 221_2b2_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 684: 221_2b2_Lr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 685: 221_2b2_Pl_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 686: 221_2b3_Al_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 687: 221_2b3_Ar_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 688: 221_2b3_Lr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 689: 221_2b3_Pr_mc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 690: 224_1b2_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 691: 225_1b1_Pl_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 692: 226_1b1_Al_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 693: 226_1b1_Ll_sc_Meditron
# --------------------------
# Samplerate = 4000, largo = (80182,)
# Iteración 694: 226_1b1_Pl_sc_LittC2SE
# --------------------------
# Samplerate = 4000, largo = (80182,)

# %%
min_list = list()
max_list = list()
len_list = list()

for i in X_segments:
    min_list.append(min(i))
    max_list.append(max(i))
    len_list.append(len(i))

# %%
print(min(min_list))
print(max(max_list))
print(max(len_list))
# Out:
# -1.0413449010074045
# 1.0
# 31320

# %% [markdown]
# # Stratify

# %%
# Definición de los grupos de pacientes
patient_groups = {1: ['101', '102', '103', '106', '107', '108', '114', '115', '116', 
                      '119', '122', '123', '126', '127', '129', '162'],
                  2: ['130', '131', '132', '165', '197'],
                  3: ['133', '134', '135', '136', '137', '138', '140', '141', '142', 
                      '143', '169'],
                  4: ['144', '145', '146', '147', '148', '149', '150', '151', '152',
                      '153', '155', '159', '179'],
                  5: ['154', '156', '160', '161', '167', '225', '226'],
                  6: ['158', '163', '164', '168', '170', '171', '183', '216', '221',
                      '224'],
                  7: ['172', '173', '174', '176', '177', '180', '189', '191', '196'],
                  8: ['178', '181', '184', '186', '187', '188', '192', '194', '202', 
                      '204'],
                  9: ['193', '198', '199', '200', '201', '203'],
                  10: ['205', '206', '207', '208', '210', '211', '213', '214', '215',
                       '219', '220']}

# Definición de variables de control
segment_count = 0
patients_reviewed = list()

for i in patient_groups.keys():
    segments_by_group = 0
    
    for j in patient_groups[i]:
        # Sumando al contador de grupo
        segments_by_group += len(patient_register[j])
        
    # Agregando a la lista de pacientes totales
    patients_reviewed.extend(patient_groups[i])
    
    # Sumando al contador total 
    segment_count += segments_by_group
    
    # Print de sanidad
    print(f'Grupo {i}: {segments_by_group}')

print(f'Definidos {segment_count} de {Y_wheeze.shape[0]}')
# Out:
# Grupo 1: 485
# Grupo 2: 492
# Grupo 3: 491
# Grupo 4: 487
# Grupo 5: 494
# Grupo 6: 493
# Grupo 7: 490
# Grupo 8: 487
# Grupo 9: 491
# Grupo 10: 492
# Definidos 4902 de 4902
# new

# %% [markdown]
# # Diseño del sistema de clasificación

# %%
def ML_classification_system(X_train, Y_train, X_test, Y_test, 
                             clean_params=None, sel_params=None, 
                             class_params=None):
    '''Diseño del sistema de clasificación basado en Machine 
    Learning.
    
    Parameters
    ----------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        'tol': 13-5, 'show': True. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        'n_features': 10, 'show': True. Por defecto es None.
    class_params: dict or None, optional
        Parámetros del proceso de clasificación. Si es None se 
        utilizan características por defecto: 
        'classifier': 'knn', 'k_neigh': 10. Por defecto es None. 
        En caso de usar 'svm', es posible modificar el 'kernel'.
        
    Returns
    -------
    classifier : class
        Clasificador entrenado.
    X_test : ndarray
        Matriz de testeo modificada (en caso de que X_test no 
        sea None).
    params_out : dict
        Parámetros obtenidos a partir del entrenamiento del
        sistema sobre los datos. Se entrega información de las
        características del clean ('s_clean'), normalización
        ('a_norm' y 'b_norm'), y de la selección de 
        características ('s_sfs').
    Y_pred : ndarray or None
        Predicción realizada por el sistema (en caso de que
        Y_test no sea None). Si no se entrega Y_test, la salida
        será None.
    '''
    # Parámetros por defecto
    if clean_params is None:
        clean_params = {'tol': 1e-5, 'show': True}
    
    if sel_params is None:
        sel_params = {'n_features': 10, 'show': True}
    
    if class_params is None:
        class_params = {'classifier': 'knn', 'k_neigh': 10}
        
    Y_pred = None
    
    
    #### Pipeline de la etapa de clasificación ####
    
    ## 1) Limpieza de las características
    s_clean = pybalu_clean(X_train, tol=clean_params['tol'], 
                           show=clean_params['show'])
    
    # Aplicando la limpieza
    X_train = X_train[:, s_clean]
    
    
    ## 2) Normalización de los datos
    X_train, a_norm, b_norm = normalize(X_train)
    
    
    ## 3) Selección de características
    s_sfs = sfs(X_train, Y_train, show=sel_params['show'],
                n_features=sel_params['n_features'])
    
    # Aplicando la selección
    X_train = X_train[:, s_sfs]
    
    
    ## 4) Proceso de clasificación   
    if class_params['classifier'] == 'knn':
        classifier = KNeighborsClassifier(n_neighbors=\
                                          class_params['k_neigh'])
        
    elif class_params['classifier'] == 'svm':
        classifier = svm.SVC(kernel=class_params['kernel'])
    
    else:
        raise Exception('Opción de clasificador no definida '
                        'correctamente.')
    
    # Ajustando el clasificador
    classifier.fit(X_train, Y_train)
    
    
    # Aplicando todo el proceso a los datos de testeo
    if X_test is not None:
        X_test = X_test[:, s_clean]         # 1) Clean
        X_test = a_norm * X_test + b_norm   # 2) Normalización
        X_test = X_test[:, s_sfs]           # 3) Selección
        
        # Aplicando el clasificador
        if Y_test is not None:
            Y_pred = classifier.predict(X_test)

    
    # Definición del diccionario de parámetros
    params_out = {'a_norm': a_norm, 'b_norm': b_norm, 's_clean': s_clean,
                  's_sfs': s_sfs}
        
    return classifier, X_test, params_out, Y_pred


def NN_MLP_classification_system(X_train, Y_train, X_test, Y_test, 
                                 clean_params=None, sel_params=None, 
                                 mlp_params=None):
    '''Diseño del sistema de clasificación basado en Redes Neuronales
    Multicapas.
    
    Parameters
    ----------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        {'tol': 13-5, 'show': True}. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        {'n_features': 10, 'show': True}. Por defecto es None.
    mlp_params : dict or None, optional
        Parámetros del preoceso de clasificación con MLP. Si es
        None se utilizan las características por defecto:
        {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
         'batch_size': None, 'epochs': 100, 'verbose': 1, 
         'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                      tf.keras.metrics.Precision()],
         'out_layer': 'sigmoid', 'preprocessing': True}
        
    Returns
    -------
    classifier : class
        Clasificador entrenado.
    X_test : ndarray
        Matriz de testeo modificada (en caso de que X_test no 
        sea None).
    params_out : dict
        Parámetros obtenidos a partir del entrenamiento del
        sistema sobre los datos. Se entrega información de las
        características del clean ('s_clean'), normalización
        ('a_norm' y 'b_norm'), y de la selección de 
        características ('s_sfs').
    Y_pred : ndarray or None
        Predicción realizada por el sistema (en caso de que
        Y_test no sea None). Si no se entrega Y_test, la salida
        será None.
    '''
    # Parámetros por defecto
    if clean_params is None:
        clean_params = {'tol': 1e-5, 'show': True}
    
    if sel_params is None:
        sel_params = {'n_features': 10, 'show': True}
        
    if mlp_params is None:
        mlp_params = {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
                      'batch_size': None, 'epochs': 100, 'verbose': 1, 
                      'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                                  tf.keras.metrics.Precision()],
                      'out_layer': 'sigmoid', 'preprocessing': True}
    
    Y_pred = None
    
    
    #### Pipeline de la etapa de clasificación ####
    
    # Rutina de preprocesamiento
    if mlp_params['preprocessing']:
        ## 1) Limpieza de las características
        s_clean = pybalu_clean(X_train, tol=clean_params['tol'], 
                               show=clean_params['show'])

        # Aplicando la limpieza
        X_train = X_train[:, s_clean]


        ## 2) Normalización de los datos
        X_train, a_norm, b_norm = normalize(X_train)


        ## 3) Selección de características
        s_sfs = sfs(X_train, Y_train, show=sel_params['show'],
                    n_features=sel_params['n_features'])

        # Aplicando la selección
        X_train = X_train[:, s_sfs]

    
    
    ## 4) Proceso de clasificación
    
    # Definición del modelo
    model = MLP_network(input_shape=(X_train.shape[1],),
                        out_layer=mlp_params['out_layer'])
    
    # Compilando modelos
    model.compile(optimizer=mlp_params['optimizer'], 
                  loss=mlp_params['loss'],
                  metrics=mlp_params['metrics'])
    
    
    # Definición de los vectores
    if mlp_params['out_layer'] == 'softmax':
        # One-Hot
        Y_train_to = \
            np.array([Y_train, np.ones(len(Y_train)) - Y_train]).T
    
    elif mlp_params['out_layer'] == 'sigmoid':
        # Normal
        Y_train_to = Y_train
    
    
    # Ajustando el Modelo
    history = model.fit(x=X_train, y=Y_train_to, 
                        batch_size=mlp_params['batch_size'],
                        epochs=mlp_params['epochs'],
                        verbose=mlp_params['verbose'])
    
    
    # Aplicando todo el proceso a los datos de testeo
    if X_test is not None:
        # Si se realizó el preprocesamiento, se actualiza
        if preprocessing:
            X_test = X_test[:, s_clean]         # 1) Clean
            X_test = X_test * a_norm + b_norm   # 2) Normalización
            X_test = X_test[:, s_sfs]           # 3) Selección
        
        # Aplicando el clasificador
        if Y_test is not None:
            Y_pred = model.predict(X_test)

    
    # Definición del diccionario de parámetros
    params_out = {'a_norm': a_norm, 'b_norm': b_norm, 's_clean': s_clean,
                  's_sfs': s_sfs, 'history': history}
        
    return model, X_test, params_out, Y_pred


def MLP_network(input_shape, out_layer='sigmoid'):
    '''Función que define una red de perceptrones multicapas para 
    clasificar.
    
    Parameters
    ----------
    input_shape : list or ndarray
        Dimensión de la información de entrada.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    
    def _layer(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    
    # Definición de la red misma
    x_layer = _layer(x_in, units=500, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_1')
    x_layer = _layer(x_layer, units=200, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_2')
    x_layer = _layer(x_layer, units=100, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_3')
    x_layer = _layer(x_layer, units=80, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_4')
    x_layer = _layer(x_layer, units=30, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_5')
    x_layer = _layer(x_layer, units=10, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_6')
    x_layer = _layer(x_layer, units=5, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_7')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_MLP')
    
    return model


def CNN_network(input_shape, padding_value, out_layer='sigmoid'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling1D(pool_size=2, strides=2, 
                                             padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    # Definición de la capa de máscara
    x_masked = tf.keras.layers.Masking(mask_value=padding_value)(x_in)
                                             
    # Definición de la CNN
    layer_params_1 = {'filters': 50, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_masked, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 30, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 10, 'kernel_size': 25, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=3, layer_params=layer_params_3)
                                             
    layer_params_4 = {'filters': 7, 'kernel_size': 13, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_4'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=3, layer_params=layer_params_4)
                      
    
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.Flatten()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=500, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    x_layer = _mlp_layers(x_layer, units=200, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_2')
    x_layer = _mlp_layers(x_layer, units=100, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_3')
    x_layer = _mlp_layers(x_layer, units=80, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_4')
    x_layer = _mlp_layers(x_layer, units=30, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_5')
    x_layer = _mlp_layers(x_layer, units=10, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_6')
    x_layer = _mlp_layers(x_layer, units=5, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_7')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model


def train_test_definition(X_data, Y_data, index_test, patient_groups,
                          patient_register, kfold=10):
    '''Función que permite retornar los conjuntos de entrenamiento
    y testeo en base a la división de la base de datos realizada 
    previamente para hacer una validación cruzada.
    
    Parameters
    ----------
    X_data : ndarray
        Matriz de características.
    Y_data : ndarray
        Etiquetas de la matriz de características.
    index_test : int
        Índice del grupo de testeo en la validación cruzada.
    patient_gropus : dict
        Diccionario que contiene los pacientes que corresponden
        a cada grupo de la validación cruzada.
    patient_register : dict
        Diccionario que contiene las entradas de cada paciente
        en la matriz de características.
    kfold : int, optional
        k de la validación cruzada que se realiza. Por defecto 
        es 10.
    
    Returns
    -------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    '''
    # Definición de los pacientes de testeo 
    test_patients = patient_groups[index_test]
    
    # Y entrenamiento
    train_patients = list()
    for i in range(1, kfold + 1):
        if i != index_test:
            train_patients.extend(patient_groups[i])
            
    # Definición de las entradas de entrenamiento y testeo
    train_indexes = list()
    test_indexes = list()
    
    for i in train_patients:
        train_indexes.extend(patient_register[str(i)])
    
    for i in test_patients:
        test_indexes.extend(patient_register[str(i)])

    # Aplicando los indices sobre los datos
    X_train = X_data[train_indexes]
    Y_train = Y_data[train_indexes]
    X_test  = X_data[test_indexes]
    Y_test  = Y_data[test_indexes]
    
    return X_train, Y_train, X_test, Y_test
    
    
def crossval_results(X_data, Y_data, experiment_type='ML', clean_params=None, 
                     sel_params=None, class_params=None, mlp_params=None,
                     kfold=10):
    '''Función que permite calcular el desempeño del clasificador
    mediante una validación cruzada de los datos.
    
    Parameters
    ----------
    X_data : ndarray
        Matriz de características.
    Y_data : ndarray
        Etiquetas de la matriz de características.
    experiment_type : {'ML', 'NN-MLP' 'CNN'}, optional
        Tipo de sistema a estudiar. 'ML' corresponde a un diseño
        estilo Machine-Learning (Rec. de Patrones). 'NN-MLP'
        corresponde a un diseño que utiliza como salida un 
        clasificador de perceptrones multicapas. 'CNN' es un
        diseño que utiliza una CNN con arquitectura clásica
        (AlexNet o VGG-16) para clasificar cada segmento.
        Por defecto es 'ML'.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        'tol': 13-5, 'show': True. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        'n_features': 10, 'show': True. Por defecto es None.
    class_params: dict or None, optional
        Parámetros del proceso de clasificación. Si es None se 
        utilizan características por defecto: 
        'classifier': 'knn', 'k_neigh': 10. Por defecto es None. 
        En caso de usar 'svm', es posible modificar el 'kernel'.
    mlp_params : dict or None, optional
        Parámetros del preoceso de clasificación con MLP. Si es
        None se utilizan las características por defecto:
        {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
         'batch_size': None, 'epochs': 100, 'verbose': 1, 
         'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                      tf.keras.metrics.Precision()],
         'out_layer': 'sigmoid', 'preprocessing': True}
    kfold : int, optional
        k de las repeticiones de la validación cruzada k-fold.
        Por defecto es 10.
    
    Returns
    -------
    confmat_list: list
        Lista de las matrices de confusión para cada iteración.
    accuracy_list : list
        Lista de las accuracys para cada iteración.
    '''
    # Definición de la lista de matrices de confusión
    confmat_list = list()
    
    # Iteraciónes del k-fold cross validation
    for index in range(1, kfold + 1):
        # Definición de la base de datos
        X_train, Y_train, X_test, Y_test = \
            train_test_definition(X_data, Y_data, index_test=index, 
                                  patient_groups=patient_groups,
                                  patient_register=patient_register)

        # Aplicando el clasificador
        if experiment_type == 'ML':
            classifier, X_test, params_out, Y_pred = \
                    ML_classification_system(X_train, Y_train, X_test, Y_test, 
                                             clean_params=clean_params, 
                                             sel_params=sel_params, 
                                             class_params=class_params)
            
        elif experiment_type == 'NN-MLP':
            model, X_test, params_out, Y_pred = \
                NN_MLP_classification_system(X_train, Y_train, X_test, Y_test, 
                                             clean_params=clean_params, 
                                             sel_params=sel_params, 
                                             mlp_params=mlp_params)
            
            # Modificar el Y_pred
            Y_pred = np.where(Y_pred < 0.5, 0, 1)[:, 0]

        elif experiment_type == 'CNN':
            pass
    
        else:
            raise Exception('Opción no válida para "experiment_type".')
    
        # Obteniendo la matriz de confusión
        conf_mat = confusion_matrix(Y_pred, Y_test)
        
        # Agregando a la lista
        confmat_list.append(conf_mat)
    
    # Cálculo de los resultados finales
    accuracy_list = list()
    
    for cmat in confmat_list:
        accuracy_i = np.sum(np.diag(cmat)) / np.sum(cmat)
        accuracy_list.append(accuracy_i)
        
    print(f'Accuracy {kfold}-fold CV: {np.mean(accuracy_list)} +- '
          f'{np.std(accuracy_list)}')
    
    return confmat_list, accuracy_list

# %%
# Parámetros generales
clean_params = {'tol': 1e-5, 'show': True}
sel_params = {'n_features': 60, 'show': True}

# %% [markdown]
# # kNN

# %%
class_params = {'classifier': 'knn', 'k_neigh': 3}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 121.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:14<00:00, 4.10 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.88 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.97 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.97 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.93 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.90 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.88 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.97 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.75 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.96 features/s]
# Accuracy 10-fold CV: 0.5510293314947965 +- 0.07420473223452298
# Clean: number of features reduced from 149 to 121.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.98 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.66 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.72 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.69 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.70 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.71 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.70 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.76 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.73 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.79 features/s]
# Accuracy 10-fold CV: 0.7616261834350369 +- 0.06144312405586361
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.08 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.06 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.14 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.09 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.95 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.14 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.05 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.08 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.08 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.15 features/s]
# Accuracy 10-fold CV: 0.5407881704969874 +- 0.06759986120558278
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.94 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.92 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.98 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.94 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.92 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.95 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.94 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.48 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.76 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.54 features/s]
# Accuracy 10-fold CV: 0.7961227283418719 +- 0.06840567558223988

# %% [markdown]
# # SVM

# %%
class_params = {'classifier': 'svm', 'kernel': 'poly'}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 121.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:14<00:00, 4.27 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.92 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.72 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.65 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.77 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.69 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.80 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.93 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.68 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.87 features/s]
# Accuracy 10-fold CV: 0.5660187439489475 +- 0.1290230327118345
# Clean: number of features reduced from 149 to 121.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.70 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.43 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.42 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.47 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.43 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.17 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.28 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.32 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.24 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.39 features/s]
# Accuracy 10-fold CV: 0.7971965833752551 +- 0.07703200750850601
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.73 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.74 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.86 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.93 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.65 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.72 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.89 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.92 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.82 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.86 features/s]
# Accuracy 10-fold CV: 0.5643193513719288 +- 0.13877708534888913
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.85 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.68 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.84 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.43 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.61 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.19 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.57 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.62 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.74 features/s]
# Accuracy 10-fold CV: 0.8138678363810097 +- 0.07293877920007519

# %% [markdown]
# # Redes Neuronales MLP

# %%
preprocessing = True
mlp_params = {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
              'batch_size': None, 'epochs': 30, 'verbose': 0, 
              'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                          tf.keras.metrics.Precision()],
              'out_layer': 'sigmoid', 'preprocessing': True}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)
# Out:
# Clean: number of features reduced from 149 to 121.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 4.00 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.72 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.53 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.07 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.37 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:15<00:00, 3.77 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.69 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.71 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.65 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.51 features/s]
# Accuracy 10-fold CV: 0.5547237580848834 +- 0.08159031973013899
# Clean: number of features reduced from 149 to 121.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:16<00:00, 3.66 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.36 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.30 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.10 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.43 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.43 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.27 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.23 features/s]
# Clean: number of features reduced from 149 to 126.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.41 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:17<00:00, 3.47 features/s]
# Accuracy 10-fold CV: 0.7507860071542727 +- 0.07070154593320024
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.81 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.86 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.63 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.84 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.86 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.82 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.79 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.76 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.76 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.81 features/s]
# Accuracy 10-fold CV: 0.5655197838280108 +- 0.07584921945477313
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.65 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.67 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.68 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.57 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.61 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.64 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.65 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.67 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.69 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.52 features/s]
# Accuracy 10-fold CV: 0.7933760009183782 +- 0.055980745332417696

# %% [markdown]
# # Redes neuronales CNN

# %%
X_segments_mat = tf.keras.preprocessing.sequence.pad_sequences(X_segments, padding="post", value=10)
X_segments_mat = np.expand_dims(X_segments_mat, axis=-1)
print(X_segments_mat.shape)
# Out:
# (4902, 31320, 1)

# %%
cnn_params = {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
              'batch_size': 5, 'epochs': 10, 'verbose': 0, 
              'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                          tf.keras.metrics.Precision()],
              'out_layer': 'softmax'}

X_train, Y_train, X_test, Y_test = \
        train_test_definition(X_segments_mat, Y_crackl, index_test=10, 
                              patient_groups=patient_groups,
                              patient_register=patient_register, kfold=10)

# %%
model = CNN_network(input_shape=X_segments_mat.shape[1:], padding_value=10, 
                    out_layer=cnn_params['out_layer'])
model.compile(optimizer=cnn_params['optimizer'], loss=cnn_params['loss'],
              metrics=cnn_params['metrics'])

# %%
model.summary()
# Out:
# Model: "Red_CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_19 (InputLayer)        [(None, 31320, 1)]        0
# _________________________________________________________________
# masking_18 (Masking)         (None, 31320, 1)          0
# _________________________________________________________________
# Conv_cnn_1_0 (Conv1D)        (None, 31320, 50)         5050
# _________________________________________________________________
# BatchNorm_cnn_1_0 (BatchNorm (None, 31320, 50)         200
# _________________________________________________________________
# Activation_cnn_1_0 (Activati (None, 31320, 50)         0
# _________________________________________________________________
# Conv_cnn_1_1 (Conv1D)        (None, 31320, 50)         250050
# _________________________________________________________________
# BatchNorm_cnn_1_1 (BatchNorm (None, 31320, 50)         200
# _________________________________________________________________
# Activation_cnn_1_1 (Activati (None, 31320, 50)         0
# _________________________________________________________________
# MaxPool_Conv_cnn_1 (MaxPooli (None, 15660, 50)         0
# _________________________________________________________________
# Conv_cnn_2_0 (Conv1D)        (None, 15660, 30)         75030
# _________________________________________________________________
# BatchNorm_cnn_2_0 (BatchNorm (None, 15660, 30)         120
# _________________________________________________________________
# Activation_cnn_2_0 (Activati (None, 15660, 30)         0
# _________________________________________________________________
# Conv_cnn_2_1 (Conv1D)        (None, 15660, 30)         45030
# _________________________________________________________________
# BatchNorm_cnn_2_1 (BatchNorm (None, 15660, 30)         120
# _________________________________________________________________
# Activation_cnn_2_1 (Activati (None, 15660, 30)         0
# _________________________________________________________________
# MaxPool_Conv_cnn_2 (MaxPooli (None, 7830, 30)          0
# _________________________________________________________________
# Conv_cnn_3_0 (Conv1D)        (None, 7830, 10)          7510
# _________________________________________________________________
# BatchNorm_cnn_3_0 (BatchNorm (None, 7830, 10)          40
# _________________________________________________________________
# Activation_cnn_3_0 (Activati (None, 7830, 10)          0
# _________________________________________________________________
# Conv_cnn_3_1 (Conv1D)        (None, 7830, 10)          2510
# _________________________________________________________________
# BatchNorm_cnn_3_1 (BatchNorm (None, 7830, 10)          40
# _________________________________________________________________
# Activation_cnn_3_1 (Activati (None, 7830, 10)          0
# _________________________________________________________________
# Conv_cnn_3_2 (Conv1D)        (None, 7830, 10)          2510
# _________________________________________________________________
# BatchNorm_cnn_3_2 (BatchNorm (None, 7830, 10)          40
# _________________________________________________________________
# Activation_cnn_3_2 (Activati (None, 7830, 10)          0
# _________________________________________________________________
# MaxPool_Conv_cnn_3 (MaxPooli (None, 3915, 10)          0
# _________________________________________________________________
# Conv_cnn_4_0 (Conv1D)        (None, 3915, 7)           917
# _________________________________________________________________
# BatchNorm_cnn_4_0 (BatchNorm (None, 3915, 7)           28
# _________________________________________________________________
# Activation_cnn_4_0 (Activati (None, 3915, 7)           0
# _________________________________________________________________
# Conv_cnn_4_1 (Conv1D)        (None, 3915, 7)           644
# _________________________________________________________________
# BatchNorm_cnn_4_1 (BatchNorm (None, 3915, 7)           28
# _________________________________________________________________
# Activation_cnn_4_1 (Activati (None, 3915, 7)           0
# _________________________________________________________________
# Conv_cnn_4_2 (Conv1D)        (None, 3915, 7)           644
# _________________________________________________________________
# BatchNorm_cnn_4_2 (BatchNorm (None, 3915, 7)           28
# _________________________________________________________________
# Activation_cnn_4_2 (Activati (None, 3915, 7)           0
# _________________________________________________________________
# MaxPool_Conv_cnn_4 (MaxPooli (None, 1957, 7)           0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 13699)             0
# _________________________________________________________________
# Dense_Layer_1 (Dense)        (None, 500)               6850000
# _________________________________________________________________
# BatchNorm_Layer_1 (BatchNorm (None, 500)               2000
# _________________________________________________________________
# Activation_Layer_1 (Activati (None, 500)               0
# _________________________________________________________________
# Dense_Layer_2 (Dense)        (None, 200)               100200
# _________________________________________________________________
# BatchNorm_Layer_2 (BatchNorm (None, 200)               800
# _________________________________________________________________
# Activation_Layer_2 (Activati (None, 200)               0
# _________________________________________________________________
# Dense_Layer_3 (Dense)        (None, 100)               20100
# _________________________________________________________________
# BatchNorm_Layer_3 (BatchNorm (None, 100)               400
# _________________________________________________________________
# Activation_Layer_3 (Activati (None, 100)               0
# _________________________________________________________________
# Dense_Layer_4 (Dense)        (None, 80)                8080
# _________________________________________________________________
# BatchNorm_Layer_4 (BatchNorm (None, 80)                320
# _________________________________________________________________
# Activation_Layer_4 (Activati (None, 80)                0
# _________________________________________________________________
# Dense_Layer_5 (Dense)        (None, 30)                2430
# _________________________________________________________________
# BatchNorm_Layer_5 (BatchNorm (None, 30)                120
# _________________________________________________________________
# Activation_Layer_5 (Activati (None, 30)                0
# _________________________________________________________________
# Dense_Layer_6 (Dense)        (None, 10)                310
# _________________________________________________________________
# BatchNorm_Layer_6 (BatchNorm (None, 10)                40
# _________________________________________________________________
# Activation_Layer_6 (Activati (None, 10)                0
# _________________________________________________________________
# Dense_Layer_7 (Dense)        (None, 5)                 55
# _________________________________________________________________
# BatchNorm_Layer_7 (BatchNorm (None, 5)                 20
# _________________________________________________________________
# Activation_Layer_7 (Activati (None, 5)                 0
# _________________________________________________________________
# softmax_out (Dense)          (None, 2)                 12
# =================================================================
# Total params: 7,375,626
# Trainable params: 7,373,354
# Non-trainable params: 2,272
# _________________________________________________________________

# %%
X_train.shape
# Out:
# (4410, 31320, 1)

# %%
# Pasando a One-Hot
Y_train1H = np.array([Y_train, np.ones(Y_train.shape[0]) - Y_train]).T
print(Y_train.shape)
print(Y_train1H.shape)
# Out:
# (4410,)
# (4410, 2)

# %%
history = model.fit(x=X_train, y=Y_train1H, epochs=cnn_params['epochs'],
                    verbose=1, batch_size=cnn_params['batch_size'])
# Out:
# Epoch 1/10
#  93/882 [==>...........................] - ETA: 0s - loss: 0.7347 - accuracy: 0.4000 - recall_15: 0.4000 - precision_15: 0.400 - ETA: 2:11 - loss: 0.7045 - accuracy: 0.5000 - recall_15: 0.5000 - precision_15: 0.500 - ETA: 2:53 - loss: 0.7543 - accuracy: 0.3333 - recall_15: 0.3333 - precision_15: 0.333 - ETA: 3:13 - loss: 0.8893 - accuracy: 0.3500 - recall_15: 0.3500 - precision_15: 0.350 - ETA: 3:24 - loss: 0.8817 - accuracy: 0.2800 - recall_15: 0.2800 - precision_15: 0.280 - ETA: 3:31 - loss: 0.8772 - accuracy: 0.3000 - recall_15: 0.3000 - precision_15: 0.300 - ETA: 3:35 - loss: 0.8731 - accuracy: 0.2571 - recall_15: 0.2571 - precision_15: 0.257 - ETA: 3:39 - loss: 0.9436 - accuracy: 0.2500 - recall_15: 0.2500 - precision_15: 0.250 - ETA: 3:42 - loss: 0.9398 - accuracy: 0.2444 - recall_15: 0.2444 - precision_15: 0.244 - ETA: 3:44 - loss: 1.0049 - accuracy: 0.2600 - recall_15: 0.2600 - precision_15: 0.260 - ETA: 3:45 - loss: 0.9995 - accuracy: 0.2909 - recall_15: 0.2909 - precision_15: 0.290 - ETA: 3:47 - loss: 0.9935 - accuracy: 0.3000 - recall_15: 0.3000 - precision_15: 0.300 - ETA: 3:48 - loss: 0.9815 - accuracy: 0.2769 - recall_15: 0.2769 - precision_15: 0.276 - ETA: 3:49 - loss: 1.0177 - accuracy: 0.2857 - recall_15: 0.2857 - precision_15: 0.285 - ETA: 3:50 - loss: 1.0197 - accuracy: 0.2667 - recall_15: 0.2667 - precision_15: 0.266 - ETA: 3:51 - loss: 0.9982 - accuracy: 0.2875 - recall_15: 0.2875 - precision_15: 0.287 - ETA: 3:51 - loss: 1.0037 - accuracy: 0.2706 - recall_15: 0.2706 - precision_15: 0.270 - ETA: 3:51 - loss: 0.9883 - accuracy: 0.2778 - recall_15: 0.2778 - precision_15: 0.277 - ETA: 3:52 - loss: 0.9772 - accuracy: 0.2737 - recall_15: 0.2737 - precision_15: 0.273 - ETA: 3:52 - loss: 0.9672 - accuracy: 0.2700 - recall_15: 0.2700 - precision_15: 0.270 - ETA: 3:52 - loss: 0.9954 - accuracy: 0.2857 - recall_15: 0.2857 - precision_15: 0.285 - ETA: 3:53 - loss: 0.9831 - accuracy: 0.2909 - recall_15: 0.2909 - precision_15: 0.290 - ETA: 3:53 - loss: 0.9761 - accuracy: 0.2783 - recall_15: 0.2783 - precision_15: 0.278 - ETA: 3:53 - loss: 0.9822 - accuracy: 0.2750 - recall_15: 0.2750 - precision_15: 0.275 - ETA: 3:53 - loss: 0.9856 - accuracy: 0.2800 - recall_15: 0.2800 - precision_15: 0.280 - ETA: 3:53 - loss: 1.0014 - accuracy: 0.2769 - recall_15: 0.2769 - precision_15: 0.276 - ETA: 3:53 - loss: 1.0106 - accuracy: 0.2889 - recall_15: 0.2889 - precision_15: 0.288 - ETA: 3:53 - loss: 1.0126 - accuracy: 0.2929 - recall_15: 0.2929 - precision_15: 0.292 - ETA: 3:53 - loss: 1.0057 - accuracy: 0.2828 - recall_15: 0.2828 - precision_15: 0.282 - ETA: 3:54 - loss: 1.0161 - accuracy: 0.2867 - recall_15: 0.2867 - precision_15: 0.286 - ETA: 3:54 - loss: 1.0080 - accuracy: 0.2839 - recall_15: 0.2839 - precision_15: 0.283 - ETA: 3:54 - loss: 1.0137 - accuracy: 0.3000 - recall_15: 0.3000 - precision_15: 0.300 - ETA: 3:53 - loss: 1.0048 - accuracy: 0.3030 - recall_15: 0.3030 - precision_15: 0.303 - ETA: 3:53 - loss: 1.0245 - accuracy: 0.3059 - recall_15: 0.3059 - precision_15: 0.305 - ETA: 3:53 - loss: 1.0181 - accuracy: 0.2971 - recall_15: 0.2971 - precision_15: 0.297 - ETA: 3:53 - loss: 1.0220 - accuracy: 0.3000 - recall_15: 0.3000 - precision_15: 0.300 - ETA: 3:53 - loss: 1.0211 - accuracy: 0.3081 - recall_15: 0.3081 - precision_15: 0.308 - ETA: 3:53 - loss: 1.0198 - accuracy: 0.3000 - recall_15: 0.3000 - precision_15: 0.300 - ETA: 3:53 - loss: 1.0156 - accuracy: 0.2974 - recall_15: 0.2974 - precision_15: 0.297 - ETA: 3:53 - loss: 1.0053 - accuracy: 0.3050 - recall_15: 0.3050 - precision_15: 0.305 - ETA: 3:53 - loss: 1.0001 - accuracy: 0.2976 - recall_15: 0.2976 - precision_15: 0.297 - ETA: 3:53 - loss: 0.9988 - accuracy: 0.2905 - recall_15: 0.2905 - precision_15: 0.290 - ETA: 3:53 - loss: 0.9939 - accuracy: 0.2837 - recall_15: 0.2837 - precision_15: 0.283 - ETA: 3:52 - loss: 0.9939 - accuracy: 0.2909 - recall_15: 0.2909 - precision_15: 0.290 - ETA: 3:52 - loss: 0.9917 - accuracy: 0.2933 - recall_15: 0.2933 - precision_15: 0.293 - ...
# 186/882 [=====>........................] - ETA: 3:41 - loss: 0.9356 - accuracy: 0.3319 - recall_15: 0.3319 - precision_15: 0.331 - ETA: 3:41 - loss: 0.9378 - accuracy: 0.3368 - recall_15: 0.3368 - precision_15: 0.336 - ETA: 3:40 - loss: 0.9399 - accuracy: 0.3417 - recall_15: 0.3417 - precision_15: 0.341 - ETA: 3:40 - loss: 0.9374 - accuracy: 0.3381 - recall_15: 0.3381 - precision_15: 0.338 - ETA: 3:40 - loss: 0.9349 - accuracy: 0.3388 - recall_15: 0.3388 - precision_15: 0.338 - ETA: 3:40 - loss: 0.9342 - accuracy: 0.3414 - recall_15: 0.3414 - precision_15: 0.341 - ETA: 3:39 - loss: 0.9318 - accuracy: 0.3460 - recall_15: 0.3460 - precision_15: 0.346 - ETA: 3:39 - loss: 0.9348 - accuracy: 0.3446 - recall_15: 0.3446 - precision_15: 0.344 - ETA: 3:39 - loss: 0.9301 - accuracy: 0.3490 - recall_15: 0.3490 - precision_15: 0.349 - ETA: 3:39 - loss: 0.9278 - accuracy: 0.3534 - recall_15: 0.3534 - precision_15: 0.353 - ETA: 3:38 - loss: 0.9248 - accuracy: 0.3558 - recall_15: 0.3558 - precision_15: 0.355 - ETA: 3:38 - loss: 0.9226 - accuracy: 0.3581 - recall_15: 0.3581 - precision_15: 0.358 - ETA: 3:38 - loss: 0.9201 - accuracy: 0.3623 - recall_15: 0.3623 - precision_15: 0.362 - ETA: 3:38 - loss: 0.9262 - accuracy: 0.3626 - recall_15: 0.3626 - precision_15: 0.362 - ETA: 3:37 - loss: 0.9263 - accuracy: 0.3630 - recall_15: 0.3630 - precision_15: 0.363 - ETA: 3:37 - loss: 0.9274 - accuracy: 0.3633 - recall_15: 0.3633 - precision_15: 0.363 - ETA: 3:37 - loss: 0.9251 - accuracy: 0.3636 - recall_15: 0.3636 - precision_15: 0.363 - ETA: 3:37 - loss: 0.9237 - accuracy: 0.3622 - recall_15: 0.3622 - precision_15: 0.362 - ETA: 3:36 - loss: 0.9198 - accuracy: 0.3661 - recall_15: 0.3661 - precision_15: 0.366 - ETA: 3:36 - loss: 0.9177 - accuracy: 0.3699 - recall_15: 0.3699 - precision_15: 0.369 - ETA: 3:36 - loss: 0.9156 - accuracy: 0.3737 - recall_15: 0.3737 - precision_15: 0.373 - ETA: 3:36 - loss: 0.9137 - accuracy: 0.3757 - recall_15: 0.3757 - precision_15: 0.375 - ETA: 3:35 - loss: 0.9117 - accuracy: 0.3793 - recall_15: 0.3793 - precision_15: 0.379 - ETA: 3:35 - loss: 0.9098 - accuracy: 0.3812 - recall_15: 0.3812 - precision_15: 0.381 - ETA: 3:35 - loss: 0.9052 - accuracy: 0.3864 - recall_15: 0.3864 - precision_15: 0.386 - ETA: 3:34 - loss: 0.9033 - accuracy: 0.3899 - recall_15: 0.3899 - precision_15: 0.389 - ETA: 3:34 - loss: 0.9064 - accuracy: 0.3917 - recall_15: 0.3917 - precision_15: 0.391 - ETA: 3:34 - loss: 0.9112 - accuracy: 0.3917 - recall_15: 0.3917 - precision_15: 0.391 - ETA: 3:34 - loss: 0.9092 - accuracy: 0.3967 - recall_15: 0.3967 - precision_15: 0.396 - ETA: 3:33 - loss: 0.9073 - accuracy: 0.4000 - recall_15: 0.4000 - precision_15: 0.400 - ETA: 3:33 - loss: 0.9054 - accuracy: 0.4048 - recall_15: 0.4048 - precision_15: 0.404 - ETA: 3:33 - loss: 0.9037 - accuracy: 0.4048 - recall_15: 0.4048 - precision_15: 0.404 - ETA: 3:33 - loss: 0.9013 - accuracy: 0.4048 - recall_15: 0.4048 - precision_15: 0.404 - ETA: 3:32 - loss: 0.8995 - accuracy: 0.4079 - recall_15: 0.4079 - precision_15: 0.407 - ETA: 3:32 - loss: 0.8977 - accuracy: 0.4109 - recall_15: 0.4109 - precision_15: 0.410 - ETA: 3:32 - loss: 0.8959 - accuracy: 0.4140 - recall_15: 0.4140 - precision_15: 0.414 - ETA: 3:32 - loss: 0.8943 - accuracy: 0.4154 - recall_15: 0.4154 - precision_15: 0.415 - ETA: 3:31 - loss: 0.8988 - accuracy: 0.4153 - recall_15: 0.4153 - precision_15: 0.415 - ETA: 3:31 - loss: 0.8969 - accuracy: 0.4197 - recall_15: 0.4197 - precision_15: 0.419 - ETA: 3:31 - loss: 0.8952 - accuracy: 0.4226 - recall_15: 0.4226 - precision_15: 0.422 - ETA: 3:30 - loss: 0.8938 - accuracy: 0.4254 - recall_15: 0.4254 - precision_15: 0.425 - ETA: 3:30 - loss: 0.8888 - accuracy: 0.4296 - recall_15: 0.4296 - precision_15: 0.429 - ETA: 3:30 - loss: 0.8872 - accuracy: 0.4324 - recall_15: 0.4324 - precision_15: 0.432 - ETA: 3:30 - loss: 0.8854 - accuracy: 0.4365 - recall_15: 0.4365 - precision_15: 0.436 - ETA: 3:29 - loss: 0.8837 - accuracy: 0.4406 - recall_15: 0.4406 - precision_15: 0.440 ...
# 279/882 [========>.....................] - ETA: 3:16 - loss: 0.8338 - accuracy: 0.5155 - recall_15: 0.5155 - precision_15: 0.515 - ETA: 3:16 - loss: 0.8326 - accuracy: 0.5170 - recall_15: 0.5170 - precision_15: 0.517 - ETA: 3:16 - loss: 0.8319 - accuracy: 0.5164 - recall_15: 0.5164 - precision_15: 0.516 - ETA: 3:15 - loss: 0.8300 - accuracy: 0.5179 - recall_15: 0.5179 - precision_15: 0.517 - ETA: 3:15 - loss: 0.8291 - accuracy: 0.5183 - recall_15: 0.5183 - precision_15: 0.518 - ETA: 3:15 - loss: 0.8276 - accuracy: 0.5198 - recall_15: 0.5198 - precision_15: 0.519 - ETA: 3:14 - loss: 0.8268 - accuracy: 0.5202 - recall_15: 0.5202 - precision_15: 0.520 - ETA: 3:14 - loss: 0.8258 - accuracy: 0.5216 - recall_15: 0.5216 - precision_15: 0.521 - ETA: 3:14 - loss: 0.8247 - accuracy: 0.5231 - recall_15: 0.5231 - precision_15: 0.523 - ETA: 3:14 - loss: 0.8233 - accuracy: 0.5255 - recall_15: 0.5255 - precision_15: 0.525 - ETA: 3:13 - loss: 0.8244 - accuracy: 0.5249 - recall_15: 0.5249 - precision_15: 0.524 - ETA: 3:13 - loss: 0.8249 - accuracy: 0.5222 - recall_15: 0.5222 - precision_15: 0.522 - ETA: 3:13 - loss: 0.8234 - accuracy: 0.5236 - recall_15: 0.5236 - precision_15: 0.523 - ETA: 3:12 - loss: 0.8219 - accuracy: 0.5260 - recall_15: 0.5260 - precision_15: 0.526 - ETA: 3:12 - loss: 0.8228 - accuracy: 0.5234 - recall_15: 0.5234 - precision_15: 0.523 - ETA: 3:12 - loss: 0.8216 - accuracy: 0.5228 - recall_15: 0.5228 - precision_15: 0.522 - ETA: 3:12 - loss: 0.8224 - accuracy: 0.5232 - recall_15: 0.5232 - precision_15: 0.523 - ETA: 3:11 - loss: 0.8205 - accuracy: 0.5255 - recall_15: 0.5255 - precision_15: 0.525 - ETA: 3:11 - loss: 0.8194 - accuracy: 0.5268 - recall_15: 0.5268 - precision_15: 0.526 - ETA: 3:11 - loss: 0.8183 - accuracy: 0.5272 - recall_15: 0.5272 - precision_15: 0.527 - ETA: 3:11 - loss: 0.8177 - accuracy: 0.5275 - recall_15: 0.5275 - precision_15: 0.527 - ETA: 3:10 - loss: 0.8173 - accuracy: 0.5288 - recall_15: 0.5288 - precision_15: 0.528 - ETA: 3:10 - loss: 0.8168 - accuracy: 0.5273 - recall_15: 0.5273 - precision_15: 0.527 - ETA: 3:10 - loss: 0.8158 - accuracy: 0.5286 - recall_15: 0.5286 - precision_15: 0.528 - ETA: 3:09 - loss: 0.8152 - accuracy: 0.5289 - recall_15: 0.5289 - precision_15: 0.528 - ETA: 3:09 - loss: 0.8140 - accuracy: 0.5302 - recall_15: 0.5302 - precision_15: 0.530 - ETA: 3:09 - loss: 0.8134 - accuracy: 0.5305 - recall_15: 0.5305 - precision_15: 0.530 - ETA: 3:09 - loss: 0.8130 - accuracy: 0.5299 - recall_15: 0.5299 - precision_15: 0.529 - ETA: 3:08 - loss: 0.8117 - accuracy: 0.5321 - recall_15: 0.5321 - precision_15: 0.532 - ETA: 3:08 - loss: 0.8119 - accuracy: 0.5333 - recall_15: 0.5333 - precision_15: 0.533 - ETA: 3:08 - loss: 0.8106 - accuracy: 0.5355 - recall_15: 0.5355 - precision_15: 0.535 - ETA: 3:08 - loss: 0.8097 - accuracy: 0.5367 - recall_15: 0.5367 - precision_15: 0.536 - ETA: 3:07 - loss: 0.8087 - accuracy: 0.5379 - recall_15: 0.5379 - precision_15: 0.537 - ETA: 3:07 - loss: 0.8078 - accuracy: 0.5391 - recall_15: 0.5391 - precision_15: 0.539 - ETA: 3:07 - loss: 0.8068 - accuracy: 0.5376 - recall_15: 0.5376 - precision_15: 0.537 - ETA: 3:06 - loss: 0.8056 - accuracy: 0.5396 - recall_15: 0.5396 - precision_15: 0.539 - ETA: 3:06 - loss: 0.8050 - accuracy: 0.5399 - recall_15: 0.5399 - precision_15: 0.539 - ETA: 3:06 - loss: 0.8040 - accuracy: 0.5411 - recall_15: 0.5411 - precision_15: 0.541 - ETA: 3:06 - loss: 0.8031 - accuracy: 0.5422 - recall_15: 0.5422 - precision_15: 0.542 - ETA: 3:05 - loss: 0.8047 - accuracy: 0.5398 - recall_15: 0.5398 - precision_15: 0.539 - ETA: 3:05 - loss: 0.8048 - accuracy: 0.5410 - recall_15: 0.5410 - precision_15: 0.541 - ETA: 3:05 - loss: 0.8036 - accuracy: 0.5421 - recall_15: 0.5421 - precision_15: 0.542 - ETA: 3:05 - loss: 0.8063 - accuracy: 0.5415 - recall_15: 0.5415 - precision_15: 0.541 - ETA: 3:04 - loss: 0.8054 - accuracy: 0.5426 - recall_15: 0.5426 - precision_15: 0.542 - ETA: 3:04 - loss: 0.8043 - accuracy: 0.5437 - recall_15: 0.5437 - precision_15: 0.543 ...
# 372/882 [===========>..................] - ETA: 2:50 - loss: 0.7666 - accuracy: 0.5821 - recall_15: 0.5821 - precision_15: 0.582 - ETA: 2:50 - loss: 0.7659 - accuracy: 0.5829 - recall_15: 0.5829 - precision_15: 0.582 - ETA: 2:50 - loss: 0.7655 - accuracy: 0.5830 - recall_15: 0.5830 - precision_15: 0.583 - ETA: 2:50 - loss: 0.7648 - accuracy: 0.5837 - recall_15: 0.5837 - precision_15: 0.583 - ETA: 2:49 - loss: 0.7645 - accuracy: 0.5838 - recall_15: 0.5838 - precision_15: 0.583 - ETA: 2:49 - loss: 0.7638 - accuracy: 0.5846 - recall_15: 0.5846 - precision_15: 0.584 - ETA: 2:49 - loss: 0.7633 - accuracy: 0.5846 - recall_15: 0.5846 - precision_15: 0.584 - ETA: 2:48 - loss: 0.7619 - accuracy: 0.5861 - recall_15: 0.5861 - precision_15: 0.586 - ETA: 2:48 - loss: 0.7611 - accuracy: 0.5868 - recall_15: 0.5868 - precision_15: 0.586 - ETA: 2:48 - loss: 0.7605 - accuracy: 0.5875 - recall_15: 0.5875 - precision_15: 0.587 - ETA: 2:48 - loss: 0.7594 - accuracy: 0.5883 - recall_15: 0.5883 - precision_15: 0.588 - ETA: 2:47 - loss: 0.7593 - accuracy: 0.5876 - recall_15: 0.5876 - precision_15: 0.587 - ETA: 2:47 - loss: 0.7586 - accuracy: 0.5884 - recall_15: 0.5884 - precision_15: 0.588 - ETA: 2:47 - loss: 0.7573 - accuracy: 0.5898 - recall_15: 0.5898 - precision_15: 0.589 - ETA: 2:46 - loss: 0.7566 - accuracy: 0.5905 - recall_15: 0.5905 - precision_15: 0.590 - ETA: 2:46 - loss: 0.7560 - accuracy: 0.5912 - recall_15: 0.5912 - precision_15: 0.591 - ETA: 2:46 - loss: 0.7569 - accuracy: 0.5919 - recall_15: 0.5919 - precision_15: 0.591 - ETA: 2:46 - loss: 0.7563 - accuracy: 0.5919 - recall_15: 0.5919 - precision_15: 0.591 - ETA: 2:45 - loss: 0.7561 - accuracy: 0.5919 - recall_15: 0.5919 - precision_15: 0.591 - ETA: 2:45 - loss: 0.7559 - accuracy: 0.5920 - recall_15: 0.5920 - precision_15: 0.592 - ETA: 2:45 - loss: 0.7556 - accuracy: 0.5920 - recall_15: 0.5920 - precision_15: 0.592 - ETA: 2:45 - loss: 0.7548 - accuracy: 0.5927 - recall_15: 0.5927 - precision_15: 0.592 - ETA: 2:44 - loss: 0.7535 - accuracy: 0.5940 - recall_15: 0.5940 - precision_15: 0.594 - ETA: 2:44 - loss: 0.7528 - accuracy: 0.5947 - recall_15: 0.5947 - precision_15: 0.594 - ETA: 2:44 - loss: 0.7521 - accuracy: 0.5954 - recall_15: 0.5954 - precision_15: 0.595 - ETA: 2:43 - loss: 0.7519 - accuracy: 0.5954 - recall_15: 0.5954 - precision_15: 0.595 - ETA: 2:43 - loss: 0.7511 - accuracy: 0.5961 - recall_15: 0.5961 - precision_15: 0.596 - ETA: 2:43 - loss: 0.7504 - accuracy: 0.5967 - recall_15: 0.5967 - precision_15: 0.596 - ETA: 2:43 - loss: 0.7498 - accuracy: 0.5968 - recall_15: 0.5968 - precision_15: 0.596 - ETA: 2:42 - loss: 0.7496 - accuracy: 0.5968 - recall_15: 0.5968 - precision_15: 0.596 - ETA: 2:42 - loss: 0.7483 - accuracy: 0.5981 - recall_15: 0.5981 - precision_15: 0.598 - ETA: 2:42 - loss: 0.7473 - accuracy: 0.5994 - recall_15: 0.5994 - precision_15: 0.599 - ETA: 2:41 - loss: 0.7471 - accuracy: 0.5994 - recall_15: 0.5994 - precision_15: 0.599 - ETA: 2:41 - loss: 0.7461 - accuracy: 0.6006 - recall_15: 0.6006 - precision_15: 0.600 - ETA: 2:41 - loss: 0.7464 - accuracy: 0.6000 - recall_15: 0.6000 - precision_15: 0.600 - ETA: 2:41 - loss: 0.7461 - accuracy: 0.6000 - recall_15: 0.6000 - precision_15: 0.600 - ETA: 2:40 - loss: 0.7459 - accuracy: 0.6000 - recall_15: 0.6000 - precision_15: 0.600 - ETA: 2:40 - loss: 0.7450 - accuracy: 0.6013 - recall_15: 0.6013 - precision_15: 0.601 - ETA: 2:40 - loss: 0.7440 - accuracy: 0.6019 - recall_15: 0.6019 - precision_15: 0.601 - ETA: 2:39 - loss: 0.7433 - accuracy: 0.6025 - recall_15: 0.6025 - precision_15: 0.602 - ETA: 2:39 - loss: 0.7423 - accuracy: 0.6037 - recall_15: 0.6037 - precision_15: 0.603 - ETA: 2:39 - loss: 0.7417 - accuracy: 0.6037 - recall_15: 0.6037 - precision_15: 0.603 - ETA: 2:39 - loss: 0.7412 - accuracy: 0.6043 - recall_15: 0.6043 - precision_15: 0.604 - ETA: 2:38 - loss: 0.7399 - accuracy: 0.6056 - recall_15: 0.6056 - precision_15: 0.605 - ETA: 2:38 - loss: 0.7403 - accuracy: 0.6049 - recall_15: 0.6049 - precision_15: 0.604 ...
# 465/882 [==============>...............] - ETA: 2:24 - loss: 0.7201 - accuracy: 0.6198 - recall_15: 0.6198 - precision_15: 0.619 - ETA: 2:24 - loss: 0.7192 - accuracy: 0.6209 - recall_15: 0.6209 - precision_15: 0.620 - ETA: 2:24 - loss: 0.7187 - accuracy: 0.6213 - recall_15: 0.6213 - precision_15: 0.621 - ETA: 2:23 - loss: 0.7182 - accuracy: 0.6218 - recall_15: 0.6218 - precision_15: 0.621 - ETA: 2:23 - loss: 0.7175 - accuracy: 0.6223 - recall_15: 0.6223 - precision_15: 0.622 - ETA: 2:23 - loss: 0.7182 - accuracy: 0.6212 - recall_15: 0.6212 - precision_15: 0.621 - ETA: 2:23 - loss: 0.7175 - accuracy: 0.6216 - recall_15: 0.6216 - precision_15: 0.621 - ETA: 2:22 - loss: 0.7178 - accuracy: 0.6211 - recall_15: 0.6211 - precision_15: 0.621 - ETA: 2:22 - loss: 0.7181 - accuracy: 0.6205 - recall_15: 0.6205 - precision_15: 0.620 - ETA: 2:22 - loss: 0.7178 - accuracy: 0.6204 - recall_15: 0.6204 - precision_15: 0.620 - ETA: 2:21 - loss: 0.7175 - accuracy: 0.6209 - recall_15: 0.6209 - precision_15: 0.620 - ETA: 2:21 - loss: 0.7174 - accuracy: 0.6214 - recall_15: 0.6214 - precision_15: 0.621 - ETA: 2:21 - loss: 0.7166 - accuracy: 0.6223 - recall_15: 0.6223 - precision_15: 0.622 - ETA: 2:21 - loss: 0.7161 - accuracy: 0.6228 - recall_15: 0.6228 - precision_15: 0.622 - ETA: 2:20 - loss: 0.7168 - accuracy: 0.6217 - recall_15: 0.6217 - precision_15: 0.621 - ETA: 2:20 - loss: 0.7157 - accuracy: 0.6227 - recall_15: 0.6227 - precision_15: 0.622 - ETA: 2:20 - loss: 0.7156 - accuracy: 0.6226 - recall_15: 0.6226 - precision_15: 0.622 - ETA: 2:19 - loss: 0.7154 - accuracy: 0.6226 - recall_15: 0.6226 - precision_15: 0.622 - ETA: 2:19 - loss: 0.7153 - accuracy: 0.6225 - recall_15: 0.6225 - precision_15: 0.622 - ETA: 2:19 - loss: 0.7145 - accuracy: 0.6235 - recall_15: 0.6235 - precision_15: 0.623 - ETA: 2:19 - loss: 0.7144 - accuracy: 0.6234 - recall_15: 0.6234 - precision_15: 0.623 - ETA: 2:18 - loss: 0.7135 - accuracy: 0.6244 - recall_15: 0.6244 - precision_15: 0.624 - ETA: 2:18 - loss: 0.7127 - accuracy: 0.6253 - recall_15: 0.6253 - precision_15: 0.625 - ETA: 2:18 - loss: 0.7122 - accuracy: 0.6258 - recall_15: 0.6258 - precision_15: 0.625 - ETA: 2:17 - loss: 0.7118 - accuracy: 0.6262 - recall_15: 0.6262 - precision_15: 0.626 - ETA: 2:17 - loss: 0.7113 - accuracy: 0.6266 - recall_15: 0.6266 - precision_15: 0.626 - ETA: 2:17 - loss: 0.7105 - accuracy: 0.6276 - recall_15: 0.6276 - precision_15: 0.627 - ETA: 2:17 - loss: 0.7100 - accuracy: 0.6280 - recall_15: 0.6280 - precision_15: 0.628 - ETA: 2:16 - loss: 0.7095 - accuracy: 0.6284 - recall_15: 0.6284 - precision_15: 0.628 - ETA: 2:16 - loss: 0.7092 - accuracy: 0.6284 - recall_15: 0.6284 - precision_15: 0.628 - ETA: 2:16 - loss: 0.7084 - accuracy: 0.6293 - recall_15: 0.6293 - precision_15: 0.629 - ETA: 2:15 - loss: 0.7087 - accuracy: 0.6287 - recall_15: 0.6287 - precision_15: 0.628 - ETA: 2:15 - loss: 0.7083 - accuracy: 0.6291 - recall_15: 0.6291 - precision_15: 0.629 - ETA: 2:15 - loss: 0.7083 - accuracy: 0.6291 - recall_15: 0.6291 - precision_15: 0.629 - ETA: 2:15 - loss: 0.7079 - accuracy: 0.6290 - recall_15: 0.6290 - precision_15: 0.629 - ETA: 2:14 - loss: 0.7082 - accuracy: 0.6289 - recall_15: 0.6289 - precision_15: 0.628 - ETA: 2:14 - loss: 0.7079 - accuracy: 0.6289 - recall_15: 0.6289 - precision_15: 0.628 - ETA: 2:14 - loss: 0.7078 - accuracy: 0.6288 - recall_15: 0.6288 - precision_15: 0.628 - ETA: 2:14 - loss: 0.7082 - accuracy: 0.6282 - recall_15: 0.6282 - precision_15: 0.628 - ETA: 2:13 - loss: 0.7074 - accuracy: 0.6291 - recall_15: 0.6291 - precision_15: 0.629 - ETA: 2:13 - loss: 0.7066 - accuracy: 0.6300 - recall_15: 0.6300 - precision_15: 0.630 - ETA: 2:13 - loss: 0.7062 - accuracy: 0.6304 - recall_15: 0.6304 - precision_15: 0.630 - ETA: 2:12 - loss: 0.7068 - accuracy: 0.6304 - recall_15: 0.6304 - precision_15: 0.630 - ETA: 2:12 - loss: 0.7064 - accuracy: 0.6308 - recall_15: 0.6308 - precision_15: 0.630 - ETA: 2:12 - loss: 0.7064 - accuracy: 0.6307 - recall_15: 0.6307 - precision_15: 0.630 ...
# 558/882 [=================>............] - ETA: 1:58 - loss: 0.6951 - accuracy: 0.6429 - recall_15: 0.6429 - precision_15: 0.642 - ETA: 1:58 - loss: 0.6948 - accuracy: 0.6433 - recall_15: 0.6433 - precision_15: 0.643 - ETA: 1:57 - loss: 0.6942 - accuracy: 0.6432 - recall_15: 0.6432 - precision_15: 0.643 - ETA: 1:57 - loss: 0.6942 - accuracy: 0.6431 - recall_15: 0.6431 - precision_15: 0.643 - ETA: 1:57 - loss: 0.6935 - accuracy: 0.6438 - recall_15: 0.6438 - precision_15: 0.643 - ETA: 1:57 - loss: 0.6935 - accuracy: 0.6437 - recall_15: 0.6437 - precision_15: 0.643 - ETA: 1:56 - loss: 0.6928 - accuracy: 0.6445 - recall_15: 0.6445 - precision_15: 0.644 - ETA: 1:56 - loss: 0.6924 - accuracy: 0.6448 - recall_15: 0.6448 - precision_15: 0.644 - ETA: 1:56 - loss: 0.6920 - accuracy: 0.6451 - recall_15: 0.6451 - precision_15: 0.645 - ETA: 1:55 - loss: 0.6925 - accuracy: 0.6451 - recall_15: 0.6451 - precision_15: 0.645 - ETA: 1:55 - loss: 0.6923 - accuracy: 0.6450 - recall_15: 0.6450 - precision_15: 0.645 - ETA: 1:55 - loss: 0.6916 - accuracy: 0.6457 - recall_15: 0.6457 - precision_15: 0.645 - ETA: 1:55 - loss: 0.6924 - accuracy: 0.6452 - recall_15: 0.6452 - precision_15: 0.645 - ETA: 1:54 - loss: 0.6927 - accuracy: 0.6447 - recall_15: 0.6447 - precision_15: 0.644 - ETA: 1:54 - loss: 0.6950 - accuracy: 0.6438 - recall_15: 0.6438 - precision_15: 0.643 - ETA: 1:54 - loss: 0.6950 - accuracy: 0.6437 - recall_15: 0.6437 - precision_15: 0.643 - ETA: 1:53 - loss: 0.6947 - accuracy: 0.6440 - recall_15: 0.6440 - precision_15: 0.644 - ETA: 1:53 - loss: 0.6946 - accuracy: 0.6439 - recall_15: 0.6439 - precision_15: 0.643 - ETA: 1:53 - loss: 0.6947 - accuracy: 0.6438 - recall_15: 0.6438 - precision_15: 0.643 - ETA: 1:53 - loss: 0.6947 - accuracy: 0.6437 - recall_15: 0.6437 - precision_15: 0.643 - ETA: 1:52 - loss: 0.6944 - accuracy: 0.6440 - recall_15: 0.6440 - precision_15: 0.644 - ETA: 1:52 - loss: 0.6971 - accuracy: 0.6427 - recall_15: 0.6427 - precision_15: 0.642 - ETA: 1:52 - loss: 0.6971 - accuracy: 0.6426 - recall_15: 0.6426 - precision_15: 0.642 - ETA: 1:51 - loss: 0.6964 - accuracy: 0.6434 - recall_15: 0.6434 - precision_15: 0.643 - ETA: 1:51 - loss: 0.6959 - accuracy: 0.6437 - recall_15: 0.6437 - precision_15: 0.643 - ETA: 1:51 - loss: 0.6953 - accuracy: 0.6444 - recall_15: 0.6444 - precision_15: 0.644 - ETA: 1:51 - loss: 0.6972 - accuracy: 0.6435 - recall_15: 0.6435 - precision_15: 0.643 - ETA: 1:50 - loss: 0.6969 - accuracy: 0.6438 - recall_15: 0.6438 - precision_15: 0.643 - ETA: 1:50 - loss: 0.6965 - accuracy: 0.6441 - recall_15: 0.6441 - precision_15: 0.644 - ETA: 1:50 - loss: 0.6963 - accuracy: 0.6444 - recall_15: 0.6444 - precision_15: 0.644 - ETA: 1:49 - loss: 0.6958 - accuracy: 0.6448 - recall_15: 0.6448 - precision_15: 0.644 - ETA: 1:49 - loss: 0.6964 - accuracy: 0.6447 - recall_15: 0.6447 - precision_15: 0.644 - ETA: 1:49 - loss: 0.6964 - accuracy: 0.6446 - recall_15: 0.6446 - precision_15: 0.644 - ETA: 1:49 - loss: 0.6957 - accuracy: 0.6453 - recall_15: 0.6453 - precision_15: 0.645 - ETA: 1:48 - loss: 0.6976 - accuracy: 0.6440 - recall_15: 0.6440 - precision_15: 0.644 - ETA: 1:48 - loss: 0.6973 - accuracy: 0.6443 - recall_15: 0.6443 - precision_15: 0.644 - ETA: 1:48 - loss: 0.6973 - accuracy: 0.6442 - recall_15: 0.6442 - precision_15: 0.644 - ETA: 1:47 - loss: 0.6970 - accuracy: 0.6433 - recall_15: 0.6433 - precision_15: 0.643 - ETA: 1:47 - loss: 0.6966 - accuracy: 0.6433 - recall_15: 0.6433 - precision_15: 0.643 - ETA: 1:47 - loss: 0.6966 - accuracy: 0.6432 - recall_15: 0.6432 - precision_15: 0.643 - ETA: 1:47 - loss: 0.6966 - accuracy: 0.6431 - recall_15: 0.6431 - precision_15: 0.643 - ETA: 1:46 - loss: 0.6966 - accuracy: 0.6430 - recall_15: 0.6430 - precision_15: 0.643 - ETA: 1:46 - loss: 0.6963 - accuracy: 0.6433 - recall_15: 0.6433 - precision_15: 0.643 - ETA: 1:46 - loss: 0.6955 - accuracy: 0.6440 - recall_15: 0.6440 - precision_15: 0.644 - ETA: 1:45 - loss: 0.6961 - accuracy: 0.6431 - recall_15: 0.6431 - precision_15: 0.643 ...
# 651/882 [=====================>........] - ETA: 1:32 - loss: 0.6882 - accuracy: 0.6572 - recall_15: 0.6572 - precision_15: 0.657 - ETA: 1:31 - loss: 0.6879 - accuracy: 0.6575 - recall_15: 0.6575 - precision_15: 0.657 - ETA: 1:31 - loss: 0.6880 - accuracy: 0.6574 - recall_15: 0.6574 - precision_15: 0.657 - ETA: 1:31 - loss: 0.6878 - accuracy: 0.6569 - recall_15: 0.6569 - precision_15: 0.656 - ETA: 1:30 - loss: 0.6874 - accuracy: 0.6568 - recall_15: 0.6568 - precision_15: 0.656 - ETA: 1:30 - loss: 0.6875 - accuracy: 0.6567 - recall_15: 0.6567 - precision_15: 0.656 - ETA: 1:30 - loss: 0.6878 - accuracy: 0.6563 - recall_15: 0.6563 - precision_15: 0.656 - ETA: 1:30 - loss: 0.6875 - accuracy: 0.6565 - recall_15: 0.6565 - precision_15: 0.656 - ETA: 1:29 - loss: 0.6879 - accuracy: 0.6561 - recall_15: 0.6561 - precision_15: 0.656 - ETA: 1:29 - loss: 0.6876 - accuracy: 0.6563 - recall_15: 0.6563 - precision_15: 0.656 - ETA: 1:29 - loss: 0.6876 - accuracy: 0.6562 - recall_15: 0.6562 - precision_15: 0.656 - ETA: 1:28 - loss: 0.6872 - accuracy: 0.6565 - recall_15: 0.6565 - precision_15: 0.656 - ETA: 1:28 - loss: 0.6869 - accuracy: 0.6567 - recall_15: 0.6567 - precision_15: 0.656 - ETA: 1:28 - loss: 0.6870 - accuracy: 0.6566 - recall_15: 0.6566 - precision_15: 0.656 - ETA: 1:28 - loss: 0.6863 - accuracy: 0.6572 - recall_15: 0.6572 - precision_15: 0.657 - ETA: 1:27 - loss: 0.6860 - accuracy: 0.6575 - recall_15: 0.6575 - precision_15: 0.657 - ETA: 1:27 - loss: 0.6860 - accuracy: 0.6574 - recall_15: 0.6574 - precision_15: 0.657 - ETA: 1:27 - loss: 0.6857 - accuracy: 0.6576 - recall_15: 0.6576 - precision_15: 0.657 - ETA: 1:27 - loss: 0.6854 - accuracy: 0.6579 - recall_15: 0.6579 - precision_15: 0.657 - ETA: 1:26 - loss: 0.6848 - accuracy: 0.6585 - recall_15: 0.6585 - precision_15: 0.658 - ETA: 1:26 - loss: 0.6841 - accuracy: 0.6591 - recall_15: 0.6591 - precision_15: 0.659 - ETA: 1:26 - loss: 0.6839 - accuracy: 0.6593 - recall_15: 0.6593 - precision_15: 0.659 - ETA: 1:25 - loss: 0.6836 - accuracy: 0.6596 - recall_15: 0.6596 - precision_15: 0.659 - ETA: 1:25 - loss: 0.6830 - accuracy: 0.6601 - recall_15: 0.6601 - precision_15: 0.660 - ETA: 1:25 - loss: 0.6830 - accuracy: 0.6600 - recall_15: 0.6600 - precision_15: 0.660 - ETA: 1:25 - loss: 0.6826 - accuracy: 0.6603 - recall_15: 0.6603 - precision_15: 0.660 - ETA: 1:24 - loss: 0.6820 - accuracy: 0.6609 - recall_15: 0.6609 - precision_15: 0.660 - ETA: 1:24 - loss: 0.6817 - accuracy: 0.6611 - recall_15: 0.6611 - precision_15: 0.661 - ETA: 1:24 - loss: 0.6818 - accuracy: 0.6610 - recall_15: 0.6610 - precision_15: 0.661 - ETA: 1:23 - loss: 0.6812 - accuracy: 0.6616 - recall_15: 0.6616 - precision_15: 0.661 - ETA: 1:23 - loss: 0.6806 - accuracy: 0.6621 - recall_15: 0.6621 - precision_15: 0.662 - ETA: 1:23 - loss: 0.6806 - accuracy: 0.6620 - recall_15: 0.6620 - precision_15: 0.662 - ETA: 1:23 - loss: 0.6818 - accuracy: 0.6623 - recall_15: 0.6623 - precision_15: 0.662 - ETA: 1:22 - loss: 0.6818 - accuracy: 0.6618 - recall_15: 0.6618 - precision_15: 0.661 - ETA: 1:22 - loss: 0.6815 - accuracy: 0.6617 - recall_15: 0.6617 - precision_15: 0.661 - ETA: 1:22 - loss: 0.6819 - accuracy: 0.6613 - recall_15: 0.6613 - precision_15: 0.661 - ETA: 1:21 - loss: 0.6819 - accuracy: 0.6612 - recall_15: 0.6612 - precision_15: 0.661 - ETA: 1:21 - loss: 0.6817 - accuracy: 0.6614 - recall_15: 0.6614 - precision_15: 0.661 - ETA: 1:21 - loss: 0.6814 - accuracy: 0.6616 - recall_15: 0.6616 - precision_15: 0.661 - ETA: 1:21 - loss: 0.6821 - accuracy: 0.6619 - recall_15: 0.6619 - precision_15: 0.661 - ETA: 1:20 - loss: 0.6818 - accuracy: 0.6621 - recall_15: 0.6621 - precision_15: 0.662 - ETA: 1:20 - loss: 0.6819 - accuracy: 0.6620 - recall_15: 0.6620 - precision_15: 0.662 - ETA: 1:20 - loss: 0.6815 - accuracy: 0.6626 - recall_15: 0.6626 - precision_15: 0.662 - ETA: 1:19 - loss: 0.6809 - accuracy: 0.6631 - recall_15: 0.6631 - precision_15: 0.663 - ETA: 1:19 - loss: 0.6806 - accuracy: 0.6630 - recall_15: 0.6630 - precision_15: 0.663 ...
# 746/882 [========================>.....] - ETA: 1:05 - loss: 0.6770 - accuracy: 0.6702 - recall_15: 0.6702 - precision_15: 0.670 - ETA: 1:05 - loss: 0.6768 - accuracy: 0.6704 - recall_15: 0.6704 - precision_15: 0.670 - ETA: 1:05 - loss: 0.6763 - accuracy: 0.6709 - recall_15: 0.6709 - precision_15: 0.670 - ETA: 1:04 - loss: 0.6773 - accuracy: 0.6708 - recall_15: 0.6708 - precision_15: 0.670 - ETA: 1:04 - loss: 0.6772 - accuracy: 0.6707 - recall_15: 0.6707 - precision_15: 0.670 - ETA: 1:04 - loss: 0.6769 - accuracy: 0.6709 - recall_15: 0.6709 - precision_15: 0.670 - ETA: 1:04 - loss: 0.6764 - accuracy: 0.6714 - recall_15: 0.6714 - precision_15: 0.671 - ETA: 1:03 - loss: 0.6760 - accuracy: 0.6716 - recall_15: 0.6716 - precision_15: 0.671 - ETA: 1:03 - loss: 0.6755 - accuracy: 0.6721 - recall_15: 0.6721 - precision_15: 0.672 - ETA: 1:03 - loss: 0.6753 - accuracy: 0.6723 - recall_15: 0.6723 - precision_15: 0.672 - ETA: 1:02 - loss: 0.6750 - accuracy: 0.6725 - recall_15: 0.6725 - precision_15: 0.672 - ETA: 1:02 - loss: 0.6754 - accuracy: 0.6721 - recall_15: 0.6721 - precision_15: 0.672 - ETA: 1:02 - loss: 0.6757 - accuracy: 0.6717 - recall_15: 0.6717 - precision_15: 0.671 - ETA: 1:02 - loss: 0.6756 - accuracy: 0.6719 - recall_15: 0.6719 - precision_15: 0.671 - ETA: 1:01 - loss: 0.6753 - accuracy: 0.6721 - recall_15: 0.6721 - precision_15: 0.672 - ETA: 1:01 - loss: 0.6756 - accuracy: 0.6720 - recall_15: 0.6720 - precision_15: 0.672 - ETA: 1:01 - loss: 0.6752 - accuracy: 0.6725 - recall_15: 0.6725 - precision_15: 0.672 - ETA: 1:00 - loss: 0.6748 - accuracy: 0.6729 - recall_15: 0.6729 - precision_15: 0.672 - ETA: 1:00 - loss: 0.6742 - accuracy: 0.6734 - recall_15: 0.6734 - precision_15: 0.673 - ETA: 1:00 - loss: 0.6743 - accuracy: 0.6733 - recall_15: 0.6733 - precision_15: 0.673 - ETA: 1:00 - loss: 0.6741 - accuracy: 0.6735 - recall_15: 0.6735 - precision_15: 0.673 - ETA: 59s - loss: 0.6742 - accuracy: 0.6734 - recall_15: 0.6734 - precision_15: 0.673 - ETA: 59s - loss: 0.6742 - accuracy: 0.6733 - recall_15: 0.6733 - precision_15: 0.67 - ETA: 59s - loss: 0.6756 - accuracy: 0.6729 - recall_15: 0.6729 - precision_15: 0.67 - ETA: 58s - loss: 0.6756 - accuracy: 0.6728 - recall_15: 0.6728 - precision_15: 0.67 - ETA: 58s - loss: 0.6754 - accuracy: 0.6730 - recall_15: 0.6730 - precision_15: 0.67 - ETA: 58s - loss: 0.6751 - accuracy: 0.6732 - recall_15: 0.6732 - precision_15: 0.67 - ETA: 58s - loss: 0.6746 - accuracy: 0.6733 - recall_15: 0.6733 - precision_15: 0.67 - ETA: 57s - loss: 0.6741 - accuracy: 0.6738 - recall_15: 0.6738 - precision_15: 0.67 - ETA: 57s - loss: 0.6735 - accuracy: 0.6743 - recall_15: 0.6743 - precision_15: 0.67 - ETA: 57s - loss: 0.6733 - accuracy: 0.6745 - recall_15: 0.6745 - precision_15: 0.67 - ETA: 56s - loss: 0.6731 - accuracy: 0.6747 - recall_15: 0.6747 - precision_15: 0.67 - ETA: 56s - loss: 0.6728 - accuracy: 0.6749 - recall_15: 0.6749 - precision_15: 0.67 - ETA: 56s - loss: 0.6725 - accuracy: 0.6750 - recall_15: 0.6750 - precision_15: 0.67 - ETA: 56s - loss: 0.6720 - accuracy: 0.6755 - recall_15: 0.6755 - precision_15: 0.67 - ETA: 55s - loss: 0.6723 - accuracy: 0.6754 - recall_15: 0.6754 - precision_15: 0.67 - ETA: 55s - loss: 0.6720 - accuracy: 0.6756 - recall_15: 0.6756 - precision_15: 0.67 - ETA: 55s - loss: 0.6719 - accuracy: 0.6758 - recall_15: 0.6758 - precision_15: 0.67 - ETA: 54s - loss: 0.6719 - accuracy: 0.6757 - recall_15: 0.6757 - precision_15: 0.67 - ETA: 54s - loss: 0.6716 - accuracy: 0.6758 - recall_15: 0.6758 - precision_15: 0.67 - ETA: 54s - loss: 0.6714 - accuracy: 0.6760 - recall_15: 0.6760 - precision_15: 0.67 - ETA: 54s - loss: 0.6721 - accuracy: 0.6759 - recall_15: 0.6759 - precision_15: 0.67 - ETA: 53s - loss: 0.6728 - accuracy: 0.6761 - recall_15: 0.6761 - precision_15: 0.67 - ETA: 53s - loss: 0.6725 - accuracy: 0.6763 - recall_15: 0.6763 - precision_15: 0.67 - ETA: 53s - loss: 0.6723 - accuracy: 0.6764 - recall_15: 0.6764 - precision_15: 0.67 - ETA: 52s - loss: 0.6720 - accuracy: 0.6766 - ...
# 841/882 [===========================>..] - ETA: 38s - loss: 0.6672 - accuracy: 0.6843 - recall_15: 0.6843 - precision_15: 0.68 - ETA: 38s - loss: 0.6676 - accuracy: 0.6840 - recall_15: 0.6840 - precision_15: 0.68 - ETA: 38s - loss: 0.6674 - accuracy: 0.6841 - recall_15: 0.6841 - precision_15: 0.68 - ETA: 37s - loss: 0.6676 - accuracy: 0.6840 - recall_15: 0.6840 - precision_15: 0.68 - ETA: 37s - loss: 0.6671 - accuracy: 0.6844 - recall_15: 0.6844 - precision_15: 0.68 - ETA: 37s - loss: 0.6670 - accuracy: 0.6843 - recall_15: 0.6843 - precision_15: 0.68 - ETA: 36s - loss: 0.6663 - accuracy: 0.6847 - recall_15: 0.6847 - precision_15: 0.68 - ETA: 36s - loss: 0.6665 - accuracy: 0.6846 - recall_15: 0.6846 - precision_15: 0.68 - ETA: 36s - loss: 0.6663 - accuracy: 0.6848 - recall_15: 0.6848 - precision_15: 0.68 - ETA: 36s - loss: 0.6656 - accuracy: 0.6852 - recall_15: 0.6852 - precision_15: 0.68 - ETA: 35s - loss: 0.6657 - accuracy: 0.6851 - recall_15: 0.6851 - precision_15: 0.68 - ETA: 35s - loss: 0.6658 - accuracy: 0.6850 - recall_15: 0.6850 - precision_15: 0.68 - ETA: 35s - loss: 0.6654 - accuracy: 0.6854 - recall_15: 0.6854 - precision_15: 0.68 - ETA: 34s - loss: 0.6649 - accuracy: 0.6858 - recall_15: 0.6858 - precision_15: 0.68 - ETA: 34s - loss: 0.6647 - accuracy: 0.6859 - recall_15: 0.6859 - precision_15: 0.68 - ETA: 34s - loss: 0.6644 - accuracy: 0.6861 - recall_15: 0.6861 - precision_15: 0.68 - ETA: 34s - loss: 0.6645 - accuracy: 0.6860 - recall_15: 0.6860 - precision_15: 0.68 - ETA: 33s - loss: 0.6639 - accuracy: 0.6864 - recall_15: 0.6864 - precision_15: 0.68 - ETA: 33s - loss: 0.6637 - accuracy: 0.6865 - recall_15: 0.6865 - precision_15: 0.68 - ETA: 33s - loss: 0.6632 - accuracy: 0.6869 - recall_15: 0.6869 - precision_15: 0.68 - ETA: 32s - loss: 0.6630 - accuracy: 0.6871 - recall_15: 0.6871 - precision_15: 0.68 - ETA: 32s - loss: 0.6629 - accuracy: 0.6870 - recall_15: 0.6870 - precision_15: 0.68 - ETA: 32s - loss: 0.6624 - accuracy: 0.6874 - recall_15: 0.6874 - precision_15: 0.68 - ETA: 32s - loss: 0.6622 - accuracy: 0.6875 - recall_15: 0.6875 - precision_15: 0.68 - ETA: 31s - loss: 0.6621 - accuracy: 0.6874 - recall_15: 0.6874 - precision_15: 0.68 - ETA: 31s - loss: 0.6622 - accuracy: 0.6873 - recall_15: 0.6873 - precision_15: 0.68 - ETA: 31s - loss: 0.6620 - accuracy: 0.6875 - recall_15: 0.6875 - precision_15: 0.68 - ETA: 30s - loss: 0.6620 - accuracy: 0.6873 - recall_15: 0.6873 - precision_15: 0.68 - ETA: 30s - loss: 0.6628 - accuracy: 0.6870 - recall_15: 0.6870 - precision_15: 0.68 - ETA: 30s - loss: 0.6629 - accuracy: 0.6869 - recall_15: 0.6869 - precision_15: 0.68 - ETA: 30s - loss: 0.6630 - accuracy: 0.6867 - recall_15: 0.6867 - precision_15: 0.68 - ETA: 29s - loss: 0.6626 - accuracy: 0.6871 - recall_15: 0.6871 - precision_15: 0.68 - ETA: 29s - loss: 0.6624 - accuracy: 0.6873 - recall_15: 0.6873 - precision_15: 0.68 - ETA: 29s - loss: 0.6622 - accuracy: 0.6874 - recall_15: 0.6874 - precision_15: 0.68 - ETA: 28s - loss: 0.6617 - accuracy: 0.6878 - recall_15: 0.6878 - precision_15: 0.68 - ETA: 28s - loss: 0.6615 - accuracy: 0.6880 - recall_15: 0.6880 - precision_15: 0.68 - ETA: 28s - loss: 0.6613 - accuracy: 0.6881 - recall_15: 0.6881 - precision_15: 0.68 - ETA: 28s - loss: 0.6617 - accuracy: 0.6880 - recall_15: 0.6880 - precision_15: 0.68 - ETA: 27s - loss: 0.6615 - accuracy: 0.6882 - recall_15: 0.6882 - precision_15: 0.68 - ETA: 27s - loss: 0.6613 - accuracy: 0.6883 - recall_15: 0.6883 - precision_15: 0.68 - ETA: 27s - loss: 0.6614 - accuracy: 0.6882 - recall_15: 0.6882 - precision_15: 0.68 - ETA: 26s - loss: 0.6608 - accuracy: 0.6886 - recall_15: 0.6886 - precision_15: 0.68 - ETA: 26s - loss: 0.6604 - accuracy: 0.6890 - recall_15: 0.6890 - precision_15: 0.68 - ETA: 26s - loss: 0.6600 - accuracy: 0.6894 - recall_15: 0.6894 - precision_15: 0.68 - ETA: 26s - loss: 0.6597 - accuracy: 0.6898 - recall_15: 0.6898 - precision_15: 0.68 - ETA: 25s - loss: 0.6601 - accuracy: 0.6894 - recall_15: 0.6894 - precision_15: 0.68 - E ...
# 882/882 [==============================] - ETA: 11s - loss: 0.6541 - accuracy: 0.6938 - recall_15: 0.6938 - precision_15: 0.69 - ETA: 11s - loss: 0.6542 - accuracy: 0.6937 - recall_15: 0.6937 - precision_15: 0.69 - ETA: 10s - loss: 0.6546 - accuracy: 0.6934 - recall_15: 0.6934 - precision_15: 0.69 - ETA: 10s - loss: 0.6551 - accuracy: 0.6933 - recall_15: 0.6933 - precision_15: 0.69 - ETA: 10s - loss: 0.6557 - accuracy: 0.6927 - recall_15: 0.6927 - precision_15: 0.69 - ETA: 10s - loss: 0.6558 - accuracy: 0.6926 - recall_15: 0.6926 - precision_15: 0.69 - ETA: 9s - loss: 0.6562 - accuracy: 0.6922 - recall_15: 0.6922 - precision_15: 0.6922 - ETA: 9s - loss: 0.6564 - accuracy: 0.6921 - recall_15: 0.6921 - precision_15: 0.692 - ETA: 9s - loss: 0.6560 - accuracy: 0.6925 - recall_15: 0.6925 - precision_15: 0.692 - ETA: 8s - loss: 0.6559 - accuracy: 0.6926 - recall_15: 0.6926 - precision_15: 0.692 - ETA: 8s - loss: 0.6557 - accuracy: 0.6925 - recall_15: 0.6925 - precision_15: 0.692 - ETA: 8s - loss: 0.6555 - accuracy: 0.6926 - recall_15: 0.6926 - precision_15: 0.692 - ETA: 8s - loss: 0.6554 - accuracy: 0.6927 - recall_15: 0.6927 - precision_15: 0.692 - ETA: 7s - loss: 0.6556 - accuracy: 0.6926 - recall_15: 0.6926 - precision_15: 0.692 - ETA: 7s - loss: 0.6551 - accuracy: 0.6930 - recall_15: 0.6930 - precision_15: 0.693 - ETA: 7s - loss: 0.6555 - accuracy: 0.6926 - recall_15: 0.6926 - precision_15: 0.692 - ETA: 6s - loss: 0.6550 - accuracy: 0.6930 - recall_15: 0.6930 - precision_15: 0.693 - ETA: 6s - loss: 0.6557 - accuracy: 0.6929 - recall_15: 0.6929 - precision_15: 0.692 - ETA: 6s - loss: 0.6553 - accuracy: 0.6933 - recall_15: 0.6933 - precision_15: 0.693 - ETA: 6s - loss: 0.6554 - accuracy: 0.6931 - recall_15: 0.6931 - precision_15: 0.693 - ETA: 5s - loss: 0.6552 - accuracy: 0.6933 - recall_15: 0.6933 - precision_15: 0.693 - ETA: 5s - loss: 0.6547 - accuracy: 0.6936 - recall_15: 0.6936 - precision_15: 0.693 - ETA: 5s - loss: 0.6548 - accuracy: 0.6935 - recall_15: 0.6935 - precision_15: 0.693 - ETA: 4s - loss: 0.6544 - accuracy: 0.6939 - recall_15: 0.6939 - precision_15: 0.693 - ETA: 4s - loss: 0.6543 - accuracy: 0.6940 - recall_15: 0.6940 - precision_15: 0.694 - ETA: 4s - loss: 0.6541 - accuracy: 0.6941 - recall_15: 0.6941 - precision_15: 0.694 - ETA: 4s - loss: 0.6537 - accuracy: 0.6945 - recall_15: 0.6945 - precision_15: 0.694 - ETA: 3s - loss: 0.6532 - accuracy: 0.6948 - recall_15: 0.6948 - precision_15: 0.694 - ETA: 3s - loss: 0.6531 - accuracy: 0.6949 - recall_15: 0.6949 - precision_15: 0.694 - ETA: 3s - loss: 0.6529 - accuracy: 0.6951 - recall_15: 0.6951 - precision_15: 0.695 - ETA: 2s - loss: 0.6529 - accuracy: 0.6950 - recall_15: 0.6950 - precision_15: 0.695 - ETA: 2s - loss: 0.6525 - accuracy: 0.6953 - recall_15: 0.6953 - precision_15: 0.695 - ETA: 2s - loss: 0.6525 - accuracy: 0.6952 - recall_15: 0.6952 - precision_15: 0.695 - ETA: 2s - loss: 0.6526 - accuracy: 0.6951 - recall_15: 0.6951 - precision_15: 0.695 - ETA: 1s - loss: 0.6525 - accuracy: 0.6952 - recall_15: 0.6952 - precision_15: 0.695 - ETA: 1s - loss: 0.6523 - accuracy: 0.6953 - recall_15: 0.6953 - precision_15: 0.695 - ETA: 1s - loss: 0.6519 - accuracy: 0.6957 - recall_15: 0.6957 - precision_15: 0.695 - ETA: 0s - loss: 0.6515 - accuracy: 0.6960 - recall_15: 0.6960 - precision_15: 0.696 - ETA: 0s - loss: 0.6513 - accuracy: 0.6961 - recall_15: 0.6961 - precision_15: 0.696 - ETA: 0s - loss: 0.6509 - accuracy: 0.6965 - recall_15: 0.6965 - precision_15: 0.696 - ETA: 0s - loss: 0.6509 - accuracy: 0.6964 - recall_15: 0.6964 - precision_15: 0.696 - 253s 287ms/step - loss: 0.6509 - accuracy: 0.6964 - recall_15: 0.6964 - precision_15: 0.6964
# Epoch 2/10
#  93/882 [==>...........................] - ETA: 0s - loss: 0.5080 - accuracy: 0.8000 - recall_15: 0.8000 - precision_15: 0.800 - ETA: 2:07 - loss: 0.5079 - accuracy: 0.8000 - recall_15: 0.8000 - precision_15: 0.800 - ETA: 2:49 - loss: 0.4059 - accuracy: 0.8667 - recall_15: 0.8667 - precision_15: 0.866 - ETA: 3:11 - loss: 0.4313 - accuracy: 0.8500 - recall_15: 0.8500 - precision_15: 0.850 - ETA: 3:24 - loss: 0.4497 - accuracy: 0.8400 - recall_15: 0.8400 - precision_15: 0.840 - ETA: 3:32 - loss: 0.4593 - accuracy: 0.8333 - recall_15: 0.8333 - precision_15: 0.833 - ETA: 3:38 - loss: 0.4976 - accuracy: 0.8000 - recall_15: 0.8000 - precision_15: 0.800 - ETA: 3:42 - loss: 0.4988 - accuracy: 0.8000 - recall_15: 0.8000 - precision_15: 0.800 - ETA: 3:45 - loss: 0.4997 - accuracy: 0.8000 - recall_15: 0.8000 - precision_15: 0.800 - ETA: 3:48 - loss: 0.4785 - accuracy: 0.8200 - recall_15: 0.8200 - precision_15: 0.820 - ETA: 3:50 - loss: 0.4610 - accuracy: 0.8364 - recall_15: 0.8364 - precision_15: 0.836 - ETA: 3:52 - loss: 0.5201 - accuracy: 0.7833 - recall_15: 0.7833 - precision_15: 0.783 - ETA: 3:54 - loss: 0.5191 - accuracy: 0.7846 - recall_15: 0.7846 - precision_15: 0.784 - ETA: 3:55 - loss: 0.5175 - accuracy: 0.7857 - recall_15: 0.7857 - precision_15: 0.785 - ETA: 3:56 - loss: 0.5168 - accuracy: 0.7867 - recall_15: 0.7867 - precision_15: 0.786 - ETA: 3:57 - loss: 0.5162 - accuracy: 0.7875 - recall_15: 0.7875 - precision_15: 0.787 - ETA: 3:57 - loss: 0.5133 - accuracy: 0.7882 - recall_15: 0.7882 - precision_15: 0.788 - ETA: 3:58 - loss: 0.5129 - accuracy: 0.7889 - recall_15: 0.7889 - precision_15: 0.788 - ETA: 3:59 - loss: 0.5126 - accuracy: 0.7895 - recall_15: 0.7895 - precision_15: 0.789 - ETA: 3:59 - loss: 0.5234 - accuracy: 0.7800 - recall_15: 0.7800 - precision_15: 0.780 - ETA: 3:59 - loss: 0.5226 - accuracy: 0.7810 - recall_15: 0.7810 - precision_15: 0.781 - ETA: 3:59 - loss: 0.5219 - accuracy: 0.7818 - recall_15: 0.7818 - precision_15: 0.781 - ETA: 3:59 - loss: 0.5287 - accuracy: 0.7739 - recall_15: 0.7739 - precision_15: 0.773 - ETA: 4:00 - loss: 0.5278 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.775 - ETA: 4:00 - loss: 0.5447 - accuracy: 0.7600 - recall_15: 0.7600 - precision_15: 0.760 - ETA: 4:00 - loss: 0.5442 - accuracy: 0.7615 - recall_15: 0.7615 - precision_15: 0.761 - ETA: 4:00 - loss: 0.5428 - accuracy: 0.7630 - recall_15: 0.7630 - precision_15: 0.763 - ETA: 4:00 - loss: 0.5780 - accuracy: 0.7500 - recall_15: 0.7500 - precision_15: 0.750 - ETA: 4:00 - loss: 0.5798 - accuracy: 0.7517 - recall_15: 0.7517 - precision_15: 0.751 - ETA: 4:00 - loss: 0.5774 - accuracy: 0.7533 - recall_15: 0.7533 - precision_15: 0.753 - ETA: 4:00 - loss: 0.5751 - accuracy: 0.7548 - recall_15: 0.7548 - precision_15: 0.754 - ETA: 4:00 - loss: 0.5730 - accuracy: 0.7563 - recall_15: 0.7563 - precision_15: 0.756 - ETA: 4:00 - loss: 0.5710 - accuracy: 0.7576 - recall_15: 0.7576 - precision_15: 0.757 - ETA: 4:00 - loss: 0.5626 - accuracy: 0.7647 - recall_15: 0.7647 - precision_15: 0.764 - ETA: 4:00 - loss: 0.5585 - accuracy: 0.7657 - recall_15: 0.7657 - precision_15: 0.765 - ETA: 4:00 - loss: 0.5770 - accuracy: 0.7611 - recall_15: 0.7611 - precision_15: 0.761 - ETA: 4:00 - loss: 0.5823 - accuracy: 0.7568 - recall_15: 0.7568 - precision_15: 0.756 - ETA: 4:00 - loss: 0.5861 - accuracy: 0.7526 - recall_15: 0.7526 - precision_15: 0.752 - ETA: 4:00 - loss: 0.5841 - accuracy: 0.7538 - recall_15: 0.7538 - precision_15: 0.753 - ETA: 4:00 - loss: 0.5822 - accuracy: 0.7550 - recall_15: 0.7550 - precision_15: 0.755 - ETA: 3:59 - loss: 0.5857 - accuracy: 0.7512 - recall_15: 0.7512 - precision_15: 0.751 - ETA: 3:59 - loss: 0.6044 - accuracy: 0.7429 - recall_15: 0.7429 - precision_15: 0.742 - ETA: 3:59 - loss: 0.6021 - accuracy: 0.7442 - recall_15: 0.7442 - precision_15: 0.744 - ETA: 3:59 - loss: 0.5996 - accuracy: 0.7455 - recall_15: 0.7455 - precision_15: 0.745 - ETA: 3:59 - loss: 0.6024 - accuracy: 0.7422 - recall_15: 0.7422 - precision_15: 0.742 - ...
# 186/882 [=====>........................] - ETA: 3:48 - loss: 0.5905 - accuracy: 0.7532 - recall_15: 0.7532 - precision_15: 0.753 - ETA: 3:47 - loss: 0.5873 - accuracy: 0.7558 - recall_15: 0.7558 - precision_15: 0.755 - ETA: 3:47 - loss: 0.5920 - accuracy: 0.7521 - recall_15: 0.7521 - precision_15: 0.752 - ETA: 3:47 - loss: 0.5895 - accuracy: 0.7546 - recall_15: 0.7546 - precision_15: 0.754 - ETA: 3:46 - loss: 0.5909 - accuracy: 0.7531 - recall_15: 0.7531 - precision_15: 0.753 - ETA: 3:46 - loss: 0.5900 - accuracy: 0.7535 - recall_15: 0.7535 - precision_15: 0.753 - ETA: 3:46 - loss: 0.5863 - accuracy: 0.7560 - recall_15: 0.7560 - precision_15: 0.756 - ETA: 3:46 - loss: 0.5856 - accuracy: 0.7564 - recall_15: 0.7564 - precision_15: 0.756 - ETA: 3:45 - loss: 0.5828 - accuracy: 0.7588 - recall_15: 0.7588 - precision_15: 0.758 - ETA: 3:45 - loss: 0.5842 - accuracy: 0.7573 - recall_15: 0.7573 - precision_15: 0.757 - ETA: 3:45 - loss: 0.5807 - accuracy: 0.7596 - recall_15: 0.7596 - precision_15: 0.759 - ETA: 3:45 - loss: 0.5772 - accuracy: 0.7619 - recall_15: 0.7619 - precision_15: 0.761 - ETA: 3:44 - loss: 0.5746 - accuracy: 0.7642 - recall_15: 0.7642 - precision_15: 0.764 - ETA: 3:44 - loss: 0.5719 - accuracy: 0.7664 - recall_15: 0.7664 - precision_15: 0.766 - ETA: 3:44 - loss: 0.5690 - accuracy: 0.7685 - recall_15: 0.7685 - precision_15: 0.768 - ETA: 3:44 - loss: 0.5680 - accuracy: 0.7688 - recall_15: 0.7688 - precision_15: 0.768 - ETA: 3:43 - loss: 0.5655 - accuracy: 0.7709 - recall_15: 0.7709 - precision_15: 0.770 - ETA: 3:43 - loss: 0.5623 - accuracy: 0.7730 - recall_15: 0.7730 - precision_15: 0.773 - ETA: 3:43 - loss: 0.5591 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.775 - ETA: 3:43 - loss: 0.5598 - accuracy: 0.7735 - recall_15: 0.7735 - precision_15: 0.773 - ETA: 3:42 - loss: 0.5612 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.771 - ETA: 3:42 - loss: 0.5581 - accuracy: 0.7739 - recall_15: 0.7739 - precision_15: 0.773 - ETA: 3:42 - loss: 0.5680 - accuracy: 0.7707 - recall_15: 0.7707 - precision_15: 0.770 - ETA: 3:41 - loss: 0.5694 - accuracy: 0.7692 - recall_15: 0.7692 - precision_15: 0.769 - ETA: 3:41 - loss: 0.5689 - accuracy: 0.7695 - recall_15: 0.7695 - precision_15: 0.769 - ETA: 3:41 - loss: 0.5664 - accuracy: 0.7714 - recall_15: 0.7714 - precision_15: 0.771 - ETA: 3:41 - loss: 0.5678 - accuracy: 0.7700 - recall_15: 0.7700 - precision_15: 0.770 - ETA: 3:40 - loss: 0.5710 - accuracy: 0.7669 - recall_15: 0.7669 - precision_15: 0.766 - ETA: 3:40 - loss: 0.5756 - accuracy: 0.7656 - recall_15: 0.7656 - precision_15: 0.765 - ETA: 3:40 - loss: 0.5750 - accuracy: 0.7659 - recall_15: 0.7659 - precision_15: 0.765 - ETA: 3:39 - loss: 0.5755 - accuracy: 0.7645 - recall_15: 0.7645 - precision_15: 0.764 - ETA: 3:39 - loss: 0.5754 - accuracy: 0.7632 - recall_15: 0.7632 - precision_15: 0.763 - ETA: 3:39 - loss: 0.5748 - accuracy: 0.7635 - recall_15: 0.7635 - precision_15: 0.763 - ETA: 3:39 - loss: 0.5753 - accuracy: 0.7622 - recall_15: 0.7622 - precision_15: 0.762 - ETA: 3:38 - loss: 0.5747 - accuracy: 0.7625 - recall_15: 0.7625 - precision_15: 0.762 - ETA: 3:38 - loss: 0.5718 - accuracy: 0.7643 - recall_15: 0.7643 - precision_15: 0.764 - ETA: 3:38 - loss: 0.5696 - accuracy: 0.7662 - recall_15: 0.7662 - precision_15: 0.766 - ETA: 3:38 - loss: 0.5727 - accuracy: 0.7664 - recall_15: 0.7664 - precision_15: 0.766 - ETA: 3:37 - loss: 0.5705 - accuracy: 0.7682 - recall_15: 0.7682 - precision_15: 0.768 - ETA: 3:37 - loss: 0.5717 - accuracy: 0.7669 - recall_15: 0.7669 - precision_15: 0.766 - ETA: 3:37 - loss: 0.5712 - accuracy: 0.7672 - recall_15: 0.7672 - precision_15: 0.767 - ETA: 3:36 - loss: 0.5707 - accuracy: 0.7644 - recall_15: 0.7644 - precision_15: 0.764 - ETA: 3:36 - loss: 0.5703 - accuracy: 0.7647 - recall_15: 0.7647 - precision_15: 0.764 - ETA: 3:36 - loss: 0.5756 - accuracy: 0.7620 - recall_15: 0.7620 - precision_15: 0.762 - ETA: 3:36 - loss: 0.5757 - accuracy: 0.7609 - recall_15: 0.7609 - precision_15: 0.760 ...
# ...
# 651/882 [=====================>........] - ETA: 1:38 - loss: 0.5348 - accuracy: 0.7742 - recall_15: 0.7742 - precision_15: 0.774 - ETA: 1:38 - loss: 0.5343 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.774 - ETA: 1:37 - loss: 0.5338 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.775 - ETA: 1:37 - loss: 0.5333 - accuracy: 0.7754 - recall_15: 0.7754 - precision_15: 0.775 - ETA: 1:37 - loss: 0.5332 - accuracy: 0.7755 - recall_15: 0.7755 - precision_15: 0.775 - ETA: 1:37 - loss: 0.5335 - accuracy: 0.7752 - recall_15: 0.7752 - precision_15: 0.775 - ETA: 1:36 - loss: 0.5339 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 1:36 - loss: 0.5338 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 1:36 - loss: 0.5346 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.774 - ETA: 1:35 - loss: 0.5346 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.774 - ETA: 1:35 - loss: 0.5345 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.774 - ETA: 1:35 - loss: 0.5340 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 1:34 - loss: 0.5344 - accuracy: 0.7744 - recall_15: 0.7744 - precision_15: 0.774 - ETA: 1:34 - loss: 0.5348 - accuracy: 0.7741 - recall_15: 0.7741 - precision_15: 0.774 - ETA: 1:34 - loss: 0.5347 - accuracy: 0.7742 - recall_15: 0.7742 - precision_15: 0.774 - ETA: 1:34 - loss: 0.5351 - accuracy: 0.7739 - recall_15: 0.7739 - precision_15: 0.773 - ETA: 1:33 - loss: 0.5351 - accuracy: 0.7739 - recall_15: 0.7739 - precision_15: 0.773 - ETA: 1:33 - loss: 0.5354 - accuracy: 0.7736 - recall_15: 0.7736 - precision_15: 0.773 - ETA: 1:33 - loss: 0.5354 - accuracy: 0.7737 - recall_15: 0.7737 - precision_15: 0.773 - ETA: 1:32 - loss: 0.5357 - accuracy: 0.7734 - recall_15: 0.7734 - precision_15: 0.773 - ETA: 1:32 - loss: 0.5352 - accuracy: 0.7737 - recall_15: 0.7737 - precision_15: 0.773 - ETA: 1:32 - loss: 0.5352 - accuracy: 0.7738 - recall_15: 0.7738 - precision_15: 0.773 - ETA: 1:31 - loss: 0.5351 - accuracy: 0.7738 - recall_15: 0.7738 - precision_15: 0.773 - ETA: 1:31 - loss: 0.5346 - accuracy: 0.7742 - recall_15: 0.7742 - precision_15: 0.774 - ETA: 1:31 - loss: 0.5342 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.774 - ETA: 1:30 - loss: 0.5341 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 1:30 - loss: 0.5341 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 1:30 - loss: 0.5340 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 1:30 - loss: 0.5339 - accuracy: 0.7748 - recall_15: 0.7748 - precision_15: 0.774 - ETA: 1:29 - loss: 0.5334 - accuracy: 0.7752 - recall_15: 0.7752 - precision_15: 0.775 - ETA: 1:29 - loss: 0.5338 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 1:29 - loss: 0.5338 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 1:28 - loss: 0.5337 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.775 - ETA: 1:28 - loss: 0.5332 - accuracy: 0.7753 - recall_15: 0.7753 - precision_15: 0.775 - ETA: 1:28 - loss: 0.5328 - accuracy: 0.7757 - recall_15: 0.7757 - precision_15: 0.775 - ETA: 1:27 - loss: 0.5331 - accuracy: 0.7754 - recall_15: 0.7754 - precision_15: 0.775 - ETA: 1:27 - loss: 0.5331 - accuracy: 0.7755 - recall_15: 0.7755 - precision_15: 0.775 - ETA: 1:27 - loss: 0.5335 - accuracy: 0.7752 - recall_15: 0.7752 - precision_15: 0.775 - ETA: 1:27 - loss: 0.5338 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 1:26 - loss: 0.5337 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 1:26 - loss: 0.5337 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.775 - ETA: 1:26 - loss: 0.5340 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 1:25 - loss: 0.5336 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.775 - ETA: 1:25 - loss: 0.5331 - accuracy: 0.7754 - recall_15: 0.7754 - precision_15: 0.775 - ETA: 1:25 - loss: 0.5331 - accuracy: 0.7755 - recall_15: 0.7755 - precision_15: 0.775 ...
# 745/882 [========================>.....] - ETA: 1:10 - loss: 0.5377 - accuracy: 0.7718 - recall_15: 0.7718 - precision_15: 0.771 - ETA: 1:10 - loss: 0.5372 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.772 - ETA: 1:09 - loss: 0.5376 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.771 - ETA: 1:09 - loss: 0.5378 - accuracy: 0.7716 - recall_15: 0.7716 - precision_15: 0.771 - ETA: 1:09 - loss: 0.5378 - accuracy: 0.7716 - recall_15: 0.7716 - precision_15: 0.771 - ETA: 1:08 - loss: 0.5374 - accuracy: 0.7720 - recall_15: 0.7720 - precision_15: 0.772 - ETA: 1:08 - loss: 0.5370 - accuracy: 0.7723 - recall_15: 0.7723 - precision_15: 0.772 - ETA: 1:08 - loss: 0.5369 - accuracy: 0.7724 - recall_15: 0.7724 - precision_15: 0.772 - ETA: 1:07 - loss: 0.5376 - accuracy: 0.7718 - recall_15: 0.7718 - precision_15: 0.771 - ETA: 1:07 - loss: 0.5375 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.771 - ETA: 1:07 - loss: 0.5377 - accuracy: 0.7716 - recall_15: 0.7716 - precision_15: 0.771 - ETA: 1:06 - loss: 0.5374 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.771 - ETA: 1:06 - loss: 0.5373 - accuracy: 0.7720 - recall_15: 0.7720 - precision_15: 0.772 - ETA: 1:06 - loss: 0.5380 - accuracy: 0.7714 - recall_15: 0.7714 - precision_15: 0.771 - ETA: 1:06 - loss: 0.5376 - accuracy: 0.7718 - recall_15: 0.7718 - precision_15: 0.771 - ETA: 1:05 - loss: 0.5379 - accuracy: 0.7715 - recall_15: 0.7715 - precision_15: 0.771 - ETA: 1:05 - loss: 0.5378 - accuracy: 0.7716 - recall_15: 0.7716 - precision_15: 0.771 - ETA: 1:05 - loss: 0.5374 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.771 - ETA: 1:04 - loss: 0.5377 - accuracy: 0.7716 - recall_15: 0.7716 - precision_15: 0.771 - ETA: 1:04 - loss: 0.5376 - accuracy: 0.7717 - recall_15: 0.7717 - precision_15: 0.771 - ETA: 1:04 - loss: 0.5375 - accuracy: 0.7717 - recall_15: 0.7717 - precision_15: 0.771 - ETA: 1:03 - loss: 0.5371 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.772 - ETA: 1:03 - loss: 0.5367 - accuracy: 0.7724 - recall_15: 0.7724 - precision_15: 0.772 - ETA: 1:03 - loss: 0.5367 - accuracy: 0.7724 - recall_15: 0.7724 - precision_15: 0.772 - ETA: 1:03 - loss: 0.5370 - accuracy: 0.7722 - recall_15: 0.7722 - precision_15: 0.772 - ETA: 1:02 - loss: 0.5369 - accuracy: 0.7722 - recall_15: 0.7722 - precision_15: 0.772 - ETA: 1:02 - loss: 0.5369 - accuracy: 0.7723 - recall_15: 0.7723 - precision_15: 0.772 - ETA: 1:02 - loss: 0.5365 - accuracy: 0.7726 - recall_15: 0.7726 - precision_15: 0.772 - ETA: 1:01 - loss: 0.5368 - accuracy: 0.7724 - recall_15: 0.7724 - precision_15: 0.772 - ETA: 1:01 - loss: 0.5368 - accuracy: 0.7724 - recall_15: 0.7724 - precision_15: 0.772 - ETA: 1:01 - loss: 0.5374 - accuracy: 0.7718 - recall_15: 0.7718 - precision_15: 0.771 - ETA: 1:00 - loss: 0.5374 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.771 - ETA: 1:00 - loss: 0.5374 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.771 - ETA: 1:00 - loss: 0.5372 - accuracy: 0.7720 - recall_15: 0.7720 - precision_15: 0.772 - ETA: 59s - loss: 0.5375 - accuracy: 0.7717 - recall_15: 0.7717 - precision_15: 0.771 - ETA: 59s - loss: 0.5371 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.77 - ETA: 59s - loss: 0.5371 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.77 - ETA: 59s - loss: 0.5367 - accuracy: 0.7724 - recall_15: 0.7724 - precision_15: 0.77 - ETA: 58s - loss: 0.5376 - accuracy: 0.7716 - recall_15: 0.7716 - precision_15: 0.77 - ETA: 58s - loss: 0.5382 - accuracy: 0.7711 - recall_15: 0.7711 - precision_15: 0.77 - ETA: 58s - loss: 0.5382 - accuracy: 0.7711 - recall_15: 0.7711 - precision_15: 0.77 - ETA: 57s - loss: 0.5381 - accuracy: 0.7711 - recall_15: 0.7711 - precision_15: 0.77 - ETA: 57s - loss: 0.5381 - accuracy: 0.7712 - recall_15: 0.7712 - precision_15: 0.77 - ETA: 57s - loss: 0.5377 - accuracy: 0.7715 - recall_15: 0.7715 - precision_15: 0.77 - ETA: 56s - loss: 0.5384 - accuracy: 0.7710 - recall_15: 0.7710 - precision_15: 0.77 - ETA: 56s - loss: 0 ...
# 840/882 [===========================>..] - ETA: 41s - loss: 0.5363 - accuracy: 0.7727 - recall_15: 0.7727 - precision_15: 0.77 - ETA: 41s - loss: 0.5363 - accuracy: 0.7727 - recall_15: 0.7727 - precision_15: 0.77 - ETA: 40s - loss: 0.5366 - accuracy: 0.7725 - recall_15: 0.7725 - precision_15: 0.77 - ETA: 40s - loss: 0.5372 - accuracy: 0.7720 - recall_15: 0.7720 - precision_15: 0.77 - ETA: 40s - loss: 0.5371 - accuracy: 0.7720 - recall_15: 0.7720 - precision_15: 0.77 - ETA: 40s - loss: 0.5367 - accuracy: 0.7723 - recall_15: 0.7723 - precision_15: 0.77 - ETA: 39s - loss: 0.5367 - accuracy: 0.7723 - recall_15: 0.7723 - precision_15: 0.77 - ETA: 39s - loss: 0.5371 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.77 - ETA: 39s - loss: 0.5370 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.77 - ETA: 38s - loss: 0.5370 - accuracy: 0.7722 - recall_15: 0.7722 - precision_15: 0.77 - ETA: 38s - loss: 0.5379 - accuracy: 0.7714 - recall_15: 0.7714 - precision_15: 0.77 - ETA: 38s - loss: 0.5382 - accuracy: 0.7712 - recall_15: 0.7712 - precision_15: 0.77 - ETA: 37s - loss: 0.5381 - accuracy: 0.7712 - recall_15: 0.7712 - precision_15: 0.77 - ETA: 37s - loss: 0.5378 - accuracy: 0.7715 - recall_15: 0.7715 - precision_15: 0.77 - ETA: 37s - loss: 0.5377 - accuracy: 0.7716 - recall_15: 0.7716 - precision_15: 0.77 - ETA: 37s - loss: 0.5373 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.77 - ETA: 36s - loss: 0.5373 - accuracy: 0.7719 - recall_15: 0.7719 - precision_15: 0.77 - ETA: 36s - loss: 0.5376 - accuracy: 0.7717 - recall_15: 0.7717 - precision_15: 0.77 - ETA: 36s - loss: 0.5375 - accuracy: 0.7717 - recall_15: 0.7717 - precision_15: 0.77 - ETA: 35s - loss: 0.5375 - accuracy: 0.7718 - recall_15: 0.7718 - precision_15: 0.77 - ETA: 35s - loss: 0.5374 - accuracy: 0.7718 - recall_15: 0.7718 - precision_15: 0.77 - ETA: 35s - loss: 0.5371 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.77 - ETA: 34s - loss: 0.5370 - accuracy: 0.7721 - recall_15: 0.7721 - precision_15: 0.77 - ETA: 34s - loss: 0.5367 - accuracy: 0.7724 - recall_15: 0.7724 - precision_15: 0.77 - ETA: 34s - loss: 0.5363 - accuracy: 0.7727 - recall_15: 0.7727 - precision_15: 0.77 - ETA: 33s - loss: 0.5360 - accuracy: 0.7730 - recall_15: 0.7730 - precision_15: 0.77 - ETA: 33s - loss: 0.5359 - accuracy: 0.7731 - recall_15: 0.7731 - precision_15: 0.77 - ETA: 33s - loss: 0.5362 - accuracy: 0.7728 - recall_15: 0.7728 - precision_15: 0.77 - ETA: 33s - loss: 0.5361 - accuracy: 0.7729 - recall_15: 0.7729 - precision_15: 0.77 - ETA: 32s - loss: 0.5358 - accuracy: 0.7732 - recall_15: 0.7732 - precision_15: 0.77 - ETA: 32s - loss: 0.5357 - accuracy: 0.7732 - recall_15: 0.7732 - precision_15: 0.77 - ETA: 32s - loss: 0.5354 - accuracy: 0.7735 - recall_15: 0.7735 - precision_15: 0.77 - ETA: 31s - loss: 0.5353 - accuracy: 0.7735 - recall_15: 0.7735 - precision_15: 0.77 - ETA: 31s - loss: 0.5353 - accuracy: 0.7736 - recall_15: 0.7736 - precision_15: 0.77 - ETA: 31s - loss: 0.5349 - accuracy: 0.7738 - recall_15: 0.7738 - precision_15: 0.77 - ETA: 30s - loss: 0.5346 - accuracy: 0.7741 - recall_15: 0.7741 - precision_15: 0.77 - ETA: 30s - loss: 0.5349 - accuracy: 0.7739 - recall_15: 0.7739 - precision_15: 0.77 - ETA: 30s - loss: 0.5345 - accuracy: 0.7742 - recall_15: 0.7742 - precision_15: 0.77 - ETA: 29s - loss: 0.5344 - accuracy: 0.7742 - recall_15: 0.7742 - precision_15: 0.77 - ETA: 29s - loss: 0.5344 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.77 - ETA: 29s - loss: 0.5343 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.77 - ETA: 29s - loss: 0.5343 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.77 - ETA: 28s - loss: 0.5345 - accuracy: 0.7741 - recall_15: 0.7741 - precision_15: 0.77 - ETA: 28s - loss: 0.5354 - accuracy: 0.7734 - recall_15: 0.7734 - precision_15: 0.77 - ETA: 28s - loss: 0.5354 - accuracy: 0.7734 - recall_15: 0.7734 - precision_15: 0.77 - ETA: 27s - loss: 0.5350 - accuracy: 0.7737 - recall_15: 0.7737 - precision_15: 0.77 - E ...
# 882/882 [==============================] - ETA: 12s - loss: 0.5329 - accuracy: 0.7755 - recall_15: 0.7755 - precision_15: 0.77 - ETA: 12s - loss: 0.5325 - accuracy: 0.7758 - recall_15: 0.7758 - precision_15: 0.77 - ETA: 11s - loss: 0.5328 - accuracy: 0.7756 - recall_15: 0.7756 - precision_15: 0.77 - ETA: 11s - loss: 0.5328 - accuracy: 0.7756 - recall_15: 0.7756 - precision_15: 0.77 - ETA: 11s - loss: 0.5327 - accuracy: 0.7756 - recall_15: 0.7756 - precision_15: 0.77 - ETA: 11s - loss: 0.5330 - accuracy: 0.7754 - recall_15: 0.7754 - precision_15: 0.77 - ETA: 10s - loss: 0.5336 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.77 - ETA: 10s - loss: 0.5335 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.77 - ETA: 10s - loss: 0.5335 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.77 - ETA: 9s - loss: 0.5338 - accuracy: 0.7748 - recall_15: 0.7748 - precision_15: 0.7748 - ETA: 9s - loss: 0.5337 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 9s - loss: 0.5334 - accuracy: 0.7751 - recall_15: 0.7751 - precision_15: 0.775 - ETA: 8s - loss: 0.5334 - accuracy: 0.7751 - recall_15: 0.7751 - precision_15: 0.775 - ETA: 8s - loss: 0.5336 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 8s - loss: 0.5336 - accuracy: 0.7750 - recall_15: 0.7750 - precision_15: 0.775 - ETA: 7s - loss: 0.5341 - accuracy: 0.7745 - recall_15: 0.7745 - precision_15: 0.774 - ETA: 7s - loss: 0.5341 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.774 - ETA: 7s - loss: 0.5345 - accuracy: 0.7744 - recall_15: 0.7744 - precision_15: 0.774 - ETA: 7s - loss: 0.5350 - accuracy: 0.7739 - recall_15: 0.7739 - precision_15: 0.773 - ETA: 6s - loss: 0.5353 - accuracy: 0.7737 - recall_15: 0.7737 - precision_15: 0.773 - ETA: 6s - loss: 0.5352 - accuracy: 0.7738 - recall_15: 0.7738 - precision_15: 0.773 - ETA: 6s - loss: 0.5352 - accuracy: 0.7738 - recall_15: 0.7738 - precision_15: 0.773 - ETA: 5s - loss: 0.5348 - accuracy: 0.7740 - recall_15: 0.7740 - precision_15: 0.774 - ETA: 5s - loss: 0.5348 - accuracy: 0.7741 - recall_15: 0.7741 - precision_15: 0.774 - ETA: 5s - loss: 0.5345 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.774 - ETA: 4s - loss: 0.5342 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.774 - ETA: 4s - loss: 0.5338 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 4s - loss: 0.5338 - accuracy: 0.7749 - recall_15: 0.7749 - precision_15: 0.774 - ETA: 3s - loss: 0.5340 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 3s - loss: 0.5340 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 3s - loss: 0.5343 - accuracy: 0.7745 - recall_15: 0.7745 - precision_15: 0.774 - ETA: 3s - loss: 0.5345 - accuracy: 0.7743 - recall_15: 0.7743 - precision_15: 0.774 - ETA: 2s - loss: 0.5342 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.774 - ETA: 2s - loss: 0.5347 - accuracy: 0.7741 - recall_15: 0.7741 - precision_15: 0.774 - ETA: 2s - loss: 0.5347 - accuracy: 0.7742 - recall_15: 0.7742 - precision_15: 0.774 - ETA: 1s - loss: 0.5344 - accuracy: 0.7744 - recall_15: 0.7744 - precision_15: 0.774 - ETA: 1s - loss: 0.5340 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 1s - loss: 0.5343 - accuracy: 0.7745 - recall_15: 0.7745 - precision_15: 0.774 - ETA: 0s - loss: 0.5340 - accuracy: 0.7747 - recall_15: 0.7747 - precision_15: 0.774 - ETA: 0s - loss: 0.5342 - accuracy: 0.7745 - recall_15: 0.7745 - precision_15: 0.774 - ETA: 0s - loss: 0.5342 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.774 - ETA: 0s - loss: 0.5341 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.774 - 269s 305ms/step - loss: 0.5341 - accuracy: 0.7746 - recall_15: 0.7746 - precision_15: 0.7746

# %%
ypred = list()
for i in range(X_test.shape[0]):
    yhat = model.predict(np.expand_dims(X_test[i], axis=0))
    ypred.append(np.argmax(yhat))

# %%
print(confusion_matrix(ypred, Y_test))
print(accuracy_score(ypred, Y_test))
# Out:
# [[411  30]
#  [ 47   4]]
# 0.8434959349593496
