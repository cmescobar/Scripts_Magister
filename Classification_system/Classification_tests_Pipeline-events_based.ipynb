# %%
# Imports
import os, warnings
import librosa
import numpy as np
import tensorflow as tf
import soundfile as sf
import matplotlib.pyplot as plt
from ast import literal_eval
from scipy.io import wavfile
from scipy import signal, fftpack
from collections import defaultdict
from testing_functions import test_hss
from process_functions import preprocessing_audio
from utils import find_and_open_audio, signal_segmentation, get_resp_segments
from heart_sound_segmentation.filter_and_sampling import downsampling_signal, \
    upsampling_signal
from respiratory_sound_classification.respiratory_sound_management import \
    get_label_filename
from source_separation.descriptor_functions import get_spectrogram
from IPython.display import Audio
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn import preprocessing, linear_model, svm
from sklearn.metrics import confusion_matrix, accuracy_score
from pybalu.feature_selection import sfs
from pybalu.feature_transformation import normalize

# %% [markdown]
# # Funciones previas

# %%
# Funciones de características
def get_filterbanks(N, samplerate, freq_lim, n_filters, norm_exp=1,
                    scale_type='mel', filter_type='triangular',
                    norm_filters=True, plot_filterbank=False):
    '''Función que permite obtener un banco de filtros linealmente
    espaciados o espaciados en frecuencia de mel para calcular
    coeficientes cepstrales.
    
    Parameters
    ----------
    N : ndarray
        Largo de la señal.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_filters : int
        Cantidad de filtros a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''
    def _freq_to_bin(f):
        # Definición del bin correspondiente en la definición
        # del intervalo de cálculo. Se usa (N - 1) ya que los bins
        # se definen entre 0 y (N - 1) (largo N)
        return np.rint(f / samplerate * (N - 1)).astype(int)
    
    
    def _triangular_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i] + 1] = \
                np.linspace(0, 1, abs(bins_points[i] - bins_points[i - 1] + 1))
            
            # Tramo descendente del filtro triangular
            filter_bank[i - 1][bins_points[i]:bins_points[i + 1] + 1] = \
                np.linspace(1, 0, abs(bins_points[i + 1] - bins_points[i] + 1))
            
        return filter_bank
    
    
    def _hanning_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i + 1] + 1] = \
                np.hanning(abs(bins_points[i + 1] - bins_points[i - 1] + 1))
        
        return filter_bank
    
    
    def _squared_filter(bins_points):
        # Definición del banco de filtros
        filter_bank = np.zeros((n_filters, N))
        
        for i in range(1, n_filters + 1):
            # Tramo ascendente del filtro triangular
            filter_bank[i - 1][bins_points[i - 1]:bins_points[i + 1] + 1] = 1
        
        return filter_bank
    
    
    def _norm_filterbank(filter_bank):
        # Definición del banco de filtros de salida
        filter_bank_out = np.zeros((n_filters, N))
        
        # Normalizar los filtros a energía 1
        for i in range(n_filters):
            filter_bank_out[i] = filter_bank[i] / \
                                 sum(filter_bank[i] ** norm_exp)
            
        return filter_bank_out
    
    
    # Definición de los bines en base a las frecuencias de cada filtro
    if scale_type == 'linear':
        # Definición de las "n_filters" frecuencias equiespaciadas entre
        # 0 y freq_lim. Se le agregan 2 puntos (0 y el freq_lim) ya que se 
        # necesitan para definir los límites de los filtros.
        freqs = np.arange(0, (n_filters + 1) + 1) * freq_lim / (n_filters + 1)
    
    
    elif scale_type == 'mel':
        # Definición del límite en frecuencias de mel (para no pasarse del
        # freq_lim al devolverse)
        mel_freq_lim = 2595 * np.log10(1 + freq_lim / 700)
        
        # Definición de las "n_filters" frecuencias espaciadas en escala mel 
        # entre 0 y freq_lim. Se le agregan 2 puntos (0 y el freq_lim) ya 
        # que se necesitan para definir los límites de los filtros.
        mel_freqs = np.arange(0, (n_filters + 1) + 1) * mel_freq_lim / (n_filters + 1)
        
        # Transformando de intervalos equi espaciados usando la escala
        # de mel. Es necesario hacer la transformación inversa ya que
        # en este caso se dice que lo equi espaciado viene de mel
        freqs = 700 * (10 ** (mel_freqs / 2595) - 1)
    
    else:
        raise Exception('Opción de tipo de coeficiente cepstral no válido.')
    
    
    # Transformando a bins
    bins_to = _freq_to_bin(freqs)
    
    
    # Obtención del banco de filtros
    if filter_type == 'triangular':
        filter_bank = _triangular_filter(bins_to)
        
    if filter_type == 'hanning':
        filter_bank = _hanning_filter(bins_to)
    
    elif filter_type == 'squared':
        filter_bank = _squared_filter(bins_to)
    
    # Normalizar por la energía de la señal
    if norm_filters:
        filter_bank = _norm_filterbank(filter_bank)
    
    
    # Gráfico del banco de filtros
    if plot_filterbank:
        plt.figure()
        
        # Definición del vector de frecuencias
        f_plot = np.arange(N) * samplerate / N
        
        for i in range(n_filters):
            plt.plot(filter_bank[i])
            # plt.plot(f_plot, filter_bank[i])

        for i in bins_to:
            # plt.axvline(i * samplerate / N, c='silver', linestyle=':')
            plt.axvline(i, c='silver', linestyle=':')
            
        # plt.xlim([0, freq_lim])
        plt.xlim([0, bins_to[-1]])
        plt.show()
    
    
    return filter_bank


def get_cepstral_coefficients(signal_in, samplerate, spectrogram_params,
                              freq_lim, n_filters, n_coefs, scale_type='mel', 
                              filter_type='triangular', inverse_func='dct', 
                              norm_filters=True, plot_filterbank=False, 
                              power=2):
    '''Función que permite obtener los coeficientes cepstrales a partir de 
    un banco de filtros.
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_coefs : int
        Cantidad de coeficientes a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''    
    # Definición de la cantidad de puntos a considerar
    filter_bank = get_filterbanks(spectrogram_params['N'], samplerate, 
                                  freq_lim=freq_lim, n_filters=n_filters, 
                                  scale_type=scale_type, 
                                  filter_type=filter_type,
                                  norm_filters=norm_filters, 
                                  plot_filterbank=plot_filterbank)
    
    # Obtener el espectrograma de la señal
    t, f, S = get_spectrogram(signal_in, samplerate, N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=True)
    
    # Definición del espectro de la señal
    energy_spectrum = np.abs(S) ** power
    
    # Se aplica el banco de filtros sobre el espectro de la señal
    energy_coefs = np.dot(filter_bank, energy_spectrum)
    
    # Aplicando el logaritmo
    energy_coefs = np.log(energy_coefs + 1e-10)
    
    # Calculando los coeficientes cepstrales
    if inverse_func == 'dct':
        cepstral_coefs = fftpack.dct(energy_coefs, norm='ortho', axis=0)
    elif inverse_func == 'idft':
        cepstral_coefs = np.fft.ifft(energy_coefs, axis=-1).real
    else:
        raise Exception('Opción de tipo de función inversa no válida.')
    
    
    return cepstral_coefs[:n_coefs]


def get_bands_coefficients(signal_in, samplerate, spectrogram_params,
                           freq_lim, n_coefs, scale_type='mel', 
                           filter_type='triangular', norm_filters=True, 
                           plot_filterbank=False, 
                           power=2):
    '''Función que permite obtener la energía por bandas de frecuencia
    a partir de un banco de filtros.
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    freq_lim : float
        Frecuencia límite para calcular los coeficientes cepstrales.
    n_coefs : int
        Cantidad de coeficientes a obtener.
    scale_type : {'mel', 'linear'}, optional
        Tipo de espaciado entre los bancos de filtros para el cálculo
        de los coeficientes cepstrales. Por defecto es 'mel' (MFCC). 
    filter_type : {'triangular', 'hanning', 'squared'}, optional
        Forma del filtro a utilizar para el cálculo de la energía en 
        cada banda. Por defecto es 'triangular'.
    inverse_func : {'dct', 'idft'}, optional
        Función a utilizar para obtener los coeficientes cepstrales.
        Por defecto es 'dct'.
    plot_filterbank : bool, optional
        Booleano que indica si se grafica el banco de filtros. Por 
        defecto es False.
    
    References
    ----------
    [1] http://practicalcryptography.com/miscellaneous/machine-learning/
        guide-mel-frequency-cepstral-coefficients-mfccs/
    [2] Xuedong Huang, Alex Acero, Hsiao-Wuen Hon - Spoken Language 
        Processing A Guide to Theory, Algorithm and System 
        Development-Prentice Hall PTR (2001)
    '''    
    # Definición de la cantidad de puntos a considerar
    filter_bank = get_filterbanks(spectrogram_params['N'], samplerate, 
                                  freq_lim=freq_lim, 
                                  n_coefs=n_coefs, scale_type=scale_type, 
                                  filter_type=filter_type,
                                  norm_filters=norm_filters, 
                                  plot_filterbank=plot_filterbank)
    
    # Obtener el espectrograma de la señal
    t, f, S = get_spectrogram(signal_in, samplerate, N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=True)
    
    # Definición del espectro de la señal
    energy_spectrum = np.abs(S) ** power
    
    # Se aplica el banco de filtros sobre el espectro de la señal
    energy_coefs = np.dot(filter_bank, energy_spectrum)
    
    return energy_coefs


def get_energy_bands(signal_in, samplerate, spectrogram_params, 
                     fmin=0, fmax=1000, fband=20, power=2):
    '''Función que permite definir un espectrograma en bandas de 
    energía.
    
    
    Parameters
    ----------
    signal_in : ndarray
        Señal de entrada.
    samplerate : float
        Tasa de muestreo de la señal de entrada.
    spectrogram_params : dict
        Parámetros del espectrograma.
    fmin : float, optional
        Frecuencia mínima a considerar en el intervalo de interés.
        Por defecto es 0.
    fmax : float, optional
        Frecuencia máxima a considerar en el intervalo de interés.
        Este valor no puede mayor a samplerate / 2. Por defecto 
        es 1000.
    fband : float, optional
        Ancho de cada banda de frecuencia entre fmin y fmax. Por 
        defecto es 20.
    power : float, optional
        Exponente con el que se calcula la energía.
    
    Returns
    -------
    energy_S : ndarray
        Bandas de energía a través del tiempo (formato 
        espectrograma) con dimensión (#bandas x #bins de tiempo 
        del espectrograma).     
    '''
    # Obtener el espectrograma
    t, f, S = get_spectrogram(signal_in, samplerate, 
                              N=spectrogram_params['N'], 
                              padding=spectrogram_params['padding'], 
                              repeat=spectrogram_params['repeat'], 
                              noverlap=spectrogram_params['noverlap'], 
                              window=spectrogram_params['window'], 
                              whole=False)
    
    # Definición de los intervalos
    f_intervals = np.arange(fmin, fmax, fband)

    # Definición de la lista que almacenará los datos
    energy_band = np.zeros(len(f_intervals) - 1)
    energy_S = np.zeros((len(energy_band), len(t)))

    for i in range(len(f_intervals) - 1):
        lower_lim = f_intervals[i]
        upper_lim = f_intervals[i + 1]

        # Definición de los índices de interés
        indexes = np.where((lower_lim <= f) & (f <= upper_lim))[0]

        # Definiendo el valor
        energy_S[i] = np.sum(abs(S[indexes,:]) ** power, axis=0)
    
    return energy_S

# %%
def _conditioning_signal(signal_in, samplerate, samplerate_to):
    # Acondicionando en caso de que no tenga samplerate de 1000 Hz.
    if samplerate < samplerate_to:
        print(f'Upsampling de la señal de fs = {samplerate} Hz '
              f'a fs = {samplerate_to} Hz.') 
        new_rate = samplerate_to           
        audio_to = upsampling_signal(signal_in, samplerate, new_samplerate=new_rate)

    elif samplerate > samplerate_to:
        print(f'Downsampling de la señal de fs = {samplerate} Hz '
              f'a fs = {samplerate_to} Hz.')
        new_rate, audio_to = downsampling_signal(signal_in, samplerate, 
                                                 freq_pass=samplerate_to//2-100, 
                                                 freq_stop=samplerate_to//2)

    else:
        print(f'Samplerate adecuado a fs = {samplerate} Hz.')
        audio_to = signal_in
        new_rate = samplerate_to

    # Mensaje para asegurar
    print(f'Señal acondicionada a {new_rate} Hz para la separación de fuentes.')

    # Asegurándose de que el largo de la señal sea par
    if len(audio_to) % 2 != 0:
        audio_to = np.concatenate((audio_to, [0]))

    return audio_to, new_rate

# %%
def pybalu_clean(features, tol=1e-8, show=False):
    n_features = features.shape[1]
    ip = np.ones(n_features, dtype=int)

    # cleaning correlated features
    warnings.filterwarnings('ignore')
    C = np.abs(np.corrcoef(features, rowvar=False))
    idxs = np.vstack(np.where(C > .99))
    
    # remove pairs of same feature ( feature i will have a correlation of 1 whit itself )
    idxs = idxs[:, idxs[0,:] != idxs[1,:]]
    
    # remove correlated features
    if idxs.size > 0:
        ip[np.max(idxs, 0)] = 0
    
    # remove constant features
    s = features.std(axis=0, ddof=1)
    ip[s < tol] = 0
    p = np.where(ip.astype(bool))[0]

    if show:
        print(f'Clean: number of features reduced from {n_features} to {p.size}.')

    return p

# %% [markdown]
# # Parámetros de los descriptores

# %%
# Parámetros de los espectrogramas generales
N = 1024
noverlap = int(0.9 * N)
spec_params = {'N': N, 'noverlap': noverlap, 'window': 'hann', 
               'padding': 0, 'repeat': 0}

# Parámetros MFCC
mfcc_params = {'n_mfcc': 50, 'n_filters': 50, 'spec_params': spec_params,
               'freq_lim': 2000, 'norm_filters': True, 'power': 2}
lfcc_params = {'n_mfcc': 50, 'n_filters': 50, 'spec_params': spec_params,
               'freq_lim': 2000, 'norm_filters': True, 'power': 2}
energy_params = {'spec_params': spec_params, 'fmin': 0, 'fmax': 1000, 
                 'fband': 20}

# %%
# Dirección de la base de datos
db_original = 'C:/Users/Chris/Desktop/Scripts_Magister/Respiratory_Sound_Database/audio_and_txt_files'
db_folder = 'preprocessed_signals'

# %% [markdown]
# # Stratify

# %%
# Definición de la carpeta a buscar los archivos
train_test_folder = '/'.join(db_original.split('/')[:-1])
file_traintest = f'{train_test_folder}/ICBHI_challenge_train_test.txt'


def train_test_filebased(filename, db_root, db_folder):
    # Definición de las listas de entrenamiento y testeo
    train_list = list()
    test_list = list()

    # Definición de la lista de nombres de entrenamiento y testeo
    with open(filename, 'r', encoding='utf8') as file:
        for line in file:
            # Obteniendo los datos de cada línea
            data = line.strip().split('\t')

            # Controlar que no se utilicen sonidos traqueales
            if 'Tc' in data[0]:
                continue

            # Definición del nombre del archivo de audio
            filename_audio = f'{db_root}/{data[0]}.wav'

            # Obteniendo el samplerate del archivo original
            try:
                sr, _ = wavfile.read(f'{filename_audio}')
            except:
                _, sr = sf.read(f'{filename_audio}')

            if data[1] == 'train':
                train_list.append((f'{db_folder}/{data[0]}_{sr}'))
            elif data[1] == 'test':
                test_list.append((f'{db_folder}/{data[0]}_{sr}'))
                
    return train_list, test_list


# Definición de las listas de entrenamiento y testeo
train_list, test_list = \
        train_test_filebased(file_traintest, db_original, db_folder)

# %%
def get_label_filename_ML(filename, time_array):
    '''Función que permite retornar las etiquetas correspondientes 
    a cada sonido respiratorio.
    
    Parameters
    ----------
    filename : str
        Nombre del archivo de interés (solo nombre).
    time_array : float
        Eje temporal del espectrograma para el cálculo de las 
        variables.

    Returns
    -------
    Y_wheeze : ndarray
        Señal que contiene la ubicación de los wheezes.
    Y_crackl : ndarray
        Señal que contiene la ubicación de los crackles.
    '''
    # Definición de la carpeta de base de datos de los eventos
    db_events = 'C:/Users/Chris/Desktop/Scripts_Magister/'\
                'Respiratory_Sound_Database/events'
    
    # Definición de las etiquetas para cada caso
    Y_wheeze = np.zeros(len(time_array), dtype=np.int8)
    Y_crackl = np.zeros(len(time_array), dtype=np.int8)
        
    with open(f'{db_events}/{filename}_events.txt', 'r', 
              encoding='utf8') as file:
        # Definición la información de los intervalos
        intervals_info = list()
        
        # Obteniendo la información de cada segmento
        for line in file:
            # Obteniendo la información de la línea
            data = line.strip().split('\t')
            
            if data == ['']:
                continue
            
            # Definición de los límites inferior y superior
            lower = float(data[0])
            upper = float(data[1])
            
            # Agregando los datos etiquetas
            intervals_info.append(((lower, upper), data[2]))
    
    # Etiquetando cada índice de tiempo
    for num, t in enumerate(time_array):
        # Revisando cada intervalo para ver si el tiempo "t"
        # está en alguno de ellos
        for interval in intervals_info:
            if interval[0][0] <= t <= interval[0][1]:
                if interval[1] == 'wheeze':
                    Y_wheeze[num] = 1
                if interval[1] == 'crackle':
                    Y_crackl[num] = 1
    
    return Y_wheeze, Y_crackl

# %% [markdown]
# # Extracción de características

# %%
# %matplotlib notebook


def get_ML_data_OLD(filenames, spec_params, mfcc_params=None, 
                lfcc_params=None, energy_params=None):
    '''
    '''
    # Definición de la lista donde se acumulará la información
    X_data = list()
    
    # Definición de los arrays donde se acumularán las etiquetas
    Y_wheeze = list()
    Y_crackl = list()
    
    # Nombre del archivo .wav a utilizar
    for num, filename in enumerate(filenames):
        print(f'Iteración {num + 1}: {name}')
        print(f'--------------------------')
        
        # Cargando el archivo
        try:
            samplerate, resp_signal = wavfile.read(f'{filename}.wav')
        except:
            resp_signal, samplerate = sf.read(f'{filename}.wav')
        
        print(f'Samplerate = {samplerate}, largo = {resp_signal.shape}')
        
        # Normalizando
        resp_signal = resp_signal / max(abs(resp_signal))
        
        
        # Obtener el tiempo y la dimensión de las características
        t, _, S = get_spectrogram(resp_signal, samplerate, 
                                  N=spec_params['N'], 
                                  padding=spec_params['padding'], 
                                  repeat=spec_params['repeat'], 
                                  noverlap=spec_params['noverlap'], 
                                  window=spec_params['window'], 
                                  whole=False)
        
        # Obteniendo la información de los segmentos de este archivo de 
        # audio
        sr = filename.split('_')[-1]
        name_lab = '_'.join(filename.split('/')[-1].split('_')[:-1])
        Y_wheeze_i, Y_crackl_i = \
                get_label_filename_ML(filename=name_lab, time_array=t)
        
#         Y_wh, Y_cr = \
#                 get_label_filename(filename=name_lab, samplerate=samplerate,
#                                    length_desired=len(resp_signal))
        
#         plt.figure()
#         plt.subplot(1,2,1)
#         plt.plot(Y_wheeze_i)
#         plt.plot(Y_crackl_i)
        
#         plt.subplot(1,2,2)
#         plt.plot(Y_wh)
#         plt.plot(Y_cr)
#         plt.show()
        
#         if num >= 10:
#             break
        
        
        
        # Definición de la matriz de características
#         feat_mat = np.zeros((0, len(t)))       
        
        ### Calculando las características ###

        # Cálculo del MFCC
        if mfcc_params is not None:
            # Calculando la característica
            mfcc_features = \
                get_cepstral_coefficients(resp_signal, samplerate, 
                                          spectrogram_params=mfcc_params['spec_params'],
                                          freq_lim=mfcc_params['freq_lim'], 
                                          n_filters=mfcc_params['n_filters'], 
                                          n_coefs=mfcc_params['n_mfcc'], 
                                          scale_type='mel', 
                                          filter_type='triangular', inverse_func='dct', 
                                          norm_filters=mfcc_params['norm_filters'], 
                                          plot_filterbank=False, 
                                          power=mfcc_params['power'])
            
            # Agregando
            feat_mat = np.concatenate((feat_mat, mfcc_features), axis=0)
            

        # Cálculo del LFCC
        if lfcc_params is not None:
            # Calculando la característica
            lfcc_features = \
                get_cepstral_coefficients(resp_signal, samplerate, 
                                          spectrogram_params=lfcc_params['spec_params'],
                                          freq_lim=lfcc_params['freq_lim'], 
                                          n_filters=lfcc_params['n_filters'], 
                                          n_coefs=lfcc_params['n_mfcc'], 
                                          scale_type='linear', 
                                          filter_type='triangular', inverse_func='dct', 
                                          norm_filters=lfcc_params['norm_filters'], 
                                          plot_filterbank=False, 
                                          power=lfcc_params['power'])
            
            # Agregando
            feat_mat = np.concatenate((feat_mat, lfcc_features), axis=0)

        
        # Cálculo de la energía por bandas
        if energy_params is not None:
            # Calculando la característica
            energy_S = \
                get_energy_bands(resp_signal, samplerate,
                                 spectrogram_params=energy_params['spec_params'],
                                 fmin=energy_params['fmin'], 
                                 fmax=energy_params['fmax'], 
                                 fband=energy_params['fband'])
            
            # Agregando
            feat_mat = np.concatenate((feat_mat, energy_S), axis=0)
            
        
        # Agregando la información a cada arreglo
        X_data.append(feat_mat)
        Y_wheeze.append(Y_wheeze_i)
        Y_crackl.append(Y_crackl_i)
        
        print(feat_mat.shape)
        print(Y_wheeze_i.shape)
        print(Y_crackl_i.shape)

    
    return X_data, Y_wheeze, Y_crackl


def get_ML_data(filenames, spec_params, mfcc_params=None, 
                lfcc_params=None, energy_params=None):
    '''
    '''
    # Definición de la lista donde se acumulará la información
    X_data = list()
    
    # Definición de los arrays donde se acumularán las etiquetas
    Y_wheeze = list()
    Y_crackl = list()
    
    # Nombre del archivo .wav a utilizar
    for num, filename in enumerate(filenames):
        print(f'Iteración {num + 1}: {filename}')
        print(f'--------------------------')
        
        # Cargando el archivo
        try:
            samplerate, resp_signal = wavfile.read(f'{filename}.wav')
        except:
            resp_signal, samplerate = sf.read(f'{filename}.wav')
        
        print(f'Samplerate = {samplerate}, largo = {resp_signal.shape}')
        
        # Normalizando
        resp_signal = resp_signal / max(abs(resp_signal))
        
        
        # Obtener el tiempo y la dimensión de las características
        t, _, S = get_spectrogram(resp_signal, samplerate, 
                                  N=spec_params['N'], 
                                  padding=spec_params['padding'], 
                                  repeat=spec_params['repeat'], 
                                  noverlap=spec_params['noverlap'], 
                                  window=spec_params['window'], 
                                  whole=False)
        
        # Obteniendo la información de los segmentos de este archivo de 
        # audio
        sr = filename.split('_')[-1]
        name_lab = '_'.join(filename.split('/')[-1].split('_')[:-1])
        Y_wheeze_i, Y_crackl_i = \
                get_label_filename_ML(filename=name_lab, time_array=t)       
        
        
        # Definición de la matriz de características
        feat_mat = np.zeros((0, len(t)))     
        
        
        ### Calculando las características ###

        # Cálculo del MFCC
        if mfcc_params is not None:
            # Calculando la característica
            mfcc_features = \
                get_cepstral_coefficients(resp_signal, samplerate, 
                                          spectrogram_params=mfcc_params['spec_params'],
                                          freq_lim=mfcc_params['freq_lim'], 
                                          n_filters=mfcc_params['n_filters'], 
                                          n_coefs=mfcc_params['n_mfcc'], 
                                          scale_type='mel', 
                                          filter_type='triangular', inverse_func='dct', 
                                          norm_filters=mfcc_params['norm_filters'], 
                                          plot_filterbank=False, 
                                          power=mfcc_params['power'])
            
            # Agregando
            feat_mat = np.concatenate((feat_mat, mfcc_features), axis=0)
            

        # Cálculo del LFCC
        if lfcc_params is not None:
            # Calculando la característica
            lfcc_features = \
                get_cepstral_coefficients(resp_signal, samplerate, 
                                          spectrogram_params=lfcc_params['spec_params'],
                                          freq_lim=lfcc_params['freq_lim'], 
                                          n_filters=lfcc_params['n_filters'], 
                                          n_coefs=lfcc_params['n_mfcc'], 
                                          scale_type='linear', 
                                          filter_type='triangular', inverse_func='dct', 
                                          norm_filters=lfcc_params['norm_filters'], 
                                          plot_filterbank=False, 
                                          power=lfcc_params['power'])
            
            # Agregando
            feat_mat = np.concatenate((feat_mat, lfcc_features), axis=0)

        
        # Cálculo de la energía por bandas
        if energy_params is not None:
            # Calculando la característica
            energy_S = \
                get_energy_bands(resp_signal, samplerate,
                                 spectrogram_params=energy_params['spec_params'],
                                 fmin=energy_params['fmin'], 
                                 fmax=energy_params['fmax'], 
                                 fband=energy_params['fband'])
            
            # Agregando
            feat_mat = np.concatenate((feat_mat, energy_S), axis=0)
            
        
        # Agregando la información a cada arreglo
        for i in range(feat_mat.shape[1]):
            X_data.append(feat_mat[:,i])
            Y_wheeze.append(Y_wheeze_i[i])
            Y_crackl.append(Y_crackl_i[i])

        print(feat_mat.shape)
        print(Y_wheeze_i.shape)
        print(Y_crackl_i.shape)

    
    return np.array(X_data), np.array(Y_wheeze), np.array(Y_crackl)

# %%
X_train, Y_wheeze_tr, Y_crackl_tr = \
        get_ML_data(train_list, spec_params=spec_params, mfcc_params=mfcc_params, 
                    lfcc_params=lfcc_params, energy_params=energy_params)
# Out:
# Iteración 1: preprocessed_signals/103_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 2: preprocessed_signals/106_2b1_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 3: preprocessed_signals/106_2b1_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 4: preprocessed_signals/107_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 5: preprocessed_signals/107_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 6: preprocessed_signals/107_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 7: preprocessed_signals/107_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 8: preprocessed_signals/107_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 9: preprocessed_signals/107_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 10: preprocessed_signals/107_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 11: preprocessed_signals/107_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 12: preprocessed_signals/107_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 13: preprocessed_signals/107_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 14: preprocessed_signals/107_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 15: preprocessed_signals/107_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 16: preprocessed_signals/107_2b5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 17: preprocessed_signals/107_2b5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 18: preprocessed_signals/107_2b5_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 19: preprocessed_signals/107_2b5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 20: preprocessed_signals/107_2b5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 21: preprocessed_signals/107_2b5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 22: preprocessed_signals/107_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 23: preprocessed_signals/107_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 24: preprocessed_signals/107_3p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 25: preprocessed_signals/107_3p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 26: preprocessed_signals/107_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 27: preprocessed_signals/107_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 28: preprocessed_signals/108_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 29: preprocessed_signals/110_1b1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (285800,)
# (149, 2776)
# (2776,)
# (2776,)
# Iteración 30: preprocessed_signals/110_1p1_Al_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (129200,)
# (149, 1256)
# (1256,)
# (1256,)
# Iteración 31: preprocessed_signals/110_1p1_Ll_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (129600,)
# (149, 1260)
# (1260,)
# (1260,)
# Iteración 32: preprocessed_signals/110_1p1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (129600,)
# (149, 1260)
# (1260,)
# (1260,)
# Iteración 33: preprocessed_signals/110_1p1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (301000,)
# (149, 2924)
# (2924,)
# (2924,)
# Iteración 34: preprocessed_signals/112_1b1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (271400,)
# (149, 2636)
# (2636,)
# (2636,)
# Iteración 35: preprocessed_signals/112_1b1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (134400,)
# (149, 1306)
# (1306,)
# (1306,)
# Iteración 36: preprocessed_signals/112_1p1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (117440,)
# (149, 1142)
# (1142,)
# (1142,)
# Iteración 37: preprocessed_signals/112_1p1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# (149, 1167)
# (1167,)
# (1167,)
# Iteración 38: preprocessed_signals/112_1p1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# (149, 1167)
# (1167,)
# (1167,)
# Iteración 39: preprocessed_signals/114_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 40: preprocessed_signals/114_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 41: preprocessed_signals/114_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 42: preprocessed_signals/114_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 43: preprocessed_signals/114_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 44: preprocessed_signals/115_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 45: preprocessed_signals/116_1b2_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 46: preprocessed_signals/120_1b1_Al_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (267000,)
# (149, 2594)
# (2594,)
# (2594,)
# Iteración 47: preprocessed_signals/120_1b1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (267000,)
# (149, 2594)
# (2594,)
# (2594,)
# Iteración 48: preprocessed_signals/120_1b1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (344800,)
# (149, 3349)
# (3349,)
# (3349,)
# Iteración 49: preprocessed_signals/120_1b1_Pl_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (269600,)
# (149, 2619)
# (2619,)
# (2619,)
# Iteración 50: preprocessed_signals/120_1b1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (269600,)
# (149, 2619)
# (2619,)
# (2619,)
# Iteración 51: preprocessed_signals/122_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 52: preprocessed_signals/122_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 53: preprocessed_signals/122_2b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 54: preprocessed_signals/122_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 55: preprocessed_signals/122_2b3_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 56: preprocessed_signals/122_2b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 57: preprocessed_signals/127_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88068,)
# (149, 857)
# (857,)
# (857,)
# Iteración 58: preprocessed_signals/129_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 59: preprocessed_signals/130_1p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 60: preprocessed_signals/130_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 61: preprocessed_signals/130_1p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 62: preprocessed_signals/130_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 63: preprocessed_signals/130_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 64: preprocessed_signals/130_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 65: preprocessed_signals/130_1p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 66: preprocessed_signals/130_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 67: preprocessed_signals/130_1p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 68: preprocessed_signals/130_1p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 69: preprocessed_signals/130_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 70: preprocessed_signals/130_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 71: preprocessed_signals/130_1p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 72: preprocessed_signals/130_1p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 73: preprocessed_signals/130_1p4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 74: preprocessed_signals/130_1p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 75: preprocessed_signals/130_1p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 76: preprocessed_signals/130_1p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 77: preprocessed_signals/130_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 78: preprocessed_signals/130_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 79: preprocessed_signals/130_2b2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 80: preprocessed_signals/130_2b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 81: preprocessed_signals/130_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 82: preprocessed_signals/130_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 83: preprocessed_signals/130_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 84: preprocessed_signals/130_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 85: preprocessed_signals/130_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 86: preprocessed_signals/130_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 87: preprocessed_signals/130_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 88: preprocessed_signals/130_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 89: preprocessed_signals/130_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 90: preprocessed_signals/130_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 91: preprocessed_signals/130_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 92: preprocessed_signals/130_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 93: preprocessed_signals/130_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 94: preprocessed_signals/130_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 95: preprocessed_signals/130_2p5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 96: preprocessed_signals/130_2p5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 97: preprocessed_signals/130_2p5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 98: preprocessed_signals/130_2p5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 99: preprocessed_signals/130_2p5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 100: preprocessed_signals/130_3b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 101: preprocessed_signals/130_3b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 102: preprocessed_signals/130_3b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 103: preprocessed_signals/130_3b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 104: preprocessed_signals/130_3b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 105: preprocessed_signals/130_3b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 106: preprocessed_signals/130_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 107: preprocessed_signals/130_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 108: preprocessed_signals/130_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 109: preprocessed_signals/130_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 110: preprocessed_signals/130_3p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 111: preprocessed_signals/130_3p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 112: preprocessed_signals/130_3p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 113: preprocessed_signals/130_3p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 114: preprocessed_signals/130_3p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 115: preprocessed_signals/130_3p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 116: preprocessed_signals/131_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 117: preprocessed_signals/132_2b1_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 118: preprocessed_signals/132_2b2_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 119: preprocessed_signals/134_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 120: preprocessed_signals/134_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 121: preprocessed_signals/134_2b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 122: preprocessed_signals/134_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 123: preprocessed_signals/134_2b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 124: preprocessed_signals/135_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 125: preprocessed_signals/135_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 126: preprocessed_signals/135_2b1_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 127: preprocessed_signals/135_2b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 128: preprocessed_signals/135_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 129: preprocessed_signals/135_2b2_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 130: preprocessed_signals/135_2b3_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 131: preprocessed_signals/135_2b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 132: preprocessed_signals/135_2b3_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 133: preprocessed_signals/135_2b3_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 134: preprocessed_signals/137_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 135: preprocessed_signals/137_1b1_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 136: preprocessed_signals/138_1p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 137: preprocessed_signals/138_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 138: preprocessed_signals/138_1p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 139: preprocessed_signals/138_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 140: preprocessed_signals/138_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 141: preprocessed_signals/138_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 142: preprocessed_signals/138_1p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 143: preprocessed_signals/138_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 144: preprocessed_signals/138_1p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 145: preprocessed_signals/138_1p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 146: preprocessed_signals/138_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 147: preprocessed_signals/138_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 148: preprocessed_signals/138_1p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 149: preprocessed_signals/138_1p4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 150: preprocessed_signals/138_1p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 151: preprocessed_signals/138_1p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 152: preprocessed_signals/138_1p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 153: preprocessed_signals/138_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 154: preprocessed_signals/138_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 155: preprocessed_signals/138_2p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 156: preprocessed_signals/138_2p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 157: preprocessed_signals/138_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 158: preprocessed_signals/138_2p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 159: preprocessed_signals/140_2b2_Ll_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 160: preprocessed_signals/140_2b3_Ll_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 161: preprocessed_signals/141_1b1_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 162: preprocessed_signals/141_1b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 163: preprocessed_signals/141_1b2_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 164: preprocessed_signals/141_1b2_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 165: preprocessed_signals/141_1b3_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 166: preprocessed_signals/141_1b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 167: preprocessed_signals/141_1b3_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 168: preprocessed_signals/142_1b1_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 169: preprocessed_signals/148_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 170: preprocessed_signals/152_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 171: preprocessed_signals/153_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 172: preprocessed_signals/154_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 173: preprocessed_signals/154_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 174: preprocessed_signals/154_1b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 175: preprocessed_signals/154_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 176: preprocessed_signals/154_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 177: preprocessed_signals/154_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 178: preprocessed_signals/154_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 179: preprocessed_signals/154_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 180: preprocessed_signals/154_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 181: preprocessed_signals/154_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 182: preprocessed_signals/154_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 183: preprocessed_signals/154_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 184: preprocessed_signals/154_3b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 185: preprocessed_signals/154_3b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 186: preprocessed_signals/154_3b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 187: preprocessed_signals/154_4b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 188: preprocessed_signals/154_4b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 189: preprocessed_signals/154_4b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 190: preprocessed_signals/154_4b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 191: preprocessed_signals/154_4b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 192: preprocessed_signals/154_4b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 193: preprocessed_signals/155_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 194: preprocessed_signals/156_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 195: preprocessed_signals/156_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 196: preprocessed_signals/156_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 197: preprocessed_signals/156_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 198: preprocessed_signals/156_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 199: preprocessed_signals/156_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 200: preprocessed_signals/156_5b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 201: preprocessed_signals/156_5b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 202: preprocessed_signals/156_5b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 203: preprocessed_signals/156_5b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 204: preprocessed_signals/156_5b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 205: preprocessed_signals/156_5b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 206: preprocessed_signals/156_8b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 207: preprocessed_signals/156_8b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 208: preprocessed_signals/156_8b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 209: preprocessed_signals/156_8b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 210: preprocessed_signals/156_8b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 211: preprocessed_signals/157_1b1_Al_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (260200,)
# (149, 2528)
# (2528,)
# (2528,)
# Iteración 212: preprocessed_signals/157_1b1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (260200,)
# (149, 2528)
# (2528,)
# (2528,)
# Iteración 213: preprocessed_signals/157_1b1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (266000,)
# (149, 2584)
# (2584,)
# (2584,)
# Iteración 214: preprocessed_signals/157_1b1_Pl_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (252400,)
# (149, 2452)
# (2452,)
# (2452,)
# Iteración 215: preprocessed_signals/157_1b1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (252400,)
# (149, 2452)
# (2452,)
# (2452,)
# Iteración 216: preprocessed_signals/158_1b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 217: preprocessed_signals/158_1p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 218: preprocessed_signals/158_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 219: preprocessed_signals/158_1p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 220: preprocessed_signals/158_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 221: preprocessed_signals/158_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 222: preprocessed_signals/158_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 223: preprocessed_signals/158_1p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 224: preprocessed_signals/158_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 225: preprocessed_signals/158_1p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 226: preprocessed_signals/158_1p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 227: preprocessed_signals/158_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 228: preprocessed_signals/158_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 229: preprocessed_signals/158_1p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 230: preprocessed_signals/158_1p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 231: preprocessed_signals/158_1p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 232: preprocessed_signals/158_1p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 233: preprocessed_signals/158_1p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 234: preprocessed_signals/158_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 235: preprocessed_signals/158_2p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 236: preprocessed_signals/159_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 237: preprocessed_signals/159_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 238: preprocessed_signals/159_1b1_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 239: preprocessed_signals/159_1b1_Pr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 240: preprocessed_signals/161_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 241: preprocessed_signals/161_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 242: preprocessed_signals/162_1b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 243: preprocessed_signals/162_1b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 244: preprocessed_signals/162_1b2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 245: preprocessed_signals/162_1b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 246: preprocessed_signals/162_1b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 247: preprocessed_signals/162_1b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 248: preprocessed_signals/162_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 249: preprocessed_signals/162_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 250: preprocessed_signals/162_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 251: preprocessed_signals/162_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 252: preprocessed_signals/162_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 253: preprocessed_signals/162_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 254: preprocessed_signals/162_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 255: preprocessed_signals/162_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 256: preprocessed_signals/162_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 257: preprocessed_signals/162_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 258: preprocessed_signals/162_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 259: preprocessed_signals/162_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 260: preprocessed_signals/162_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 261: preprocessed_signals/162_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 262: preprocessed_signals/163_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 263: preprocessed_signals/163_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 264: preprocessed_signals/163_2b2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 265: preprocessed_signals/163_2b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 266: preprocessed_signals/163_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 267: preprocessed_signals/163_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 268: preprocessed_signals/163_8b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 269: preprocessed_signals/163_8b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 270: preprocessed_signals/163_8b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 271: preprocessed_signals/163_8b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 272: preprocessed_signals/163_8b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 273: preprocessed_signals/163_8b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 274: preprocessed_signals/164_1b1_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 275: preprocessed_signals/166_1p1_Al_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (248200,)
# (149, 2411)
# (2411,)
# (2411,)
# Iteración 276: preprocessed_signals/166_1p1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (248200,)
# (149, 2411)
# (2411,)
# (2411,)
# Iteración 277: preprocessed_signals/166_1p1_Ll_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (231200,)
# (149, 2246)
# (2246,)
# (2246,)
# Iteración 278: preprocessed_signals/166_1p1_Pl_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (250000,)
# (149, 2429)
# (2429,)
# (2429,)
# Iteración 279: preprocessed_signals/166_1p1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (250000,)
# (149, 2429)
# (2429,)
# (2429,)
# Iteración 280: preprocessed_signals/167_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 281: preprocessed_signals/167_1b1_Pr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 282: preprocessed_signals/168_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 283: preprocessed_signals/172_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 284: preprocessed_signals/172_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 285: preprocessed_signals/172_1b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 286: preprocessed_signals/172_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 287: preprocessed_signals/172_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 288: preprocessed_signals/172_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 289: preprocessed_signals/172_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 290: preprocessed_signals/172_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 291: preprocessed_signals/172_1b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 292: preprocessed_signals/172_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 293: preprocessed_signals/172_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 294: preprocessed_signals/172_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 295: preprocessed_signals/172_1b5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 296: preprocessed_signals/172_1b5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 297: preprocessed_signals/172_1b5_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 298: preprocessed_signals/172_1b5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 299: preprocessed_signals/172_1b5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 300: preprocessed_signals/172_1b5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 301: preprocessed_signals/172_2b5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 302: preprocessed_signals/172_2b5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 303: preprocessed_signals/172_2b5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 304: preprocessed_signals/172_2b5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 305: preprocessed_signals/172_2b5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 306: preprocessed_signals/179_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 307: preprocessed_signals/180_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 308: preprocessed_signals/180_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 309: preprocessed_signals/180_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 310: preprocessed_signals/180_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 311: preprocessed_signals/180_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 312: preprocessed_signals/181_1b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 313: preprocessed_signals/181_1b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 314: preprocessed_signals/183_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# ...
# (149, 858)
# (858,)
# (858,)
# Iteración 363: preprocessed_signals/199_2b3_Ll_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 364: preprocessed_signals/200_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 365: preprocessed_signals/200_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 366: preprocessed_signals/200_2p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 367: preprocessed_signals/200_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 368: preprocessed_signals/200_2p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 369: preprocessed_signals/200_2p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 370: preprocessed_signals/200_2p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 371: preprocessed_signals/200_2p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 372: preprocessed_signals/200_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 373: preprocessed_signals/200_2p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 374: preprocessed_signals/200_2p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 375: preprocessed_signals/200_2p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 376: preprocessed_signals/200_2p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 377: preprocessed_signals/200_2p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 378: preprocessed_signals/200_2p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 379: preprocessed_signals/200_3p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 380: preprocessed_signals/200_3p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 381: preprocessed_signals/200_3p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 382: preprocessed_signals/200_3p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 383: preprocessed_signals/201_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 384: preprocessed_signals/201_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 385: preprocessed_signals/201_1b2_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 386: preprocessed_signals/201_1b2_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 387: preprocessed_signals/201_1b3_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 388: preprocessed_signals/201_1b3_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 389: preprocessed_signals/203_1p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 390: preprocessed_signals/203_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 391: preprocessed_signals/203_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 392: preprocessed_signals/203_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 393: preprocessed_signals/203_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 394: preprocessed_signals/203_1p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 395: preprocessed_signals/203_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 396: preprocessed_signals/203_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 397: preprocessed_signals/203_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 398: preprocessed_signals/203_1p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 399: preprocessed_signals/203_1p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 400: preprocessed_signals/203_1p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 401: preprocessed_signals/203_1p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 402: preprocessed_signals/203_2p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 403: preprocessed_signals/203_2p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 404: preprocessed_signals/203_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 405: preprocessed_signals/203_2p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 406: preprocessed_signals/204_2b5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 407: preprocessed_signals/204_2b5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 408: preprocessed_signals/204_2b5_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 409: preprocessed_signals/204_7p5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 410: preprocessed_signals/204_7p5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 411: preprocessed_signals/204_7p5_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 412: preprocessed_signals/204_7p5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 413: preprocessed_signals/204_7p5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 414: preprocessed_signals/206_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 415: preprocessed_signals/206_1b1_Lr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 416: preprocessed_signals/206_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 417: preprocessed_signals/208_1b1_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (87980,)
# (149, 856)
# (856,)
# (856,)
# Iteración 418: preprocessed_signals/210_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 419: preprocessed_signals/210_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (87406,)
# (149, 850)
# (850,)
# (850,)
# Iteración 420: preprocessed_signals/213_1p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 421: preprocessed_signals/213_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 422: preprocessed_signals/213_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 423: preprocessed_signals/213_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 424: preprocessed_signals/213_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 425: preprocessed_signals/213_1p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 426: preprocessed_signals/213_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 427: preprocessed_signals/213_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 428: preprocessed_signals/213_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 429: preprocessed_signals/213_1p5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 430: preprocessed_signals/213_1p5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 431: preprocessed_signals/213_1p5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 432: preprocessed_signals/213_1p5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 433: preprocessed_signals/213_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 434: preprocessed_signals/213_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 435: preprocessed_signals/213_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 436: preprocessed_signals/213_2p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 437: preprocessed_signals/215_1b2_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 438: preprocessed_signals/218_1b1_Al_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (284200,)
# (149, 2761)
# (2761,)
# (2761,)
# Iteración 439: preprocessed_signals/218_1b1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (284200,)
# (149, 2761)
# (2761,)
# (2761,)
# Iteración 440: preprocessed_signals/218_1b1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (330000,)
# (149, 3205)
# (3205,)
# (3205,)
# Iteración 441: preprocessed_signals/218_1b1_Pl_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (275800,)
# (149, 2679)
# (2679,)
# (2679,)
# Iteración 442: preprocessed_signals/218_1b1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (275800,)
# (149, 2679)
# (2679,)
# (2679,)
# Iteración 443: preprocessed_signals/218_1p1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (113856,)
# (149, 1107)
# (1107,)
# (1107,)
# Iteración 444: preprocessed_signals/218_1p1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# (149, 1167)
# (1167,)
# (1167,)
# Iteración 445: preprocessed_signals/218_1p1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (112320,)
# (149, 1092)
# (1092,)
# (1092,)
# Iteración 446: preprocessed_signals/219_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 447: preprocessed_signals/219_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 448: preprocessed_signals/220_1b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 449: preprocessed_signals/221_2b1_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 450: preprocessed_signals/221_2b1_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 451: preprocessed_signals/221_2b1_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 452: preprocessed_signals/221_2b1_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 453: preprocessed_signals/221_2b2_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 454: preprocessed_signals/221_2b2_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 455: preprocessed_signals/221_2b2_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 456: preprocessed_signals/221_2b2_Pl_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 457: preprocessed_signals/221_2b3_Al_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 458: preprocessed_signals/221_2b3_Ar_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 459: preprocessed_signals/221_2b3_Lr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 460: preprocessed_signals/221_2b3_Pr_mc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 461: preprocessed_signals/222_1b1_Ar_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (297800,)
# (149, 2893)
# (2893,)
# (2893,)
# Iteración 462: preprocessed_signals/222_1b1_Lr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (277800,)
# (149, 2699)
# (2699,)
# (2699,)
# Iteración 463: preprocessed_signals/222_1b1_Pr_sc_Meditron_4000
# --------------------------
# Samplerate = 4000, largo = (293400,)
# (149, 2850)
# (2850,)
# (2850,)
# Iteración 464: preprocessed_signals/226_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 465: preprocessed_signals/226_1b1_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 466: preprocessed_signals/226_1b1_Pl_sc_LittC2SE_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)

# %%
print(X_train.shape)
print(len(Y_wheeze_tr))
# Out:
# (449961, 149)
# 449961

# %%
X_test, Y_wheeze_test, Y_crackl_test = \
        get_ML_data(test_list, spec_params=spec_params, mfcc_params=mfcc_params, 
                    lfcc_params=lfcc_params, energy_params=energy_params)
# Out:
# Iteración 1: preprocessed_signals/101_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 2: preprocessed_signals/101_1b1_Pr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 3: preprocessed_signals/102_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 4: preprocessed_signals/104_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (63424,)
# (149, 617)
# (617,)
# (617,)
# Iteración 5: preprocessed_signals/104_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (102336,)
# (149, 995)
# (995,)
# (995,)
# Iteración 6: preprocessed_signals/104_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (73920,)
# (149, 719)
# (719,)
# (719,)
# Iteración 7: preprocessed_signals/104_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (60096,)
# (149, 585)
# (585,)
# (585,)
# Iteración 8: preprocessed_signals/104_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (91840,)
# (149, 893)
# (893,)
# (893,)
# Iteración 9: preprocessed_signals/104_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (94912,)
# (149, 923)
# (923,)
# (923,)
# Iteración 10: preprocessed_signals/109_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (81344,)
# (149, 791)
# (791,)
# (791,)
# Iteración 11: preprocessed_signals/109_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (79808,)
# (149, 776)
# (776,)
# (776,)
# Iteración 12: preprocessed_signals/109_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (67776,)
# (149, 660)
# (660,)
# (660,)
# Iteración 13: preprocessed_signals/109_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (69824,)
# (149, 679)
# (679,)
# (679,)
# Iteración 14: preprocessed_signals/109_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (70592,)
# (149, 687)
# (687,)
# (687,)
# Iteración 15: preprocessed_signals/109_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# (149, 1167)
# (1167,)
# (1167,)
# Iteración 16: preprocessed_signals/113_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# (149, 568)
# (568,)
# (568,)
# Iteración 17: preprocessed_signals/113_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (62912,)
# (149, 612)
# (612,)
# (612,)
# Iteración 18: preprocessed_signals/113_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (83392,)
# (149, 811)
# (811,)
# (811,)
# Iteración 19: preprocessed_signals/113_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# (149, 568)
# (568,)
# (568,)
# Iteración 20: preprocessed_signals/113_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (78528,)
# (149, 764)
# (764,)
# (764,)
# Iteración 21: preprocessed_signals/113_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (87744,)
# (149, 853)
# (853,)
# (853,)
# Iteración 22: preprocessed_signals/118_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (61888,)
# (149, 602)
# (602,)
# (602,)
# Iteración 23: preprocessed_signals/118_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (73408,)
# (149, 714)
# (714,)
# (714,)
# Iteración 24: preprocessed_signals/118_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (50112,)
# (149, 488)
# (488,)
# (488,)
# Iteración 25: preprocessed_signals/118_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (80320,)
# (149, 781)
# (781,)
# (781,)
# Iteración 26: preprocessed_signals/118_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (49856,)
# (149, 486)
# (486,)
# (486,)
# Iteración 27: preprocessed_signals/118_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (49856,)
# (149, 486)
# (486,)
# (486,)
# Iteración 28: preprocessed_signals/119_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 29: preprocessed_signals/123_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 30: preprocessed_signals/124_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (50112,)
# (149, 488)
# (488,)
# (488,)
# Iteración 31: preprocessed_signals/124_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (44992,)
# (149, 438)
# (438,)
# (438,)
# Iteración 32: preprocessed_signals/124_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (72896,)
# (149, 709)
# (709,)
# (709,)
# Iteración 33: preprocessed_signals/124_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (69056,)
# (149, 672)
# (672,)
# (672,)
# Iteración 34: preprocessed_signals/124_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (38336,)
# (149, 374)
# (374,)
# (374,)
# Iteración 35: preprocessed_signals/124_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (31424,)
# (149, 307)
# (307,)
# (307,)
# Iteración 36: preprocessed_signals/126_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 37: preprocessed_signals/133_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 38: preprocessed_signals/133_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 39: preprocessed_signals/133_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 40: preprocessed_signals/133_2p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 41: preprocessed_signals/133_2p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 42: preprocessed_signals/133_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 43: preprocessed_signals/133_2p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 44: preprocessed_signals/133_2p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 45: preprocessed_signals/133_2p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 46: preprocessed_signals/133_2p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 47: preprocessed_signals/133_2p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 48: preprocessed_signals/133_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 49: preprocessed_signals/133_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 50: preprocessed_signals/133_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 51: preprocessed_signals/133_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 52: preprocessed_signals/136_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 53: preprocessed_signals/139_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (78528,)
# (149, 764)
# (764,)
# (764,)
# Iteración 54: preprocessed_signals/139_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (67776,)
# (149, 660)
# (660,)
# (660,)
# Iteración 55: preprocessed_signals/139_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (83392,)
# (149, 811)
# (811,)
# (811,)
# Iteración 56: preprocessed_signals/139_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# (149, 568)
# (568,)
# (568,)
# Iteración 57: preprocessed_signals/139_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (58304,)
# (149, 568)
# (568,)
# (568,)
# Iteración 58: preprocessed_signals/139_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (64960,)
# (149, 632)
# (632,)
# (632,)
# Iteración 59: preprocessed_signals/143_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 60: preprocessed_signals/144_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88112,)
# (149, 857)
# (857,)
# (857,)
# Iteración 61: preprocessed_signals/145_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 62: preprocessed_signals/145_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 63: preprocessed_signals/145_2b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 64: preprocessed_signals/145_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 65: preprocessed_signals/145_3b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 66: preprocessed_signals/145_3b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 67: preprocessed_signals/145_3b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 68: preprocessed_signals/146_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 69: preprocessed_signals/146_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 70: preprocessed_signals/146_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 71: preprocessed_signals/146_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 72: preprocessed_signals/146_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 73: preprocessed_signals/146_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 74: preprocessed_signals/146_8p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 75: preprocessed_signals/146_8p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 76: preprocessed_signals/146_8p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 77: preprocessed_signals/146_8p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 78: preprocessed_signals/146_8p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 79: preprocessed_signals/147_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 80: preprocessed_signals/147_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 81: preprocessed_signals/147_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 82: preprocessed_signals/147_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 83: preprocessed_signals/147_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 84: preprocessed_signals/147_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 85: preprocessed_signals/147_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 86: preprocessed_signals/147_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 87: preprocessed_signals/147_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 88: preprocessed_signals/147_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 89: preprocessed_signals/147_2b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 90: preprocessed_signals/147_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 91: preprocessed_signals/147_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 92: preprocessed_signals/149_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 93: preprocessed_signals/149_1b1_Lr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 94: preprocessed_signals/149_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 95: preprocessed_signals/150_1b2_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 96: preprocessed_signals/151_2p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 97: preprocessed_signals/151_2p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 98: preprocessed_signals/151_2p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 99: preprocessed_signals/151_2p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 100: preprocessed_signals/151_2p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 101: preprocessed_signals/151_2p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 102: preprocessed_signals/151_2p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 103: preprocessed_signals/151_2p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 104: preprocessed_signals/151_2p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 105: preprocessed_signals/151_2p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 106: preprocessed_signals/151_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 107: preprocessed_signals/151_2p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 108: preprocessed_signals/151_2p4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 109: preprocessed_signals/151_2p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 110: preprocessed_signals/151_2p4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 111: preprocessed_signals/151_2p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 112: preprocessed_signals/151_2p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 113: preprocessed_signals/151_2p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 114: preprocessed_signals/151_3p2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 115: preprocessed_signals/151_3p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 116: preprocessed_signals/151_3p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 117: preprocessed_signals/151_3p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 118: preprocessed_signals/151_3p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 119: preprocessed_signals/151_3p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 120: preprocessed_signals/160_1b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 121: preprocessed_signals/160_1b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 122: preprocessed_signals/160_1b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 123: preprocessed_signals/160_1b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 124: preprocessed_signals/160_1b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 125: preprocessed_signals/160_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 126: preprocessed_signals/160_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 127: preprocessed_signals/160_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 128: preprocessed_signals/160_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 129: preprocessed_signals/160_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 130: preprocessed_signals/160_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 131: preprocessed_signals/160_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 132: preprocessed_signals/160_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 133: preprocessed_signals/160_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 134: preprocessed_signals/160_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 135: preprocessed_signals/160_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 136: preprocessed_signals/160_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 137: preprocessed_signals/160_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 138: preprocessed_signals/160_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 139: preprocessed_signals/165_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (87450,)
# (149, 851)
# (851,)
# (851,)
# Iteración 140: preprocessed_signals/165_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 141: preprocessed_signals/165_1b1_Pr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 142: preprocessed_signals/169_1b1_Lr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 143: preprocessed_signals/169_1b2_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 144: preprocessed_signals/170_1b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 145: preprocessed_signals/170_1b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 146: preprocessed_signals/170_1b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 147: preprocessed_signals/170_1b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 148: preprocessed_signals/170_1b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 149: preprocessed_signals/170_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 150: preprocessed_signals/170_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 151: preprocessed_signals/170_1b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 152: preprocessed_signals/170_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 153: preprocessed_signals/170_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 154: preprocessed_signals/170_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 155: preprocessed_signals/170_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 156: preprocessed_signals/170_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 157: preprocessed_signals/170_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 158: preprocessed_signals/170_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 159: preprocessed_signals/170_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 160: preprocessed_signals/170_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 161: preprocessed_signals/170_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 162: preprocessed_signals/170_2b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 163: preprocessed_signals/170_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 164: preprocessed_signals/170_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 165: preprocessed_signals/171_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 166: preprocessed_signals/173_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 167: preprocessed_signals/174_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 168: preprocessed_signals/174_1p2_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 169: preprocessed_signals/174_1p2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 170: preprocessed_signals/174_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 171: preprocessed_signals/174_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 172: preprocessed_signals/174_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 173: preprocessed_signals/174_1p3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 174: preprocessed_signals/174_1p3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 175: preprocessed_signals/174_1p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 176: preprocessed_signals/174_1p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 177: preprocessed_signals/174_1p4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 178: preprocessed_signals/174_1p4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 179: preprocessed_signals/174_1p4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 180: preprocessed_signals/174_1p4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 181: preprocessed_signals/174_1p4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 182: preprocessed_signals/174_2p3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 183: preprocessed_signals/174_2p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 184: preprocessed_signals/174_2p3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 185: preprocessed_signals/174_2p3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 186: preprocessed_signals/175_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (75456,)
# (149, 734)
# (734,)
# (734,)
# Iteración 187: preprocessed_signals/175_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (65472,)
# (149, 637)
# (637,)
# (637,)
# Iteración 188: preprocessed_signals/175_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (72896,)
# (149, 709)
# (709,)
# (709,)
# Iteración 189: preprocessed_signals/175_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (69056,)
# (149, 672)
# (672,)
# (672,)
# Iteración 190: preprocessed_signals/175_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (86720,)
# (149, 843)
# (843,)
# (843,)
# Iteración 191: preprocessed_signals/175_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (67008,)
# (149, 652)
# (652,)
# (652,)
# Iteración 192: preprocessed_signals/176_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 193: preprocessed_signals/176_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 194: preprocessed_signals/176_1b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 195: preprocessed_signals/176_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 196: preprocessed_signals/176_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 197: preprocessed_signals/176_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 198: preprocessed_signals/176_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 199: preprocessed_signals/176_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 200: preprocessed_signals/176_1b4_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 201: preprocessed_signals/176_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 202: preprocessed_signals/176_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 203: preprocessed_signals/176_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 204: preprocessed_signals/176_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 205: preprocessed_signals/176_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 206: preprocessed_signals/176_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 207: preprocessed_signals/176_2b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 208: preprocessed_signals/176_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 209: preprocessed_signals/176_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 210: preprocessed_signals/177_1b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 211: preprocessed_signals/177_1b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 212: preprocessed_signals/177_1b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 213: preprocessed_signals/177_1b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 214: preprocessed_signals/177_1b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 215: preprocessed_signals/177_1b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 216: preprocessed_signals/177_1b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 217: preprocessed_signals/177_1b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 218: preprocessed_signals/177_1b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 219: preprocessed_signals/177_1b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 220: preprocessed_signals/177_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 221: preprocessed_signals/177_2b4_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 222: preprocessed_signals/177_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 223: preprocessed_signals/177_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 224: preprocessed_signals/178_1b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 225: preprocessed_signals/178_1b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 226: preprocessed_signals/178_1b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 227: preprocessed_signals/178_1b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 228: preprocessed_signals/178_1b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 229: preprocessed_signals/178_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 230: preprocessed_signals/178_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 231: preprocessed_signals/178_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 232: preprocessed_signals/178_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 233: preprocessed_signals/178_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 234: preprocessed_signals/178_1b6_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 235: preprocessed_signals/178_1b6_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 236: preprocessed_signals/178_1b6_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 237: preprocessed_signals/178_1b6_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 238: preprocessed_signals/178_1b6_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 239: preprocessed_signals/178_1b6_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 240: preprocessed_signals/178_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 241: preprocessed_signals/178_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 242: preprocessed_signals/178_2b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 243: preprocessed_signals/178_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 244: preprocessed_signals/185_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (74688,)
# (149, 727)
# (727,)
# (727,)
# Iteración 245: preprocessed_signals/185_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (92096,)
# (149, 896)
# (896,)
# (896,)
# Iteración 246: preprocessed_signals/185_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (77504,)
# (149, 754)
# (754,)
# (754,)
# Iteración 247: preprocessed_signals/185_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (78528,)
# (149, 764)
# (764,)
# (764,)
# Iteración 248: preprocessed_signals/185_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (74944,)
# (149, 729)
# (729,)
# (729,)
# Iteración 249: preprocessed_signals/185_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (96960,)
# (149, 943)
# (943,)
# (943,)
# Iteración 250: preprocessed_signals/187_1b1_Ll_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 251: preprocessed_signals/194_1b1_Lr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 252: preprocessed_signals/194_1b1_Pr_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 253: preprocessed_signals/195_1b1_Al_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (107712,)
# (149, 1047)
# (1047,)
# (1047,)
# Iteración 254: preprocessed_signals/195_1b1_Ar_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# (149, 1167)
# (1167,)
# (1167,)
# Iteración 255: preprocessed_signals/195_1b1_Ll_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (98496,)
# (149, 958)
# (958,)
# (958,)
# Iteración 256: preprocessed_signals/195_1b1_Lr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (81344,)
# (149, 791)
# (791,)
# (791,)
# Iteración 257: preprocessed_signals/195_1b1_Pl_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (87488,)
# (149, 851)
# (851,)
# (851,)
# Iteración 258: preprocessed_signals/195_1b1_Pr_sc_Litt3200_4000
# --------------------------
# Samplerate = 4000, largo = (120000,)
# (149, 1167)
# (1167,)
# (1167,)
# Iteración 259: preprocessed_signals/198_1b5_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 260: preprocessed_signals/198_1b5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 261: preprocessed_signals/198_1b5_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 262: preprocessed_signals/198_1b5_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 263: preprocessed_signals/198_1b5_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 264: preprocessed_signals/198_1b5_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 265: preprocessed_signals/198_6p1_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 266: preprocessed_signals/198_6p1_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 267: preprocessed_signals/198_6p1_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 268: preprocessed_signals/198_6p1_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 269: preprocessed_signals/198_6p1_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 270: preprocessed_signals/198_6p1_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 271: preprocessed_signals/202_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (87318,)
# (149, 849)
# (849,)
# (849,)
# Iteración 272: preprocessed_signals/205_1b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 273: preprocessed_signals/205_1b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 274: preprocessed_signals/205_1b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 275: preprocessed_signals/205_1b3_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 276: preprocessed_signals/205_1b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 277: preprocessed_signals/205_1b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 278: preprocessed_signals/205_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 279: preprocessed_signals/205_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 280: preprocessed_signals/205_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 281: preprocessed_signals/205_2b3_Ll_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 282: preprocessed_signals/205_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 283: preprocessed_signals/205_3b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 284: preprocessed_signals/205_3b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 285: preprocessed_signals/205_3b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 286: preprocessed_signals/205_3b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 287: preprocessed_signals/205_4b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 288: preprocessed_signals/205_4b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 289: preprocessed_signals/205_4b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 290: preprocessed_signals/205_4b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 291: preprocessed_signals/205_4b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 292: preprocessed_signals/207_2b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 293: preprocessed_signals/207_2b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 294: preprocessed_signals/207_2b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 295: preprocessed_signals/207_2b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 296: preprocessed_signals/207_2b3_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 297: preprocessed_signals/207_2b3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 298: preprocessed_signals/207_2b3_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 299: preprocessed_signals/207_2b3_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 300: preprocessed_signals/207_2b4_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 301: preprocessed_signals/207_2b4_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 302: preprocessed_signals/207_2b4_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 303: preprocessed_signals/207_2b4_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 304: preprocessed_signals/207_3b2_Al_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 305: preprocessed_signals/207_3b2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 306: preprocessed_signals/207_3b2_Lr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 307: preprocessed_signals/207_3b2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 308: preprocessed_signals/207_3b2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 309: preprocessed_signals/211_1p2_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 310: preprocessed_signals/211_1p2_Pl_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 311: preprocessed_signals/211_1p2_Pr_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 312: preprocessed_signals/211_1p3_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 313: preprocessed_signals/211_1p5_Ar_mc_AKGC417L_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 314: preprocessed_signals/214_1b1_Ar_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (87494,)
# (149, 851)
# (851,)
# (851,)
# Iteración 315: preprocessed_signals/216_1b1_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 316: preprocessed_signals/216_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 317: preprocessed_signals/223_1b1_Pr_sc_Meditron_10000
# --------------------------
# Samplerate = 4000, largo = (131600,)
# (149, 1279)
# (1279,)
# (1279,)
# Iteración 318: preprocessed_signals/223_1b1_Pl_sc_Meditron_10000
# --------------------------
# Samplerate = 4000, largo = (131600,)
# (149, 1279)
# (1279,)
# (1279,)
# Iteración 319: preprocessed_signals/223_1b1_Ar_sc_Meditron_10000
# --------------------------
# Samplerate = 4000, largo = (135600,)
# (149, 1318)
# (1318,)
# (1318,)
# Iteración 320: preprocessed_signals/223_1b1_Al_sc_Meditron_10000
# --------------------------
# Samplerate = 4000, largo = (135600,)
# (149, 1318)
# (1318,)
# (1318,)
# Iteración 321: preprocessed_signals/223_1b1_Lr_sc_Meditron_10000
# --------------------------
# Samplerate = 4000, largo = (132800,)
# (149, 1291)
# (1291,)
# (1291,)
# Iteración 322: preprocessed_signals/223_1b1_Ll_sc_Meditron_10000
# --------------------------
# Samplerate = 4000, largo = (132800,)
# (149, 1291)
# (1291,)
# (1291,)
# Iteración 323: preprocessed_signals/224_1b2_Al_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)
# Iteración 324: preprocessed_signals/225_1b1_Pl_sc_Meditron_44100
# --------------------------
# Samplerate = 4410, largo = (88200,)
# (149, 858)
# (858,)
# (858,)

# %% [markdown]
# # Diseño del sistema de clasificación

# %%
def ML_classification_system(X_train, Y_train, X_test, Y_test, 
                             clean_params=None, sel_params=None, 
                             class_params=None):
    '''Diseño del sistema de clasificación basado en Machine 
    Learning.
    
    Parameters
    ----------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        'tol': 13-5, 'show': True. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        'n_features': 10, 'show': True. Por defecto es None.
    class_params: dict or None, optional
        Parámetros del proceso de clasificación. Si es None se 
        utilizan características por defecto: 
        'classifier': 'knn', 'k_neigh': 10. Por defecto es None. 
        En caso de usar 'svm', es posible modificar el 'kernel'.
        
    Returns
    -------
    classifier : class
        Clasificador entrenado.
    X_test : ndarray
        Matriz de testeo modificada (en caso de que X_test no 
        sea None).
    params_out : dict
        Parámetros obtenidos a partir del entrenamiento del
        sistema sobre los datos. Se entrega información de las
        características del clean ('s_clean'), normalización
        ('a_norm' y 'b_norm'), y de la selección de 
        características ('s_sfs').
    Y_pred : ndarray or None
        Predicción realizada por el sistema (en caso de que
        Y_test no sea None). Si no se entrega Y_test, la salida
        será None.
    '''
    # Parámetros por defecto
    if clean_params is None:
        clean_params = {'tol': 1e-5, 'show': True}
    
    if sel_params is None:
        sel_params = {'n_features': 10, 'show': True}
    
    if class_params is None:
        class_params = {'classifier': 'knn', 'k_neigh': 10}
        
    Y_pred = None
    
    
    #### Pipeline de la etapa de clasificación ####
    
    ## 1) Limpieza de las características
    s_clean = pybalu_clean(X_train, tol=clean_params['tol'], 
                           show=clean_params['show'])
    
    # Aplicando la limpieza
    X_train = X_train[:, s_clean]
    
    
    ## 2) Normalización de los datos
    X_train, a_norm, b_norm = normalize(X_train)
    
    
    ## 3) Selección de características
    s_sfs = sfs(X_train, Y_train, show=sel_params['show'],
                n_features=sel_params['n_features'])
    
    # Aplicando la selección
    X_train = X_train[:, s_sfs]
    
    
    ## 4) Proceso de clasificación   
    if class_params['classifier'] == 'knn':
        classifier = KNeighborsClassifier(n_neighbors=\
                                          class_params['k_neigh'])
        
    elif class_params['classifier'] == 'svm':
        classifier = svm.SVC(kernel=class_params['kernel'])
    
    else:
        raise Exception('Opción de clasificador no definida '
                        'correctamente.')
    
    # Ajustando el clasificador
    classifier.fit(X_train, Y_train)
    
    
    # Aplicando todo el proceso a los datos de testeo
    if X_test is not None:
        X_test = X_test[:, s_clean]         # 1) Clean
        X_test = a_norm * X_test + b_norm   # 2) Normalización
        X_test = X_test[:, s_sfs]           # 3) Selección
        
        # Aplicando el clasificador
        if Y_test is not None:
            Y_pred = classifier.predict(X_test)

    
    # Definición del diccionario de parámetros
    params_out = {'a_norm': a_norm, 'b_norm': b_norm, 's_clean': s_clean,
                  's_sfs': s_sfs}
        
    return classifier, X_test, params_out, Y_pred


def NN_MLP_classification_system(X_train, Y_train, X_test, Y_test, 
                                 clean_params=None, sel_params=None, 
                                 mlp_params=None):
    '''Diseño del sistema de clasificación basado en Redes Neuronales
    Multicapas.
    
    Parameters
    ----------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        {'tol': 13-5, 'show': True}. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        {'n_features': 10, 'show': True}. Por defecto es None.
    mlp_params : dict or None, optional
        Parámetros del preoceso de clasificación con MLP. Si es
        None se utilizan las características por defecto:
        {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
         'batch_size': None, 'epochs': 100, 'verbose': 1, 
         'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                      tf.keras.metrics.Precision()],
         'out_layer': 'sigmoid', 'preprocessing': True}
        
    Returns
    -------
    classifier : class
        Clasificador entrenado.
    X_test : ndarray
        Matriz de testeo modificada (en caso de que X_test no 
        sea None).
    params_out : dict
        Parámetros obtenidos a partir del entrenamiento del
        sistema sobre los datos. Se entrega información de las
        características del clean ('s_clean'), normalización
        ('a_norm' y 'b_norm'), y de la selección de 
        características ('s_sfs').
    Y_pred : ndarray or None
        Predicción realizada por el sistema (en caso de que
        Y_test no sea None). Si no se entrega Y_test, la salida
        será None.
    '''
    # Parámetros por defecto
    if clean_params is None:
        clean_params = {'tol': 1e-5, 'show': True}
    
    if sel_params is None:
        sel_params = {'n_features': 10, 'show': True}
        
    if mlp_params is None:
        mlp_params = {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
                      'batch_size': None, 'epochs': 100, 'verbose': 1, 
                      'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                                  tf.keras.metrics.Precision()],
                      'out_layer': 'sigmoid', 'preprocessing': True}
    
    Y_pred = None
    
    
    #### Pipeline de la etapa de clasificación ####
    
    # Rutina de preprocesamiento
    if mlp_params['preprocessing']:
        ## 1) Limpieza de las características
        s_clean = pybalu_clean(X_train, tol=clean_params['tol'], 
                               show=clean_params['show'])

        # Aplicando la limpieza
        X_train = X_train[:, s_clean]


        ## 2) Normalización de los datos
        X_train, a_norm, b_norm = normalize(X_train)


        ## 3) Selección de características
        s_sfs = sfs(X_train, Y_train, show=sel_params['show'],
                    n_features=sel_params['n_features'])

        # Aplicando la selección
        X_train = X_train[:, s_sfs]

    
    
    ## 4) Proceso de clasificación
    
    # Definición del modelo
    model = MLP_network(input_shape=(X_train.shape[1],),
                        out_layer=mlp_params['out_layer'])
    
    # Compilando modelos
    model.compile(optimizer=mlp_params['optimizer'], 
                  loss=mlp_params['loss'],
                  metrics=mlp_params['metrics'])
    
    
    # Definición de los vectores
    if mlp_params['out_layer'] == 'softmax':
        # One-Hot
        Y_train_to = \
            np.array([Y_train, np.ones(len(Y_train)) - Y_train]).T
    
    elif mlp_params['out_layer'] == 'sigmoid':
        # Normal
        Y_train_to = Y_train
    
    
    # Ajustando el Modelo
    history = model.fit(x=X_train, y=Y_train_to, 
                        batch_size=mlp_params['batch_size'],
                        epochs=mlp_params['epochs'],
                        verbose=mlp_params['verbose'])
    
    
    # Aplicando todo el proceso a los datos de testeo
    if X_test is not None:
        # Si se realizó el preprocesamiento, se actualiza
        if preprocessing:
            X_test = X_test[:, s_clean]         # 1) Clean
            X_test = X_test * a_norm + b_norm   # 2) Normalización
            X_test = X_test[:, s_sfs]           # 3) Selección
        
        # Aplicando el clasificador
        if Y_test is not None:
            Y_pred = model.predict(X_test)

    
    # Definición del diccionario de parámetros
    params_out = {'a_norm': a_norm, 'b_norm': b_norm, 's_clean': s_clean,
                  's_sfs': s_sfs, 'history': history}
        
    return model, X_test, params_out, Y_pred


def MLP_network_OLD(input_shape, out_layer='sigmoid'):
    '''Función que define una red de perceptrones multicapas para 
    clasificar.
    
    Parameters
    ----------
    input_shape : list or ndarray
        Dimensión de la información de entrada.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    
    def _layer(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    
    # Definición de la red misma
    x_layer = _layer(x_in, units=500, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_1')
    x_layer = _layer(x_layer, units=200, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_2')
    x_layer = _layer(x_layer, units=100, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_3')
    x_layer = _layer(x_layer, units=80, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_4')
    x_layer = _layer(x_layer, units=30, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_5')
    x_layer = _layer(x_layer, units=10, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_6')
    x_layer = _layer(x_layer, units=5, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_7')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_MLP')
    
    return model


def MLP_network(input_shape, out_layer='sigmoid'):
    '''Función que define una red de perceptrones multicapas para 
    clasificar.
    
    Parameters
    ----------
    input_shape : list or ndarray
        Dimensión de la información de entrada.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    
    def _layer(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    
    # Definición de la red misma
    x_layer = _layer(x_in, units=40, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_1')
    x_layer = _layer(x_layer, units=30, kernel_initializer='he_normal', 
                     bias_initializer='he_normal', name='Layer_2')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_MLP')
    
    return model


def CNN_network_OLD(input_shape, padding_value, out_layer='sigmoid'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling1D(pool_size=2, strides=2, 
                                             padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    # Definición de la capa de máscara
    x_masked = tf.keras.layers.Masking(mask_value=padding_value)(x_in)
                                             
    # Definición de la CNN
    layer_params_1 = {'filters': 50, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_masked, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 30, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 10, 'kernel_size': 25, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=3, layer_params=layer_params_3)
                                             
    layer_params_4 = {'filters': 7, 'kernel_size': 13, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_4'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=3, layer_params=layer_params_4)
                      
    
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.Flatten()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=500, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    x_layer = _mlp_layers(x_layer, units=200, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_2')
    x_layer = _mlp_layers(x_layer, units=100, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_3')
    x_layer = _mlp_layers(x_layer, units=80, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_4')
    x_layer = _mlp_layers(x_layer, units=30, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_5')
    x_layer = _mlp_layers(x_layer, units=10, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_6')
    x_layer = _mlp_layers(x_layer, units=5, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_7')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def CNN_network(input_shape, padding_value, out_layer='sigmoid'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling1D(pool_size=2, strides=2, 
                                             padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
                                             
    # Definición de la CNN
    layer_params_1 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_in, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_3)
                                             
    layer_params_4 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_4'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_4)
                      
    layer_params_5 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_5'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_5)
                                             
    layer_params_6 = {'filters': 15, 'kernel_size': 100, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_6'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_6)
    
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.Flatten()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=40, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def CNN_network_2(input_shape, padding_value, out_layer='sigmoid'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'sigmoid'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv1D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling1D(pool_size=2, strides=2, 
                                             padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    # Definición de la CNN
    layer_params_1 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_in, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_3)
                                             
    layer_params_4 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_4'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_4)
                      
    layer_params_5 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_5'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_5)
                                             
    layer_params_6 = {'filters': 100, 'kernel_size': 50, 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_6'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_6)
    
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.GlobalMaxPool1D()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=40, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def CNN_network_2D(input_shape, padding_value, out_layer='softmax'):
    '''Función que define una red CNN para extraer características y 
    clasificar.
    
    Parameters
    ----------
    padding_value : float
        Valor utilizado para hacer padding en la señal.
    out_layer : {'sigmoid', 'softmax'}, optional
        Función a usar en la capa de salida de la red. Por defecto
        es 'softmax'.
    
    Returns
    -------
    model: tensorflow.keras.Model
        Modelo del sistema.
    '''
    def _conv_bn_act_layer(input_layer, filters, kernel_size, padding,
                           kernel_initializer, bias_initializer, name):
        '''Función auxiliar que modela las capas azules conv + batchnorm +
        Activation ReLU para realizar el ENCODING.'''
        # Aplicando la concatenación de capas
        x_conv = tf.keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, 
                                        kernel_initializer=kernel_initializer,
                                        bias_initializer=bias_initializer,
                                        padding=padding, 
                                        name=f'Conv_{name}')(input_layer)
        x_conv = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_conv)
        x_conv = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_conv)

        return x_conv
    
    
    def _cnn_layers(input_layer, n_layers_conv, layer_params):
        '''Función auxiliar que permite modelar "n_layers_conv" capas CNN seguida de 
        una capa de Maxpooling.  
        '''
        # Definición de la salida de este bloque
        x_enc = input_layer
        
        # Aplicando "n_layers_conv" capas convolucionales de codificación
        for i in range(n_layers_conv):
            x_enc = _conv_bn_act_layer(x_enc, filters=layer_params['filters'], 
                                       kernel_size=layer_params['kernel_size'], 
                                       padding=layer_params['padding'],
                                       kernel_initializer=layer_params['kernel_initializer'],
                                       bias_initializer=layer_params['bias_initializer'],
                                       name=f"{layer_params['name']}_{i}")

        # Finalmente la capa de MaxPooling
        x_enc = tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=2, padding='valid',
                                             name=f"MaxPool_Conv_{layer_params['name']}")(x_enc)
        return x_enc
    
    
    def _mlp_layers(input_layer, units, kernel_initializer, 
               bias_initializer, name):
        '''Función auxiliar que modela las capas Dense + batchnorm +
        Activation ReLU'''
        # Aplicando la concatenación de capas
        x_dense = tf.keras.layers.Dense(units=units, 
                                        bias_initializer=bias_initializer,
                                        kernel_initializer=kernel_initializer,
                                        name=f'Dense_{name}')(input_layer)
        x_dense = \
            tf.keras.layers.BatchNormalization(name=f'BatchNorm_{name}')(x_dense)
        x_dense = \
            tf.keras.layers.Activation('relu', name=f'Activation_{name}')(x_dense)

        return x_dense
    
    
    # Definición de la entrada
    x_in = tf.keras.Input(shape=input_shape, dtype='float32')
    
    # Definición de la capa de máscara
    x_masked = tf.keras.layers.Masking(mask_value=padding_value)(x_in)
                                             
    # Definición de la CNN
    layer_params_1 = {'filters': 15, 'kernel_size': (5,5), 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_1'}
    x_layer = _cnn_layers(x_masked, n_layers_conv=2, layer_params=layer_params_1)
                                             
    layer_params_2 = {'filters': 15, 'kernel_size': (4,4), 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_2'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_2)
                                             
    layer_params_3 = {'filters': 15, 'kernel_size': (3,3), 'padding': 'same',
                      'kernel_initializer': 'he_normal',
                      'bias_initializer': 'he_normal', 'name': 'cnn_3'}
    x_layer = _cnn_layers(x_layer, n_layers_conv=2, layer_params=layer_params_3)
    
                                             
    # Definición de la capa de aplanamiento para conectar la CNN con la FCL 
    x_layer = tf.keras.layers.Flatten()(x_layer)                                     
    
    
    # Definición de la red misma
    x_layer = _mlp_layers(x_layer, units=40, kernel_initializer='he_normal', 
                          bias_initializer='he_normal', name='Layer_1')
    
    # Definición de la salida
    if out_layer == 'softmax':
        x_out = tf.keras.layers.Dense(2, activation='softmax', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='softmax_out')(x_layer)
    elif out_layer == 'sigmoid':
        x_out = tf.keras.layers.Dense(1, activation='sigmoid', 
                                      kernel_initializer='he_normal', 
                                      bias_initializer='he_normal',
                                      name='sigmoid_out')(x_layer)
    else:
        raise Exception(f'Opción de parámetro "out_layer"={out_layer} '
                        f'no válido.')
    
    # Definir el modelo
    model = tf.keras.Model(inputs=x_in, outputs=x_out, name='Red_CNN')
    
    return model

                                             
def train_test_definition(X_data, Y_data, index_test, patient_groups,
                          patient_register, kfold=10):
    '''Función que permite retornar los conjuntos de entrenamiento
    y testeo en base a la división de la base de datos realizada 
    previamente para hacer una validación cruzada.
    
    Parameters
    ----------
    X_data : ndarray
        Matriz de características.
    Y_data : ndarray
        Etiquetas de la matriz de características.
    index_test : int
        Índice del grupo de testeo en la validación cruzada.
    patient_gropus : dict
        Diccionario que contiene los pacientes que corresponden
        a cada grupo de la validación cruzada.
    patient_register : dict
        Diccionario que contiene las entradas de cada paciente
        en la matriz de características.
    kfold : int, optional
        k de la validación cruzada que se realiza. Por defecto 
        es 10.
    
    Returns
    -------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    '''
    # Definición de los pacientes de testeo 
    test_patients = patient_groups[index_test]
    
    # Y entrenamiento
    train_patients = list()
    for i in range(1, kfold + 1):
        if i != index_test:
            train_patients.extend(patient_groups[i])
            
    # Definición de las entradas de entrenamiento y testeo
    train_indexes = list()
    test_indexes = list()
    
    for i in train_patients:
        train_indexes.extend(patient_register[str(i)])
    
    for i in test_patients:
        test_indexes.extend(patient_register[str(i)])

    # Aplicando los indices sobre los datos
    X_train = X_data[train_indexes]
    Y_train = Y_data[train_indexes]
    X_test  = X_data[test_indexes]
    Y_test  = Y_data[test_indexes]
    
    return X_train, Y_train, X_test, Y_test
    
    
def crossval_results(X_data, Y_data, experiment_type='ML', clean_params=None, 
                     sel_params=None, class_params=None, mlp_params=None,
                     kfold=10):
    '''Función que permite calcular el desempeño del clasificador
    mediante una validación cruzada de los datos.
    
    Parameters
    ----------
    X_data : ndarray
        Matriz de características.
    Y_data : ndarray
        Etiquetas de la matriz de características.
    experiment_type : {'ML', 'NN-MLP' 'CNN'}, optional
        Tipo de sistema a estudiar. 'ML' corresponde a un diseño
        estilo Machine-Learning (Rec. de Patrones). 'NN-MLP'
        corresponde a un diseño que utiliza como salida un 
        clasificador de perceptrones multicapas. 'CNN' es un
        diseño que utiliza una CNN con arquitectura clásica
        (AlexNet o VGG-16) para clasificar cada segmento.
        Por defecto es 'ML'.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        'tol': 13-5, 'show': True. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        'n_features': 10, 'show': True. Por defecto es None.
    class_params: dict or None, optional
        Parámetros del proceso de clasificación. Si es None se 
        utilizan características por defecto: 
        'classifier': 'knn', 'k_neigh': 10. Por defecto es None. 
        En caso de usar 'svm', es posible modificar el 'kernel'.
    mlp_params : dict or None, optional
        Parámetros del preoceso de clasificación con MLP. Si es
        None se utilizan las características por defecto:
        {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
         'batch_size': None, 'epochs': 100, 'verbose': 1, 
         'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                      tf.keras.metrics.Precision()],
         'out_layer': 'sigmoid', 'preprocessing': True}
    kfold : int, optional
        k de las repeticiones de la validación cruzada k-fold.
        Por defecto es 10.
    
    Returns
    -------
    confmat_list: list
        Lista de las matrices de confusión para cada iteración.
    accuracy_list : list
        Lista de las accuracys para cada iteración.
    '''
    # Definición de la lista de matrices de confusión
    confmat_list = list()
    
    # Iteraciónes del k-fold cross validation
    for index in range(1, kfold + 1):
        # Definición de la base de datos
        X_train, Y_train, X_test, Y_test = \
            train_test_definition(X_data, Y_data, index_test=index, 
                                  patient_groups=patient_groups,
                                  patient_register=patient_register)

        # Aplicando el clasificador
        if experiment_type == 'ML':
            classifier, X_test, params_out, Y_pred = \
                    ML_classification_system(X_train, Y_train, X_test, Y_test, 
                                             clean_params=clean_params, 
                                             sel_params=sel_params, 
                                             class_params=class_params)
            
        elif experiment_type == 'NN-MLP':
            model, X_test, params_out, Y_pred = \
                NN_MLP_classification_system(X_train, Y_train, X_test, Y_test, 
                                             clean_params=clean_params, 
                                             sel_params=sel_params, 
                                             mlp_params=mlp_params)
            
            # Modificar el Y_pred
            Y_pred = np.where(Y_pred < 0.5, 0, 1)[:, 0]

        elif experiment_type == 'CNN':
            pass
    
        else:
            raise Exception('Opción no válida para "experiment_type".')
    
        # Obteniendo la matriz de confusión
        conf_mat = confusion_matrix(Y_pred, Y_test)
        
        # Agregando a la lista
        confmat_list.append(conf_mat)
    
    # Cálculo de los resultados finales
    accuracy_list = list()
    
    for cmat in confmat_list:
        accuracy_i = np.sum(np.diag(cmat)) / np.sum(cmat)
        accuracy_list.append(accuracy_i)
        
    print(f'Accuracy {kfold}-fold CV: {np.mean(accuracy_list)} +- '
          f'{np.std(accuracy_list)}')
    
    return confmat_list, accuracy_list
                                             
                                             
def events_eval_results(X_train, Y_train, X_test, Y_test, experiment_type='ML', 
                        clean_params=None, sel_params=None, class_params=None, 
                        mlp_params=None):
    '''Función que permite calcular el desempeño del clasificador
    mediante una validación cruzada de los datos.
    
    Parameters
    ----------
    X_train : ndarray
        Datos de entrenamiento.
    Y_train : ndarray
        Etiquetas de los datos de entrenamiento.
    X_test : ndarray
        Datos de testeo.
    Y_test : ndarray
        Etiquetas de los datos de testeo.
    experiment_type : {'ML', 'NN-MLP' 'CNN'}, optional
        Tipo de sistema a estudiar. 'ML' corresponde a un diseño
        estilo Machine-Learning (Rec. de Patrones). 'NN-MLP'
        corresponde a un diseño que utiliza como salida un 
        clasificador de perceptrones multicapas. 'CNN' es un
        diseño que utiliza una CNN con arquitectura clásica
        (AlexNet o VGG-16) para clasificar cada segmento.
        Por defecto es 'ML'.
    clean_params: dict or None, optional
        Parámetros del proceso de limpieza de características. 
        Si es None se utilizan características por defecto: 
        'tol': 13-5, 'show': True. Por defecto es None.
    sel_params: dict or None, optional
        Parámetros del proceso de selección de características. 
        Si es None se utilizan características por defecto: 
        'n_features': 10, 'show': True. Por defecto es None.
    class_params: dict or None, optional
        Parámetros del proceso de clasificación. Si es None se 
        utilizan características por defecto: 
        'classifier': 'knn', 'k_neigh': 10. Por defecto es None. 
        En caso de usar 'svm', es posible modificar el 'kernel'.
    mlp_params : dict or None, optional
        Parámetros del preoceso de clasificación con MLP. Si es
        None se utilizan las características por defecto:
        {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
         'batch_size': None, 'epochs': 100, 'verbose': 1, 
         'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                      tf.keras.metrics.Precision()],
         'out_layer': 'sigmoid', 'preprocessing': True}.
    
    Returns
    -------
    confmat_list: list
        Lista de las matrices de confusión para cada iteración.
    accuracy_list : list
        Lista de las accuracys para cada iteración.
    '''    
    # Aplicando el clasificador
    if experiment_type == 'ML':
        classifier, X_test, params_out, Y_pred = \
                ML_classification_system(X_train, Y_train, X_test, Y_test, 
                                         clean_params=clean_params, 
                                         sel_params=sel_params, 
                                         class_params=class_params)

    elif experiment_type == 'NN-MLP':
        classifier, X_test, params_out, Y_pred = \
            NN_MLP_classification_system(X_train, Y_train, X_test, Y_test, 
                                         clean_params=clean_params, 
                                         sel_params=sel_params, 
                                         mlp_params=mlp_params)

        # Modificar el Y_pred
        Y_pred = np.where(Y_pred < 0.5, 0, 1)[:, 0]

    elif experiment_type == 'CNN':
        pass

    else:
        raise Exception('Opción no válida para "experiment_type".')

    # Obteniendo la matriz de confusión
    conf_mat = confusion_matrix(Y_pred, Y_test)
    accuracy = np.sum(np.diag(conf_mat)) / np.sum(conf_mat)
        
    print(f'Accuracy: {accuracy}')
    
    return conf_mat, accuracy, classifier

# %%
# Parámetros generales
clean_params = {'tol': 1e-5, 'show': True}
sel_params = {'n_features': 60, 'show': True}

# %% [markdown]
# # kNN

# %%
class_params = {'classifier': 'knn', 'k_neigh': 3}

# Diseño de los clasificadores y resultados
confmat_wheeze, accuracy_wheeze = \
        events_eval_results(X_train, Y_wheeze_tr, X_test, Y_wheeze_test, 
                            experiment_type='ML', 
                            clean_params=clean_params, 
                            sel_params=sel_params, 
                            class_params=class_params)

confmat_crackl, accuracy_crackl = \
        events_eval_results(X_train, Y_crackl_tr, X_test, Y_crackl_test,  
                            experiment_type='ML', 
                            clean_params=clean_params, 
                            sel_params=sel_params, 
                            class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 138.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [27:01<00:00, 27.0s/ features]
# Accuracy: 0.9103213281612746
# Clean: number of features reduced from 149 to 138.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [27:27<00:00, 27.5s/ features]

# %% [markdown]
# # SVM

# %%
class_params = {'classifier': 'svm', 'kernel': 'poly'}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='ML', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         class_params=class_params)
# Out:
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.41 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.39 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.31 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.40 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.43 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.27 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.30 features/s]
# Accuracy 10-fold CV: 0.7977224996719388 +- 0.07023547049904728
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.40 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.47 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:23<00:00, 2.50 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.47 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.45 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.50 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Clean: number of features reduced from 149 to 148.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.49 features/s]
# Accuracy 10-fold CV: 0.6014071003621553 +- 0.09932738706666563
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.38 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.37 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.36 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features:  67%|██████████████████████████████████▋                 | 40.0/60.0 [00:11<00:10, 1.83 features/s]

# %% [markdown]
# # Redes Neuronales MLP

# %%
preprocessing = True
mlp_params = {'optimizer': 'Adam', 'loss': 'binary_crossentropy',
              'batch_size': None, 'epochs': 30, 'verbose': 0, 
              'metrics': ['accuracy', tf.keras.metrics.Recall(), 
                          tf.keras.metrics.Precision()],
              'out_layer': 'sigmoid', 'preprocessing': True}

# Diseño de los clasificadores y resultados
confmat_wheeze_mean, accuracy_wheeze_mean = \
        crossval_results(X_data_mean, Y_wheeze, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_crackl_mean, accuracy_crackl_mean = \
        crossval_results(X_data_mean, Y_crackl, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_wheeze_max, accuracy_wheeze_max = \
        crossval_results(X_data_max, Y_wheeze, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)

confmat_crackl_max, accuracy_crackl_max = \
        crossval_results(X_data_max, Y_crackl, 
                         experiment_type='NN-MLP', 
                         clean_params=clean_params, 
                         sel_params=sel_params, 
                         mlp_params=mlp_params)
# Out:
# Clean: number of features reduced from 149 to 122.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.05 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.05 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.14 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:21<00:00, 2.78 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.09 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.01 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:28<00:00, 2.09 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.62 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:22<00:00, 2.69 features/s]
# Accuracy 10-fold CV: 0.7614519708020536 +- 0.05586195315613456
# Clean: number of features reduced from 149 to 122.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.26 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.95 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.15 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.07 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.17 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.10 features/s]
# Clean: number of features reduced from 149 to 124.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:19<00:00, 3.12 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.23 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:20<00:00, 2.99 features/s]
# Clean: number of features reduced from 149 to 123.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:18<00:00, 3.18 features/s]
# Accuracy 10-fold CV: 0.5878765666011667 +- 0.060046022376537465
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.29 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.22 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.24 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.25 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.21 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:28<00:00, 2.12 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.20 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.32 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:29<00:00, 2.06 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:27<00:00, 2.21 features/s]
# Accuracy 10-fold CV: 0.7791725087409809 +- 0.054885882735558486
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.30 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.23 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.44 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.42 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:26<00:00, 2.30 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.31 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.31 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:24<00:00, 2.42 features/s]
# Clean: number of features reduced from 149 to 149.
# Selecting Features: 100%|████████████████████████████████████████████████████| 60.0/60.0 [00:25<00:00, 2.33 features/s]
# Accuracy 10-fold CV: 0.5803796909170138 +- 0.061762798859557225
